# %%
# %matplotlib inline

import os

os.environ["KERAS_BACKEND"] = "tensorflow"

import tensorflow.keras as keras
from tensorflow.keras import layers
# from tensorflow.keras import ops
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization
import numpy as np
import os
import string
import random
import tensorflow as tf
import tensorflow.data as tf_data
import tensorflow.strings as tf_strings

from stellargraph.data import BiasedRandomWalk
from stellargraph import StellarGraph, IndexedArray
from gensim.models import Word2Vec
import pandas as pd
import matplotlib.pyplot as plt

from graph_visualization import GraphVisualization

print("Tensorflow verions:", tf.__version__)
print('Available GPUs:', tf.config.experimental.list_physical_devices('GPU'))
# Out:
# Tensorflow verions: 2.4.0
# Available GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
def causal_attention_mask(batch_size, n_dest, n_src, dtype):
    """
    Mask the upper half of the dot product matrix in self attention.
    This prevents flow of information from future tokens to current token.
    1's in the lower triangle, counting from the lower right corner.
    """
    i = tf.range(n_dest)[:, None]
    j = tf.range(n_src)
    m = i >= j - n_src + n_dest
    mask = tf.cast(m, dtype)
    mask = tf.reshape(mask, [1, n_dest, n_src])
    mult = tf.concat(
        [tf.expand_dims(batch_size, -1), tf.convert_to_tensor([1, 1])], 0
    )
    return tf.tile(mask, mult)


class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super().__init__()
        self.att = layers.MultiHeadAttention(num_heads, embed_dim)
        self.ffn = keras.Sequential(
            [
                layers.Dense(ff_dim, activation="relu"),
                layers.Dense(embed_dim),
            ]
        )
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)

    def call(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size = input_shape[0]
        seq_len = input_shape[1]
        causal_mask = causal_attention_mask(batch_size, seq_len, seq_len, "bool")
        attention_output = self.att(inputs, inputs, attention_mask=causal_mask)
        attention_output = self.dropout1(attention_output)
        out1 = self.layernorm1(inputs + attention_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output)
        return self.layernorm2(out1 + ffn_output)

# %%
vocab_size = 30  # Only consider the top 20k words
maxlen = 10  # Max sequence size
batch_size = 128

# The dataset contains each review in a separate text file
# The text files are present in four different folders
# Create a list all files
filenames = []
directories = [
    "gpt-dataset/custom-2.2"
]
for dir in directories:
    for f in os.listdir(dir):
        filenames.append(os.path.join(dir, f))

# filenames = filenames[:1000]

print(f"{len(filenames)} files")

# Create a dataset from text files
random.shuffle(filenames)
text_ds = tf_data.TextLineDataset(filenames)
text_ds = text_ds.shuffle(buffer_size=256)
text_ds = text_ds.batch(batch_size)


def custom_standardization(input_string):
    """Remove html line-break tags and handle punctuation"""
    lowercased = tf_strings.lower(input_string)
    stripped_html = tf_strings.regex_replace(lowercased, "<br />", " ")
    return tf_strings.regex_replace(stripped_html, f"([{string.punctuation}])", r" \1")


# Create a vectorization layer and adapt it to the text
vectorize_layer = TextVectorization(
    standardize=custom_standardization,
    max_tokens=vocab_size - 1,
    output_mode="int",
    output_sequence_length=maxlen + 1,
)
vectorize_layer.adapt(text_ds)
vocab = vectorize_layer.get_vocabulary()  # To get words back from token indices


def prepare_lm_inputs_labels(text):
    """
    Shift word sequences by 1 position so that the target for position (i) is
    word at position (i+1). The model will use all words up till position (i)
    to predict the next word.
    """
    text = tf.expand_dims(text, -1)
    tokenized_sentences = vectorize_layer(text)
    x = tokenized_sentences[:, :-1]
    y = tokenized_sentences[:, 1:]

    # zeros_column = tf.zeros_like(y[:, :1])  # Create a column of zeros with the same shape as the first column of y
    # y = tf.concat([zeros_column, y], axis=1)  # Concatenate the zeros column with y along the column axis
    
    print('x',x)
    print('y',y)
    
    return x, y

text_ds = text_ds.map(prepare_lm_inputs_labels, num_parallel_calls=tf_data.AUTOTUNE)
text_ds = text_ds.prefetch(tf_data.AUTOTUNE)
# Out:
# 44 files
# x Tensor("strided_slice:0", shape=(None, 10), dtype=int64)
# y Tensor("strided_slice_1:0", shape=(None, 10), dtype=int64)

# %%
list(text_ds.take(1))[0][1]
# Out:
# <tf.Tensor: shape=(44, 10), dtype=int64, numpy=
# array([[ 2, 14,  9,  2, 11,  4,  8,  5,  0,  0],
#        [ 2, 21,  9,  2, 11,  4,  8,  5,  0,  0],
#        [ 2, 13,  2, 11,  4,  8,  5,  0,  0,  0],
#        [ 2, 13,  9,  2, 11,  4, 10,  5,  0,  0],
#        [ 2, 17,  9,  2, 11,  4, 10,  0,  0,  0],
#        [ 2, 18,  2, 11,  4,  8,  5,  0,  0,  0],
#        [ 2, 15,  6,  7,  4,  8,  5,  0,  0,  0],
#        [ 2, 19,  9,  6,  7,  4, 10,  5,  0,  0],
#        [ 2, 13,  9,  6,  7,  4,  8,  5,  0,  0],
#        [ 2, 19,  9,  2, 11,  4,  8,  5,  0,  0],
#        [ 6, 22,  2, 11,  4,  8,  5,  0,  0,  0],
#        [ 2, 20,  2, 11,  4, 10,  5,  0,  0,  0],
#        [ 2, 16,  6,  7,  4,  8,  5,  0,  0,  0],
#        [ 2, 19,  6,  7,  4,  8,  5,  0,  0,  0],
#        [ 2, 14,  9,  6,  7,  4, 10,  5,  0,  0],
#        [ 6, 23,  6,  7,  4, 10,  5,  0,  0,  0],
#        [ 2, 12,  9,  6,  7,  4,  8,  5,  0,  0],
#        [ 6, 22,  9,  2, 11,  4, 10,  5,  0,  0],
#        [ 2, 16,  9,  2, 11,  4,  8,  5,  0,  0],
#        [ 2, 20,  9,  2, 11,  4,  8,  5,  0,  0],
#        [ 2, 12,  9,  2, 11,  4, 10,  5,  0,  0],
#        [ 2, 12,  2, 11,  4,  8,  5,  0,  0,  0],
#        [ 2, 20,  6,  7,  4,  8,  5,  0,  0,  0],
#        [ 2, 14,  2, 11,  4, 10,  5,  0,  0,  0],
#        [ 2, 21,  9,  6,  7,  4, 10,  5,  0,  0],
#        [ 2, 16,  9,  6,  7,  4, 10,  5,  0,  0],
#        [ 2, 15,  9,  6,  7,  4, 10,  5,  0,  0],
#        [ 2, 17,  9,  6,  7,  4,  8,  5,  0,  0],
#        [ 2, 17,  6,  7,  4, 10,  5,  0,  0,  0],
#        [ 2, 20,  9,  6,  7,  4, 10,  5,  0,  0],
#        [ 2, 17,  2, 11,  4,  8,  5,  0,  0,  0],
#        [ 2, 14,  6,  7,  4,  8,  5,  0,  0,  0],
#        [ 2, 18,  9,  6,  7,  4,  8,  5,  0,  0],
#        [ 2, 15,  6,  7,  4, 10,  5,  0,  0,  0],
#        [ 2, 21,  2, 11,  4, 10,  5,  0,  0,  0],
#        [ 2, 16,  2, 11,  4, 10,  5,  0,  0,  0],
#        [ 2, 12,  6,  7,  4, 10,  5,  0,  0,  0],
#        [ 2, 15,  9,  6,  7,  4,  8,  5,  0,  0],
#        [ 2, 19,  2, 11,  4, 10,  5,  0,  0,  0],
#        [ 2, 18,  6,  7,  4, 10,  5,  0,  0,  0],
#        [ 6, 23,  9,  6,  7,  4,  8,  5,  0,  0],
#        [ 2, 13,  6,  7,  4, 10,  5,  0,  0,  0],
#        [ 2, 21,  6,  7,  4,  8,  5,  0,  0,  0],
#        [ 2, 18,  9,  2, 11,  4, 10,  5,  0,  0]], dtype=int64)>

# %%
graph_embedding_size = 10

def node2vec(G):
        walk_length = 100
        rw = BiasedRandomWalk(G)
        walks = rw.run(
            nodes=G.nodes(),  # root nodes
            length=walk_length,  # maximum length of a random walk
            n=10,  # number of random walks per root node
            p=0.5,  # Defines (unormalised) probability, 1/p, of returning to source node
            q=2.0,  # Defines (unormalised) probability, 1/q, for moving away from source node
            weighted=False,  # for weighted random walks
            seed=42,  # random seed fixed for reproducibility
        )

        model = Word2Vec(
            walks,  vector_size=graph_embedding_size, window=5, min_count=0, sg=1, workers=1
        )

        return pd.DataFrame([(key, vector) for key,vector in zip(model.wv.index_to_key, model.wv.vectors)], columns=['node', 'embedding'])

    
def get_graph():
    nodes, edges, edge_types = [], [], []

    nodes.append('vehicle')
    nodes.append('animal')
    nodes.append('car')
    nodes.append('truck')
    nodes.append('airplane')
    nodes.append('motorcycle')
    nodes.append('bus')
    nodes.append('bird')
    nodes.append('cat')
    nodes.append('lion')
    nodes.append('bear')
    nodes.append('boar')
    nodes.append('crane')
    nodes.append('yes')
    nodes.append('no')
    nodes.append('not')

    edges.append({'source': 'car', 'target': 'vehicle'})
    edges.append({'source': 'truck', 'target': 'vehicle'})
    edges.append({'source': 'airplane', 'target': 'vehicle'})
    edges.append({'source': 'motorcycle', 'target': 'vehicle'})
    edges.append({'source': 'bus', 'target': 'vehicle'})
    edges.append({'source': 'bird', 'target': 'animal'})
    edges.append({'source': 'cat', 'target': 'animal'})
    edges.append({'source': 'lion', 'target': 'animal'})
    edges.append({'source': 'bear', 'target': 'animal'})
    edges.append({'source': 'boar', 'target': 'animal'})
    edges.append({'source': 'crane', 'target': 'animal'})

    for i in range(10):
        edge_types.append('is-a')
    
    return {'nodes':nodes, 'edges': edges, 'edge_types': edge_types}

def get_embeddings(graph):
    edges_ = pd.DataFrame({
            'source': [e['source'] for e in graph['edges']],
            'target': [e['target'] for e in graph['edges']]
        })
    
    G = StellarGraph(IndexedArray(index=graph['nodes']), edges_)

    node_embeddings = node2vec(G)
        
    return node_embeddings
    
graph = get_graph()
node_embeddings = get_embeddings(graph)

# node_embeddings = []
# node_embeddings.append([1,0])
# node_embeddings.append([0,1])
# node_embeddings.append([1,0])
# node_embeddings.append([1,0])
# node_embeddings.append([1,0])
# node_embeddings.append([1,0])
# node_embeddings.append([1,0])
# node_embeddings.append([0,1])
# node_embeddings.append([0,1])
# node_embeddings.append([0,1])
# node_embeddings.append([0,1])
# node_embeddings.append([0,1])

# graph_embedding_size = 1
# node_embeddings = []
# node_embeddings.append([1])
# node_embeddings.append([0])
# node_embeddings.append([1])
# node_embeddings.append([1])
# node_embeddings.append([1])
# node_embeddings.append([1])
# node_embeddings.append([1])
# node_embeddings.append([0])
# node_embeddings.append([0])
# node_embeddings.append([0])
# node_embeddings.append([0])
# node_embeddings.append([0])
# node_embeddings.append([0])
# node_embeddings.append([2])
# node_embeddings.append([3])

# node_embeddings = pd.DataFrame({'node': graph['nodes'], 'embedding': node_embeddings})

tmp = []
for i,word in enumerate(vocab):
    lower_nodes = list(map(lambda k: k.lower(), node_embeddings['node']))
    index = lower_nodes.index(word.lower()) if word.lower() in lower_nodes else -1
    if index != -1:
        tmp.append(node_embeddings.iloc[index][1])
    else:
        tmp.append(np.ones(graph_embedding_size) * -10)

# for row in node_embeddings.iterrows():
#     if row[0] not in vocab:
#         tmp.append(row[1])

node_embeddings = np.array(tmp).tolist()

# %%
node_embeddings[0]
# Out:
# [-10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0]

# %%
vis = GraphVisualization()
for edge in graph['edges']:
    vis.addEdge(edge['source'], edge['target'])
vis.visualize()

# %%
[(word, emb) for word, emb in zip(vocab, node_embeddings)]
# Out:
# [('', [-10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0]),
#  ('[UNK]',
#   [-10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0]),
#  ('a', [-10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0]),
#  ('is',
#   [-10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0]),
#  ('?', [-10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0]),
#  ('.', [-10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0]),
#  ('an',
#   [-10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0]),
#  ('animal',
#   [-0.34831082820892334,
#    0.19004803895950317,
#    0.5853908061981201,
#    -0.11825250834226608,
#    0.3926621675491333,
#    -0.09015680849552155,
#    1.100113868713379,
#    1.3746931552886963,
#    -1.4121274948120117,
#    0.06103026121854782]),
#  ('yes',
#   [0.07817570865154266,
#    -0.09510187804698944,
#    -0.0020553111098706722,
#    0.0346919521689415,
#    -0.009389733895659447,
#    0.08381772041320801,
#    0.09010782092809677,
#    0.06536505371332169,
#    -0.007116222288459539,
#    0.07710404694080353]),
#  ('not',
#   [0.09964849799871445,
#    -0.04362444952130318,
#    -0.005993389990180731,
#    -0.05695638805627823,
#    0.03850822523236275,
#    0.027866268530488014,
#    0.06891076266765594,
#    0.06101095676422119,
#    0.09538495540618896,
#    0.09273417294025421]),
#  ('no',
#   [0.07898068428039551,
#    -0.06989505141973495,
#    -0.09155865013599396,
#    -0.003557539079338312,
#    -0.03099841997027397,
#    0.0789431557059288,
#    0.05938572809100151,
#    -0.015456628985702991,
#    0.015109634026885033,
#    0.01790039613842964]),
#  ('vehicle',
#   [-0.9469044208526611,
#    0.8033494353294373,
#    -1.4216547012329102,
#    1.162954330444336,
#    0.02351589873433113,
#    -0.9745506048202515,
#    0.03433467075228691,
#    -0.027837246656417847,
#    -0.8722615242004395,
#    -0.07872345298528671]),
#  ('truck',
#   [-1.1716574430465698,
#    0.8138883709907532,
#    -1.3941091299057007,
#    0.9876589179039001,
#    0.09955646842718124,
#    -0.9496541619300842,
#    -0.07881374657154083,
#    0.036513086408376694,
#    -0.6798946261405945,
#    0.1666976809501648]),
#  ('motorcycle',
#   [-1.1057372093200684,
#    0.7876437902450562,
#    -1.3161789178848267,
#    0.9946175217628479,
#    0.19839708507061005,
#    -0.9670937061309814,
#    0.003390965051949024,
#    -0.07957529276609421,
#    -0.6972442269325256,
#    0.17697778344154358]),
#  ('lion',
#   [-0.2498500794172287,
#    0.3242533802986145,
#    0.49404579401016235,
#    -0.22122269868850708,
#    0.7679380178451538,
#    0.05432597175240517,
#    0.9801452159881592,
#    1.1662602424621582,
#    -1.5353108644485474,
#    0.029309110715985298]),
#  ('crane',
#   [-0.23011235892772675,
#    0.21716079115867615,
#    0.31534624099731445,
#    -0.1754515916109085,
#    0.6981409192085266,
#    0.09749326854944229,
#    0.9810419082641602,
#    1.2053335905075073,
#    -1.400878667831421,
#    -0.03303799033164978]),
#  ('cat',
#   [-0.3031943142414093,
#    0.27853721380233765,
#    0.40350496768951416,
#    -0.26914137601852417,
#    0.6579874753952026,
#    0.02027360536158085,
#    0.9657471179962158,
#    1.0377434492111206,
#    -1.3643391132354736,
#    -0.06912744045257568]),
#  ('car',
#   [-1.1338863372802734,
#    0.7929596900939941,
#    -1.2008775472640991,
#    1.0631237030029297,
#    0.150441512465477,
#    -0.9580554962158203,
#    -0.049387749284505844,
#    0.05466923862695694,
#    -0.6588284969329834,
#    0.037050794810056686]),
#  ('bus',
#   [-1.1214227676391602,
#    0.817660927772522,
#    -1.276515245437622,
#    1.0791043043136597,
#    0.048917170614004135,
#    -0.9115983247756958,
#    0.0034049642272293568,
#    -0.031365472823381424,
#    -0.6931959986686707,
#    0.1855582445859909]),
#  ('boar',
#   [-0.28059130907058716,
#    0.27816835045814514,
#    0.4564482569694519,
#    -0.23999318480491638,
#    0.6739752292633057,
#    -0.013154266402125359,
#    0.9077639579772949,
#    1.1974068880081177,
#    -1.445570945739746,
#    0.08073373138904572]),
#  ('bird',
#   [-0.1876404583454132,
#    0.3937545120716095,
#    0.33430585265159607,
#    -0.33567655086517334,
#    0.6791810393333435,
#    0.013772277161478996,
#    1.0210124254226685,
#    1.1101830005645752,
#    -1.4116491079330444,
#    -0.14353908598423004]),
#  ('bear',
#   [-0.14565877616405487,
#    0.33289551734924316,
#    0.4554464817047119,
#    -0.18496073782444,
#    0.6352503895759583,
#    -0.048540908843278885,
#    0.9550666809082031,
#    1.2132737636566162,
#    -1.4262304306030273,
#    -0.08676141500473022]),
#  ('ariplane',
#   [-10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0]),
#  ('airplane',
#   [-1.13780677318573,
#    0.7912412881851196,
#    -1.333824634552002,
#    0.9198755621910095,
#    0.11786595731973648,
#    -0.8950762748718262,
#    -0.07923131436109543,
#    0.1090681403875351,
#    -0.6333650350570679,
#    0.21260622143745422])]

# %%
class TokenAndPositionEmbedding(layers.Layer):
    def __init__(self, maxlen, vocab_size, embed_dim):
        super().__init__()
        self.token_emb = layers.Embedding(input_dim=vocab_size, output_dim=embed_dim)
        self.pos_emb = layers.Embedding(input_dim=maxlen, output_dim=embed_dim)

    def call(self, x):
        maxlen = tf.shape(x)[-1]  # Modified line
        positions = tf.range(0, maxlen, 1)  # Modified line
        positions = self.pos_emb(positions)
        x = self.token_emb(x)
        return x + positions

# %%
class NodeEmbedding(layers.Layer):
    def __init__(self, node_embed_dim, node_embeddings):
        super().__init__()
        self.node_embeddings = tf.constant(node_embeddings, dtype=tf.float32)
        self.node_embed_dim = node_embed_dim
        self.dense = layers.Dense(node_embed_dim)

    def call(self, x):
         # Reshape x to add a new dimension for embedding
        node_indices = tf.cast(tf.math.round(x), tf.int32)
        node_emb = tf.gather(self.node_embeddings, node_indices)
        node_emb = self.dense(node_emb)  # Apply dense layer to each token embedding
        return node_emb

# %%
class TextGenerator(tf.keras.callbacks.Callback):
    """A callback to generate text from a trained model.
    1. Feed some starting prompt to the model
    2. Predict probabilities for the next token
    3. Sample the next token and add it to the next input

    Arguments:
        max_tokens: Integer, the number of tokens to be generated after prompt.
        start_tokens: List of integers, the token indices for the starting prompt.
        index_to_word: List of strings, obtained from the TextVectorization layer.
        top_k: Integer, sample from the `top_k` token predictions.
        print_every: Integer, print after this many epochs.
    """

    def __init__(
        self, max_tokens, start_tokens, index_to_word, model = None, top_k=10, print_every=1
    ):
        self.max_tokens = max_tokens
        self.start_tokens = start_tokens
        self.index_to_word = index_to_word
        self.print_every = print_every
        self.k = top_k
        if model: self.model = model
        self.yes_count = 0
        self.no_count = 0
        self.activation_outputs = []
        self.gradients = []

    def sample_from(self, logits):
        logits, indices = tf.math.top_k(logits, k=self.k, sorted=True)
        indices = tf.convert_to_tensor(indices, dtype=tf.int32)
        preds = tf.keras.activations.softmax(tf.expand_dims(logits, 0))[0]
        preds = tf.convert_to_tensor(preds, dtype=tf.float32)
  
        # Reshape logits to a matrix
        logits_matrix = tf.reshape(logits, (1, -1))
   
        # Sample from the softmax probabilities
        sampled_index = tf.random.categorical(tf.math.log(preds)[tf.newaxis, :], num_samples=1)

        # Return the sampled index
        return indices[sampled_index[0, 0]]

    def detokenize(self, number):
        return self.index_to_word[number] if number < len(self.index_to_word) else '---'

    def generate_token(self, _start_tokens, tokens_generated):
        pad_len = maxlen - len(_start_tokens)
        sample_index = len(_start_tokens) - 1
        if pad_len < 0:
            x = _start_tokens[:maxlen]
            sample_index = maxlen - 1
        elif pad_len > 0:
            x = _start_tokens + [0] * pad_len
        else:
            x = _start_tokens
        x = np.array([x])
        y = self.model.predict(x, verbose=0)
        sample_token = self.sample_from(y[0][sample_index])
        tokens_generated.append(sample_token)
        _start_tokens.append(sample_token)
        num_tokens_generated = len(tokens_generated)

        return _start_tokens, tokens_generated, num_tokens_generated, y

    def get_generated_text(self, tokens_generated):
        return " ".join(
            [self.detokenize(_) for _ in tokens_generated])
        
    def get_text(self, tokens_generated):
        return " ".join(
            [self.detokenize(_) for _ in self.start_tokens + tokens_generated])
        
    def on_epoch_end(self, epoch, logs=None):
        _start_tokens = [_ for _ in self.start_tokens]
        if (epoch + 1) % self.print_every != 0:
            return
        num_tokens_generated = 0
        tokens_generated = []
        raw_outputs = []
        while num_tokens_generated <= self.max_tokens:
            _start_tokens, tokens_generated, num_tokens_generated, raw_output = self.generate_token(_start_tokens, tokens_generated)
            raw_outputs.append(raw_output)
            
        txt = self.get_text(tokens_generated)
        print(f"generated text:\n{txt}\n")

        self.yes_count += 1 if 'yes' in txt else 0
        self.no_count += 1 if 'no' in txt else 0

        return txt, raw_outputs
    
    def generate(self):
        return self.on_epoc_end(1)

# Tokenize starting prompt
word_to_index = {}
for index, word in enumerate(vocab):
    word_to_index[word] = index

def callback(start_prompt, model=None, top_k=10):
    start_tokens = [word_to_index.get(_, 1) for _ in start_prompt.split()]
    num_tokens_generated = 10
    return TextGenerator(num_tokens_generated, start_tokens, vocab, top_k=top_k) if not model else TextGenerator(num_tokens_generated, start_tokens, vocab, model, top_k)

# %%
embed_dim = 128  # Embedding size for each token
num_heads = 2  # Number of attention heads
feed_forward_dim = 128  # Hidden layer size in feed forward network inside transformer

def create_model():
    inputs = layers.Input(shape=(maxlen,), dtype="float32")
    
    embedding_layer = TokenAndPositionEmbedding(maxlen, vocab_size, embed_dim)
    x = embedding_layer(inputs)
    transformer_block = TransformerBlock(embed_dim, num_heads, feed_forward_dim)
    x = transformer_block(x)

    outputs_1 = layers.Dense(vocab_size, name='text_output')(x)

    node_embedding_layer = NodeEmbedding(embed_dim, node_embeddings)
    x2 = node_embedding_layer(inputs)
    transformer_block = TransformerBlock(embed_dim, num_heads, feed_forward_dim)
    x2 = transformer_block(x2)

    outputs_2 = layers.Dense(vocab_size, name='graph_output')(x2)

    # Concatenate outputs of both branches
    outputs = layers.Average()([outputs_1, outputs_2])

    # outputs = outputs_2

    # Softmax layer
    # softmax_output = layers.Softmax()(outputs)
    
    model = tf.keras.Model(inputs=inputs, outputs=[outputs])
    loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
    model.compile(
        optimizer='adam',
        loss=[loss_fn, None],
    )  # No loss and optimization based on word embeddings from transformer block
    return model

# %%
model = create_model()
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 10)]         0
# __________________________________________________________________________________________________
# token_and_position_embedding_1  (None, 10, 128)      5120        input_2[0][0]
# __________________________________________________________________________________________________
# node_embedding_1 (NodeEmbedding (None, 10, 128)      1408        input_2[0][0]
# __________________________________________________________________________________________________
# transformer_block_2 (Transforme (None, 10, 128)      165504      token_and_position_embedding_1[0]
# __________________________________________________________________________________________________
# transformer_block_3 (Transforme (None, 10, 128)      165504      node_embedding_1[0][0]
# __________________________________________________________________________________________________
# text_output (Dense)             (None, 10, 30)       3870        transformer_block_2[0][0]
# __________________________________________________________________________________________________
# graph_output (Dense)            (None, 10, 30)       3870        transformer_block_3[0][0]
# __________________________________________________________________________________________________
# average_1 (Average)             (None, 10, 30)       0           text_output[0][0]
#                                                                  graph_output[0][0]
# ==================================================================================================
# Total params: 345,276
# Trainable params: 345,276
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
text_gen_callback = callback("is a bus not a vehicle ?", model, top_k=1)

# %%
history = model.fit(text_ds, verbose=1, epochs=250, callbacks=[text_gen_callback])
# Out:
# Epoch 1/250
# 1/1 [==============================] - 2s 2s/step - loss: 4.1880
# generated text:
# is a bus not a vehicle ? . lion a
#
# Epoch 2/250
# 1/1 [==============================] - 0s 33ms/step - loss: 2.7789
# generated text:
# is a bus not a vehicle ?
#
# Epoch 3/250
# 1/1 [==============================] - 0s 33ms/step - loss: 2.0766
# generated text:
# is a bus not a vehicle ?
#
# Epoch 4/250
# 1/1 [==============================] - 0s 34ms/step - loss: 1.7292
# generated text:
# is a bus not a vehicle ?
#
# Epoch 5/250
# 1/1 [==============================] - 0s 30ms/step - loss: 1.4936
# generated text:
# is a bus not a vehicle ?
#
# Epoch 6/250
# 1/1 [==============================] - 0s 32ms/step - loss: 1.3029
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 7/250
# 1/1 [==============================] - 0s 29ms/step - loss: 1.1664
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 8/250
# 1/1 [==============================] - 0s 30ms/step - loss: 1.0432
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 9/250
# 1/1 [==============================] - 0s 33ms/step - loss: 0.9550
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 10/250
# 1/1 [==============================] - 0s 34ms/step - loss: 0.8839
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 11/250
# 1/1 [==============================] - 0s 31ms/step - loss: 0.8164
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 12/250
# 1/1 [==============================] - 0s 36ms/step - loss: 0.7559
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 13/250
# 1/1 [==============================] - 0s 37ms/step - loss: 0.7205
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 14/250
# 1/1 [==============================] - 0s 31ms/step - loss: 0.6848
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 15/250
# 1/1 [==============================] - 0s 32ms/step - loss: 0.6444
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 16/250
# 1/1 [==============================] - 0s 32ms/step - loss: 0.6310
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 17/250
# 1/1 [==============================] - 0s 35ms/step - loss: 0.6058
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 18/250
# 1/1 [==============================] - 0s 33ms/step - loss: 0.5901
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 19/250
# 1/1 [==============================] - 0s 30ms/step - loss: 0.5712
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 20/250
# 1/1 [==============================] - 0s 35ms/step - loss: 0.5661
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 21/250
# 1/1 [==============================] - 0s 33ms/step - loss: 0.5586
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 22/250
# 1/1 [==============================] - 0s 29ms/step - loss: 0.5405
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 23/250
# 1/1 [==============================] - 0s 32ms/step - loss: 0.5389
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 24/250
# 1/1 [==============================] - 0s 30ms/step - loss: 0.5278
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 25/250
# 1/1 [==============================] - 0s 33ms/step - loss: 0.5307
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 26/250
# 1/1 [==============================] - 0s 30ms/step - loss: 0.5216
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 27/250
# 1/1 [==============================] - 0s 33ms/step - loss: 0.5046
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 28/250
# 1/1 [==============================] - 0s 35ms/step - loss: 0.5123
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 29/250
# 1/1 [==============================] - 0s 29ms/step - loss: 0.5092
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 30/250
# 1/1 [==============================] - 0s 28ms/step - loss: 0.5023
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 31/250
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4916
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 32/250
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4977
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 33/250
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4919
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 34/250
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4946
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 35/250
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4919
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 36/250
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4884
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 37/250
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4933
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 38/250
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4864
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 39/250
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4864
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 40/250
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4778
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 41/250
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4962
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 42/250
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4827
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 43/250
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4738
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 44/250
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4809
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 45/250
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4661
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 46/250
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4800
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 47/250
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4823
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 48/250
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4796
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 49/250
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4852
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 50/250
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4759
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 51/250
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4688
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 52/250
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4784
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 53/250
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4728
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 54/250
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4781
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 55/250
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4734
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 56/250
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4789
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 57/250
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4824
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 58/250
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4657
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 59/250
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4744
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 60/250
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4722
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 61/250
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4729
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 62/250
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4763
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 63/250
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4743
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 64/250
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4688
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 65/250
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4767
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 66/250
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4669
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 67/250
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4731
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 68/250
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4765
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 69/250
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4671
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 70/250
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4775
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 71/250
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4688
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 72/250
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4640
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 73/250
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4687
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 74/250
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4669
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 75/250
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4665
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 76/250
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4709
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 77/250
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4715
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 78/250
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4684
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 79/250
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4725
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 80/250
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4581
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 81/250
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4597
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 82/250
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4687
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 83/250
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4703
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 84/250
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4730
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 85/250
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4664
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 86/250
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4624
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 87/250
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4625
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 88/250
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4627
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 89/250
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4655
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 90/250
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4695
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 91/250
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4634
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 92/250
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4663
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 93/250
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4604
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 94/250
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4571
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 95/250
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4640
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 96/250
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4649
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 97/250
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4610
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 98/250
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4647
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 99/250
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4626
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 100/250
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4638
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 101/250
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4547
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 102/250
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4691
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 103/250
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4667
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 104/250
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4597
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 105/250
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4652
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 106/250
# 1/1 [==============================] - 0s 45ms/step - loss: 0.4646
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 107/250
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4689
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 108/250
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4643
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 109/250
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4622
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 110/250
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4560
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 111/250
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4644
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 112/250
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4507
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 113/250
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4639
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 114/250
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4553
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 115/250
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4439
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 116/250
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4518
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 117/250
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4550
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 118/250
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4581
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 119/250
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4611
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 120/250
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4613
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 121/250
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4538
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 122/250
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4678
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 123/250
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4625
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 124/250
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4633
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 125/250
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4566
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 126/250
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4660
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 127/250
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4559
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 128/250
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4559
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 129/250
# 1/1 [==============================] - 0s 47ms/step - loss: 0.4576
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 130/250
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4512
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 131/250
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4555
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 132/250
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4525
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 133/250
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4538
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 134/250
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4586
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 135/250
# 1/1 [==============================] - 0s 68ms/step - loss: 0.4577
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 136/250
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4528
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 137/250
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4594
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 138/250
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4485
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 139/250
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4500
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 140/250
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4596
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 141/250
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4579
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 142/250
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4597
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 143/250
# 1/1 [==============================] - 0s 44ms/step - loss: 0.4511
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 144/250
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4470
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 145/250
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4531
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 146/250
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4539
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 147/250
# 1/1 [==============================] - 0s 45ms/step - loss: 0.4543
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 148/250
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4420
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 149/250
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4501
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 150/250
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4545
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 151/250
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4482
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 152/250
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4547
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 153/250
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4498
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 154/250
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4538
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 155/250
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4490
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 156/250
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4420
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 157/250
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4525
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 158/250
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4547
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 159/250
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4477
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 160/250
# 1/1 [==============================] - 0s 47ms/step - loss: 0.4534
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 161/250
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4489
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 162/250
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4501
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 163/250
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4423
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 164/250
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4431
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 165/250
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4485
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 166/250
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4444
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 167/250
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4473
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 168/250
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4469
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 169/250
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4435
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 170/250
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4514
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 171/250
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4478
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 172/250
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4436
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 173/250
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4511
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 174/250
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4387
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 175/250
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4423
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 176/250
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4479
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 177/250
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4482
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 178/250
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4374
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 179/250
# 1/1 [==============================] - 0s 61ms/step - loss: 0.4362
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 180/250
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4449
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 181/250
# 1/1 [==============================] - 0s 45ms/step - loss: 0.4376
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 182/250
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4419
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 183/250
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4427
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 184/250
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4417
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 185/250
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4385
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 186/250
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4379
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 187/250
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4426
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 188/250
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4415
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 189/250
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4397
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 190/250
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4385
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 191/250
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4357
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 192/250
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4396
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 193/250
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4477
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 194/250
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4375
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 195/250
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4399
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 196/250
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4401
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 197/250
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4381
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 198/250
# 1/1 [==============================] - 0s 45ms/step - loss: 0.4379
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 199/250
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4468
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 200/250
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4399
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 201/250
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4377
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 202/250
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4329
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 203/250
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4388
# generated text:
# is a bus not a vehicle ? yes .
#
# Epoch 204/250
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4433
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 205/250
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4391
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 206/250
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4355
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 207/250
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4398
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 208/250
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4280
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 209/250
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4379
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 210/250
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4335
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 211/250
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4325
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 212/250
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4292
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 213/250
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4315
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 214/250
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4293
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 215/250
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4291
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 216/250
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4296
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 217/250
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4257
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 218/250
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4260
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 219/250
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4249
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 220/250
# 1/1 [==============================] - 0s 45ms/step - loss: 0.4258
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 221/250
# 1/1 [==============================] - 0s 45ms/step - loss: 0.4278
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 222/250
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4212
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 223/250
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4235
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 224/250
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4244
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 225/250
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4180
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 226/250
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4194
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 227/250
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4239
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 228/250
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4182
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 229/250
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4154
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 230/250
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4193
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 231/250
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4170
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 232/250
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4123
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 233/250
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4139
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 234/250
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4163
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 235/250
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4171
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 236/250
# 1/1 [==============================] - 0s 48ms/step - loss: 0.4137
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 237/250
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4161
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 238/250
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4167
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 239/250
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4136
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 240/250
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4207
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 241/250
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4097
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 242/250
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4035
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 243/250
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4205
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 244/250
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4048
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 245/250
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4110
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 246/250
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4132
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 247/250
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4066
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 248/250
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4145
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 249/250
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4119
# generated text:
# is a bus not a vehicle ? no .
#
# Epoch 250/250
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4114
# generated text:
# is a bus not a vehicle ? no .

# %%
text_gen_callback.yes_count, text_gen_callback.no_count
# Out:
# (334, 127)

# %%
generator = callback('is a crane a vehicle ?', model, 1)
output = generator.on_epoch_end(0)
# Out:
# generated text:
# is a crane a vehicle ? no .

# %%
text_model = tf.keras.Model(inputs=model.input, outputs=model.get_layer('text_output').output)
graph_model = tf.keras.Model(inputs=model.input, outputs=model.get_layer('graph_output').output)
text = 'is a bus not a vehicle ?'

# %%
generator = callback(text, text_model, 2)
output = generator.on_epoch_end(0)
# Out:
# generated text:
# is a bus not a vehicle ? no .

# %%
generator = callback(text, graph_model, 2)
output = generator.on_epoch_end(0)
# Out:
# generated text:
# is a bus not a vehicle ? yes . no . . a . . . . a

# %%
# generator = text_gen_callback

# %%
start_tokens, tokens_generated, num_tokens_generated, raw_output = generator.generate_token([_ for _ in generator.start_tokens], [])
index = len(generator.start_tokens) - 1
raw_output[0][index], tf.argmax(raw_output[0][index]), vocab[tf.argmax(raw_output[0][index])], tokens_generated, generator.get_text(tokens_generated)
# Out:
# (array([ 5.7866831e+00, -2.0338802e+00, -1.6425880e+00, -1.6415734e+00,
#         -2.9838140e+00, -3.9854555e+00, -4.0178022e+00,  4.4746957e+00,
#          6.8478107e+00, -3.6314170e+00,  5.8172221e+00,  4.7501721e+00,
#         -8.1377739e-01, -1.6922829e-01, -1.9731697e-01,  2.7875334e-01,
#         -2.3341317e-01, -7.2620934e-01,  6.0848343e-01, -3.4538954e-03,
#          1.5009746e-01, -5.4614103e-01, -2.3891037e+00, -3.2902513e+00,
#         -1.4027399e+00, -2.1484437e+00, -1.8320175e+00, -2.1038582e+00,
#         -4.2623277e+00, -2.8378265e+00], dtype=float32),
#  <tf.Tensor: shape=(), dtype=int64, numpy=8>,
#  'yes',
#  [<tf.Tensor: shape=(), dtype=int32, numpy=8>],
#  'is a bus not a vehicle ? yes')

# %%
generator.sample_from(raw_output[0][5])
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=6>

# %%
(-4.4723473e+00 + 5.749256)
# Out:
# 1.2769087

# %%
tf.argmax(raw_output[0][0]), vocab
# Out:
# (<tf.Tensor: shape=(), dtype=int64, numpy=2>,
#  ['',
#   '[UNK]',
#   'a',
#   'is',
#   '?',
#   '.',
#   'an',
#   'animal',
#   'yes',
#   'no',
#   'vehicle',
#   'truck',
#   'motorcycle',
#   'lion',
#   'crane',
#   'cat',
#   'car',
#   'bus',
#   'boar',
#   'bird',
#   'bear',
#   'ariplane',
#   'airplane'])

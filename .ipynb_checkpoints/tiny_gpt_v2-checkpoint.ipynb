# %%
# %matplotlib inline

import os

os.environ["KERAS_BACKEND"] = "tensorflow"

import tensorflow.keras as keras
from tensorflow.keras import layers
# from tensorflow.keras import ops
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization
import numpy as np
import os
import string
import random
import tensorflow as tf
import tensorflow.data as tf_data
import tensorflow.strings as tf_strings

from stellargraph.data import BiasedRandomWalk
from stellargraph import StellarGraph, IndexedArray
from gensim.models import Word2Vec
import pandas as pd
import matplotlib.pyplot as plt

from graph_visualization import GraphVisualization

print("Tensorflow verions:", tf.__version__)
print('Available GPUs:', tf.config.experimental.list_physical_devices('GPU'))
# Out:
# Tensorflow verions: 2.4.0
# Available GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
def causal_attention_mask(batch_size, n_dest, n_src, dtype):
    """
    Mask the upper half of the dot product matrix in self attention.
    This prevents flow of information from future tokens to current token.
    1's in the lower triangle, counting from the lower right corner.
    """
    i = tf.range(n_dest)[:, None]
    j = tf.range(n_src)
    m = i >= j - n_src + n_dest
    mask = tf.cast(m, dtype)
    mask = tf.reshape(mask, [1, n_dest, n_src])
    mult = tf.concat(
        [tf.expand_dims(batch_size, -1), tf.convert_to_tensor([1, 1])], 0
    )
    return tf.tile(mask, mult)


class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super().__init__()
        self.att = layers.MultiHeadAttention(num_heads, embed_dim)
        self.ffn = keras.Sequential(
            [
                layers.Dense(ff_dim, activation="relu"),
                layers.Dense(embed_dim),
            ]
        )
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)

    def call(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size = input_shape[0]
        seq_len = input_shape[1]
        causal_mask = causal_attention_mask(batch_size, seq_len, seq_len, "bool")
        attention_output = self.att(inputs, inputs, attention_mask=causal_mask)
        attention_output = self.dropout1(attention_output)
        out1 = self.layernorm1(inputs + attention_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output)
        return self.layernorm2(out1 + ffn_output)

# %%
vocab_size = 30  # Only consider the top 20k words
maxlen = 10  # Max sequence size
batch_size = 128

# The dataset contains each review in a separate text file
# The text files are present in four different folders
# Create a list all files
filenames = []
directories = [
    "gpt-dataset/custom-2"
]
for dir in directories:
    for f in os.listdir(dir):
        filenames.append(os.path.join(dir, f))

# filenames = filenames[:1000]

print(f"{len(filenames)} files")

# Create a dataset from text files
random.shuffle(filenames)
text_ds = tf_data.TextLineDataset(filenames)
text_ds = text_ds.shuffle(buffer_size=256)
text_ds = text_ds.batch(batch_size)


def custom_standardization(input_string):
    """Remove html line-break tags and handle punctuation"""
    lowercased = tf_strings.lower(input_string)
    stripped_html = tf_strings.regex_replace(lowercased, "<br />", " ")
    return tf_strings.regex_replace(stripped_html, f"([{string.punctuation}])", r" \1")


# Create a vectorization layer and adapt it to the text
vectorize_layer = TextVectorization(
    standardize=custom_standardization,
    max_tokens=vocab_size - 1,
    output_mode="int",
    output_sequence_length=maxlen + 1,
)
vectorize_layer.adapt(text_ds)
vocab = vectorize_layer.get_vocabulary()  # To get words back from token indices


def prepare_lm_inputs_labels(text):
    """
    Shift word sequences by 1 position so that the target for position (i) is
    word at position (i+1). The model will use all words up till position (i)
    to predict the next word.
    """
    text = tf.expand_dims(text, -1)
    tokenized_sentences = vectorize_layer(text)
    x = tokenized_sentences[:, :-1]
    y = tokenized_sentences[:, 1:]

    # zeros_column = tf.zeros_like(y[:, :1])  # Create a column of zeros with the same shape as the first column of y
    # y = tf.concat([zeros_column, y], axis=1)  # Concatenate the zeros column with y along the column axis
    
    print('x',x)
    print('y',y)
    return x, y

text_ds = text_ds.map(prepare_lm_inputs_labels, num_parallel_calls=tf_data.AUTOTUNE)
text_ds = text_ds.prefetch(tf_data.AUTOTUNE)
# Out:
# 22 files
# x Tensor("strided_slice:0", shape=(None, 10), dtype=int64)
# y Tensor("strided_slice_1:0", shape=(None, 10), dtype=int64)

# %%
list(text_ds.take(1))[0][1]
# Out:
# <tf.Tensor: shape=(22, 10), dtype=int64, numpy=
# array([[ 2, 18,  2, 10,  4,  9,  5,  0,  0,  0],
#        [ 2, 16,  2, 10,  4,  8,  5,  0,  0,  0],
#        [ 2, 11,  2, 10,  4,  8,  5,  0,  0,  0],
#        [ 2, 20,  6,  7,  4,  8,  5,  0,  0,  0],
#        [ 2, 20,  2, 10,  4,  9,  5,  0,  0,  0],
#        [ 2, 12,  2, 10,  4,  8,  5,  0,  0,  0],
#        [ 2, 15,  2, 10,  4,  9,  5,  0,  0,  0],
#        [ 2, 14,  6,  7,  4,  9,  5,  0,  0,  0],
#        [ 2, 19,  6,  7,  4,  8,  5,  0,  0,  0],
#        [ 2, 17,  2, 10,  4,  8,  5,  0,  0,  0],
#        [ 2, 13,  6,  7,  4,  8,  5,  0,  0,  0],
#        [ 2, 14,  6,  7,  4,  8,  5,  0,  0,  0],
#        [ 2, 19,  2, 10,  4,  9,  5,  0,  0,  0],
#        [ 2, 16,  6,  7,  4,  9,  5,  0,  0,  0],
#        [ 6, 22,  6,  7,  4,  9,  5,  0,  0,  0],
#        [ 2, 18,  6,  7,  4,  8,  5,  0,  0,  0],
#        [ 2, 17,  6,  7,  4,  9,  5,  0,  0,  0],
#        [ 2, 11,  6,  7,  4,  9,  5,  0,  0,  0],
#        [ 2, 13,  2, 10,  4,  9,  5,  0,  0,  0],
#        [ 2, 15,  6,  7,  4,  8,  5,  0,  0,  0],
#        [ 2, 12,  6,  7,  4,  9,  5,  0,  0,  0],
#        [ 6, 21,  2, 10,  4,  8,  5,  0,  0,  0]], dtype=int64)>

# %%
graph_embedding_size = 10

def node2vec(G):
        walk_length = 100
        rw = BiasedRandomWalk(G)
        walks = rw.run(
            nodes=G.nodes(),  # root nodes
            length=walk_length,  # maximum length of a random walk
            n=10,  # number of random walks per root node
            p=0.5,  # Defines (unormalised) probability, 1/p, of returning to source node
            q=2.0,  # Defines (unormalised) probability, 1/q, for moving away from source node
            weighted=False,  # for weighted random walks
            seed=42,  # random seed fixed for reproducibility
        )

        model = Word2Vec(
            walks,  vector_size=graph_embedding_size, window=5, min_count=0, sg=1, workers=1
        )

        return pd.DataFrame([(key, vector) for key,vector in zip(model.wv.index_to_key, model.wv.vectors)], columns=['node', 'embedding'])

    
def get_graph():
    nodes, edges, edge_types = [], [], []

    nodes.append('vehicle')
    nodes.append('animal')
    nodes.append('car')
    nodes.append('truck')
    nodes.append('airplane')
    nodes.append('motorcycle')
    nodes.append('bus')
    nodes.append('bird')
    nodes.append('cat')
    nodes.append('lion')
    nodes.append('bear')
    nodes.append('boar')
    nodes.append('crane')
    nodes.append('yes')
    nodes.append('no')

    edges.append({'source': 'car', 'target': 'vehicle'})
    edges.append({'source': 'truck', 'target': 'vehicle'})
    edges.append({'source': 'airplane', 'target': 'vehicle'})
    edges.append({'source': 'motorcycle', 'target': 'vehicle'})
    edges.append({'source': 'bus', 'target': 'vehicle'})
    edges.append({'source': 'bird', 'target': 'animal'})
    edges.append({'source': 'cat', 'target': 'animal'})
    edges.append({'source': 'lion', 'target': 'animal'})
    edges.append({'source': 'bear', 'target': 'animal'})
    edges.append({'source': 'boar', 'target': 'animal'})
    edges.append({'source': 'crane', 'target': 'animal'})

    for i in range(10):
        edge_types.append('is-a')
    
    return {'nodes':nodes, 'edges': edges, 'edge_types': edge_types}

def get_embeddings(graph):
    edges_ = pd.DataFrame({
            'source': [e['source'] for e in graph['edges']],
            'target': [e['target'] for e in graph['edges']]
        })
    
    G = StellarGraph(IndexedArray(index=graph['nodes']), edges_)

    node_embeddings = node2vec(G)
        
    return node_embeddings
    
graph = get_graph()
node_embeddings = get_embeddings(graph)

# node_embeddings = []
# node_embeddings.append([1,0])
# node_embeddings.append([0,1])
# node_embeddings.append([1,0])
# node_embeddings.append([1,0])
# node_embeddings.append([1,0])
# node_embeddings.append([1,0])
# node_embeddings.append([1,0])
# node_embeddings.append([0,1])
# node_embeddings.append([0,1])
# node_embeddings.append([0,1])
# node_embeddings.append([0,1])
# node_embeddings.append([0,1])

# graph_embedding_size = 1
# node_embeddings = []
# node_embeddings.append([1])
# node_embeddings.append([0])
# node_embeddings.append([1])
# node_embeddings.append([1])
# node_embeddings.append([1])
# node_embeddings.append([1])
# node_embeddings.append([1])
# node_embeddings.append([0])
# node_embeddings.append([0])
# node_embeddings.append([0])
# node_embeddings.append([0])
# node_embeddings.append([0])
# node_embeddings.append([0])
# node_embeddings.append([2])
# node_embeddings.append([3])

# node_embeddings = pd.DataFrame({'node': graph['nodes'], 'embedding': node_embeddings})

tmp = []
for i,word in enumerate(vocab):
    lower_nodes = list(map(lambda k: k.lower(), node_embeddings['node']))
    index = lower_nodes.index(word.lower()) if word.lower() in lower_nodes else -1
    if index != -1:
        tmp.append(node_embeddings.iloc[index][1])
    else:
        tmp.append(np.ones(graph_embedding_size) * -10)

# for row in node_embeddings.iterrows():
#     if row[0] not in vocab:
#         tmp.append(row[1])

node_embeddings = np.array(tmp).tolist()

# %%
vis = GraphVisualization()
for edge in graph['edges']:
    vis.addEdge(edge['source'], edge['target'])
vis.visualize()

# %%
[(word, emb) for word, emb in zip(vocab, node_embeddings)]
# Out:
# [('', [-10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0]),
#  ('[UNK]',
#   [-10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0]),
#  ('a', [-10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0]),
#  ('is',
#   [-10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0]),
#  ('?', [-10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0]),
#  ('.', [-10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0]),
#  ('an',
#   [-10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0]),
#  ('animal',
#   [-0.4163645803928375,
#    0.25741854310035706,
#    0.6086070537567139,
#    -0.1655154526233673,
#    0.49575382471084595,
#    -0.0455486997961998,
#    0.8012338876724243,
#    1.535124659538269,
#    -1.2733432054519653,
#    0.15829606354236603]),
#  ('yes',
#   [0.07898068428039551,
#    -0.06989505141973495,
#    -0.09155865013599396,
#    -0.003557539079338312,
#    -0.03099841997027397,
#    0.0789431557059288,
#    0.05938572809100151,
#    -0.015456628985702991,
#    0.015109634026885033,
#    0.01790039613842964]),
#  ('no',
#   [0.09964849799871445,
#    -0.04362444952130318,
#    -0.005993389990180731,
#    -0.05695638805627823,
#    0.03850822523236275,
#    0.027866268530488014,
#    0.06891076266765594,
#    0.06101095676422119,
#    0.09538495540618896,
#    0.09273417294025421]),
#  ('vehicle',
#   [-0.673417329788208,
#    0.621108889579773,
#    -1.477669596672058,
#    1.1198447942733765,
#    -0.13751181960105896,
#    -0.9517941474914551,
#    0.18184241652488708,
#    -0.07297198474407196,
#    -0.9946886301040649,
#    -0.2799529433250427]),
#  ('truck',
#   [-0.8390606641769409,
#    0.6792362928390503,
#    -1.4236546754837036,
#    1.0338952541351318,
#    -0.16072864830493927,
#    -0.9204615950584412,
#    0.1686880737543106,
#    -0.10161280632019043,
#    -0.8987261056900024,
#    -0.10375995188951492]),
#  ('motorcycle',
#   [-0.8417881727218628,
#    0.6363859176635742,
#    -1.2531112432479858,
#    1.0426559448242188,
#    0.0676538422703743,
#    -0.9518520832061768,
#    0.28269317746162415,
#    -0.2862682342529297,
#    -0.8624190092086792,
#    -0.04490533098578453]),
#  ('lion',
#   [-0.3477270007133484,
#    0.39744171500205994,
#    0.3377327024936676,
#    -0.3396866023540497,
#    0.9144899249076843,
#    0.13047930598258972,
#    0.643014669418335,
#    1.2276742458343506,
#    -1.3374791145324707,
#    0.23753014206886292]),
#  ('crane',
#   [-0.3483507037162781,
#    0.2395029366016388,
#    0.3043364882469177,
#    -0.23999635875225067,
#    0.7480108737945557,
#    0.15035800635814667,
#    0.755444347858429,
#    1.3578766584396362,
#    -1.2826980352401733,
#    0.19249960780143738]),
#  ('cat',
#   [-0.4280926585197449,
#    0.3673712909221649,
#    0.42536309361457825,
#    -0.4021379053592682,
#    0.7745717763900757,
#    0.06321951001882553,
#    0.8145873546600342,
#    1.2509005069732666,
#    -1.3421019315719604,
#    0.12260181456804276]),
#  ('car',
#   [-0.8969957232475281,
#    0.6955980658531189,
#    -1.3713165521621704,
#    1.1774033308029175,
#    -0.08867985755205154,
#    -1.0177403688430786,
#    0.17038355767726898,
#    -0.12511667609214783,
#    -0.8705814480781555,
#    -0.20742587745189667]),
#  ('bus',
#   [-0.832133948802948,
#    0.6834102869033813,
#    -1.2917578220367432,
#    1.1103907823562622,
#    -0.14158210158348083,
#    -0.8945633769035339,
#    0.24982547760009766,
#    -0.13953730463981628,
#    -0.9103589653968811,
#    -0.03860977664589882]),
#  ('boar',
#   [-0.36519327759742737,
#    0.3670116364955902,
#    0.335117369890213,
#    -0.38203293085098267,
#    0.8426183462142944,
#    0.07247920334339142,
#    0.624898374080658,
#    1.2479417324066162,
#    -1.3185786008834839,
#    0.2582140862941742]),
#  ('bird',
#   [-0.26250290870666504,
#    0.4215860366821289,
#    0.2793501913547516,
#    -0.39316025376319885,
#    0.7784706950187683,
#    0.10136925429105759,
#    0.775338351726532,
#    1.2714201211929321,
#    -1.2963846921920776,
#    0.0936598926782608]),
#  ('bear',
#   [-0.2576075494289398,
#    0.39335897564888,
#    0.3899523615837097,
#    -0.3167826235294342,
#    0.7865154147148132,
#    0.04976788908243179,
#    0.7193542122840881,
#    1.3212189674377441,
#    -1.3440319299697876,
#    0.11752346158027649]),
#  ('ariplane',
#   [-10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0]),
#  ('airplane',
#   [-0.9351227879524231,
#    0.7131163477897644,
#    -1.4391838312149048,
#    1.043919563293457,
#    -0.09149127453565598,
#    -0.9439460039138794,
#    0.13109345734119415,
#    -0.0412275604903698,
#    -0.8398430347442627,
#    -0.013850889168679714])]

# %%
class TokenAndPositionEmbedding(layers.Layer):
    def __init__(self, maxlen, vocab_size, embed_dim):
        super().__init__()
        self.token_emb = layers.Embedding(input_dim=vocab_size, output_dim=embed_dim)
        self.pos_emb = layers.Embedding(input_dim=maxlen, output_dim=embed_dim)

    def call(self, x):
        maxlen = tf.shape(x)[-1]  # Modified line
        positions = tf.range(0, maxlen, 1)  # Modified line
        positions = self.pos_emb(positions)
        x = self.token_emb(x)
        return x + positions

# %%
class NodeEmbedding(layers.Layer):
    def __init__(self, node_embed_dim, node_embeddings):
        super().__init__()
        self.node_embeddings = tf.constant(node_embeddings, dtype=tf.float32)
        self.node_embed_dim = node_embed_dim
        self.dense = layers.Dense(node_embed_dim)

    def call(self, x):
         # Reshape x to add a new dimension for embedding
        node_indices = tf.cast(tf.math.round(x), tf.int32)
        node_emb = tf.gather(self.node_embeddings, node_indices)
        node_emb = self.dense(node_emb)  # Apply dense layer to each token embedding
        return node_emb

# %%
class TextGenerator(tf.keras.callbacks.Callback):
    """A callback to generate text from a trained model.
    1. Feed some starting prompt to the model
    2. Predict probabilities for the next token
    3. Sample the next token and add it to the next input

    Arguments:
        max_tokens: Integer, the number of tokens to be generated after prompt.
        start_tokens: List of integers, the token indices for the starting prompt.
        index_to_word: List of strings, obtained from the TextVectorization layer.
        top_k: Integer, sample from the `top_k` token predictions.
        print_every: Integer, print after this many epochs.
    """

    def __init__(
        self, max_tokens, start_tokens, index_to_word, model = None, top_k=10, print_every=1
    ):
        self.max_tokens = max_tokens
        self.start_tokens = start_tokens
        self.index_to_word = index_to_word
        self.print_every = print_every
        self.k = top_k
        if model: self.model = model
        self.yes_count = 0
        self.no_count = 0
        self.activation_outputs = []
        self.gradients = []

    def sample_from(self, logits):
        logits, indices = tf.math.top_k(logits, k=self.k, sorted=True)
        indices = tf.convert_to_tensor(indices, dtype=tf.int32)
        preds = tf.keras.activations.softmax(tf.expand_dims(logits, 0))[0]
        preds = tf.convert_to_tensor(preds, dtype=tf.float32)
  
        # Reshape logits to a matrix
        logits_matrix = tf.reshape(logits, (1, -1))
   
        # Sample from the softmax probabilities
        sampled_index = tf.random.categorical(tf.math.log(preds)[tf.newaxis, :], num_samples=1)

        # Return the sampled index
        return indices[sampled_index[0, 0]]

    def detokenize(self, number):
        return self.index_to_word[number] if number < len(self.index_to_word) else '---'

    def generate_token(self, _start_tokens, tokens_generated):
        pad_len = maxlen - len(_start_tokens)
        sample_index = len(_start_tokens) - 1
        if pad_len < 0:
            x = _start_tokens[:maxlen]
            sample_index = maxlen - 1
        elif pad_len > 0:
            x = _start_tokens + [0] * pad_len
        else:
            x = _start_tokens
        x = np.array([x])
        y = self.model.predict(x, verbose=0)
        sample_token = self.sample_from(y[0][sample_index])
        tokens_generated.append(sample_token)
        _start_tokens.append(sample_token)
        num_tokens_generated = len(tokens_generated)

        return _start_tokens, tokens_generated, num_tokens_generated, y

    def get_generated_text(self, tokens_generated):
        return " ".join(
            [self.detokenize(_) for _ in tokens_generated])
        
    def get_text(self, tokens_generated):
        return " ".join(
            [self.detokenize(_) for _ in self.start_tokens + tokens_generated])
        
    def on_epoch_end(self, epoch, logs=None):
        _start_tokens = [_ for _ in self.start_tokens]
        if (epoch + 1) % self.print_every != 0:
            return
        num_tokens_generated = 0
        tokens_generated = []
        raw_outputs = []
        while num_tokens_generated <= self.max_tokens:
            _start_tokens, tokens_generated, num_tokens_generated, raw_output = self.generate_token(_start_tokens, tokens_generated)
            raw_outputs.append(raw_output)
            
        txt = self.get_text(tokens_generated)
        print(f"generated text:\n{txt}\n")

        self.yes_count += 1 if 'yes' in txt else 0
        self.no_count += 1 if 'no' in txt else 0

        return txt, raw_outputs
    
    def generate(self):
        return self.on_epoc_end(1)

# Tokenize starting prompt
word_to_index = {}
for index, word in enumerate(vocab):
    word_to_index[word] = index

def callback(start_prompt, model=None, top_k=10):
    start_tokens = [word_to_index.get(_, 1) for _ in start_prompt.split()]
    num_tokens_generated = 10
    return TextGenerator(num_tokens_generated, start_tokens, vocab, top_k=top_k) if not model else TextGenerator(num_tokens_generated, start_tokens, vocab, model, top_k)

# %%
embed_dim = 128  # Embedding size for each token
num_heads = 2  # Number of attention heads
feed_forward_dim = 128  # Hidden layer size in feed forward network inside transformer

def create_model():
    inputs = layers.Input(shape=(maxlen,), dtype="float32")
    
    embedding_layer = TokenAndPositionEmbedding(maxlen, vocab_size, embed_dim)
    x = embedding_layer(inputs)
    transformer_block = TransformerBlock(embed_dim, num_heads, feed_forward_dim)
    x = transformer_block(x)

    outputs_1 = layers.Dense(vocab_size, name='text_output')(x)

    node_embedding_layer = NodeEmbedding(embed_dim, node_embeddings)
    x2 = node_embedding_layer(inputs)
    transformer_block = TransformerBlock(embed_dim, num_heads, feed_forward_dim)
    x2 = transformer_block(x2)

    outputs_2 = layers.Dense(vocab_size, name='graph_output')(x2)

    # Concatenate outputs of both branches
    outputs = layers.Average()([outputs_1, outputs_2])

    # outputs = outputs_2

    # Softmax layer
    # softmax_output = layers.Softmax()(outputs)
    
    model = tf.keras.Model(inputs=inputs, outputs=[outputs])
    loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
    model.compile(
        optimizer='adam',
        loss=[loss_fn, None],
    )  # No loss and optimization based on word embeddings from transformer block
    return model

# %%
model = create_model()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 10)]         0
# __________________________________________________________________________________________________
# token_and_position_embedding (T (None, 10, 128)      5120        input_1[0][0]
# __________________________________________________________________________________________________
# node_embedding (NodeEmbedding)  (None, 10, 128)      1408        input_1[0][0]
# __________________________________________________________________________________________________
# transformer_block (TransformerB (None, 10, 128)      165504      token_and_position_embedding[0][0
# __________________________________________________________________________________________________
# transformer_block_1 (Transforme (None, 10, 128)      165504      node_embedding[0][0]
# __________________________________________________________________________________________________
# text_output (Dense)             (None, 10, 30)       3870        transformer_block[0][0]
# __________________________________________________________________________________________________
# graph_output (Dense)            (None, 10, 30)       3870        transformer_block_1[0][0]
# __________________________________________________________________________________________________
# average (Average)               (None, 10, 30)       0           text_output[0][0]
#                                                                  graph_output[0][0]
# ==================================================================================================
# Total params: 345,276
# Trainable params: 345,276
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
text_gen_callback = callback("is a bus a vehicle ?", model, top_k=1)

# %%
history = model.fit(text_ds, verbose=1, epochs=200, callbacks=[text_gen_callback])
# Out:
# Epoch 1/200
# 1/1 [==============================] - 3s 3s/step - loss: 3.7888
# generated text:
# is a bus a vehicle ? . .  .
#
# Epoch 2/200
# 1/1 [==============================] - 0s 30ms/step - loss: 2.4417
# generated text:
# is a bus a vehicle ?  .
#
# Epoch 3/200
# 1/1 [==============================] - 0s 28ms/step - loss: 1.8184
# generated text:
# is a bus a vehicle ?
#
# Epoch 4/200
# 1/1 [==============================] - 0s 29ms/step - loss: 1.4812
# generated text:
# is a bus a vehicle ?
#
# Epoch 5/200
# 1/1 [==============================] - 0s 32ms/step - loss: 1.2423
# generated text:
# is a bus a vehicle ?
#
# Epoch 6/200
# 1/1 [==============================] - 0s 33ms/step - loss: 1.0312
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 7/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.9072
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 8/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.8189
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 9/200
# 1/1 [==============================] - 0s 35ms/step - loss: 0.7569
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 10/200
# 1/1 [==============================] - 0s 32ms/step - loss: 0.6964
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 11/200
# 1/1 [==============================] - 0s 35ms/step - loss: 0.6225
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 12/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.5894
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 13/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.5784
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 14/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.5283
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 15/200
# 1/1 [==============================] - 0s 34ms/step - loss: 0.5232
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 16/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.5052
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 17/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4870
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 18/200
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4752
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 19/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4668
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 20/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4580
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 21/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4595
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 22/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4446
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 23/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4368
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 24/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4239
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 25/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4184
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 26/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4229
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 27/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4269
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 28/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4276
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 29/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4230
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 30/200
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4064
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 31/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4118
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 32/200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4150
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 33/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4002
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 34/200
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4118
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 35/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4006
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 36/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4029
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 37/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4149
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 38/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4077
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 39/200
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3909
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 40/200
# 1/1 [==============================] - 0s 33ms/step - loss: 0.3901
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 41/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4060
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 42/200
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4023
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 43/200
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4043
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 44/200
# 1/1 [==============================] - 0s 32ms/step - loss: 0.3977
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 45/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3984
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 46/200
# 1/1 [==============================] - 0s 32ms/step - loss: 0.3982
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 47/200
# 1/1 [==============================] - 0s 32ms/step - loss: 0.3986
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 48/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3850
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 49/200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3927
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 50/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3971
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 51/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3894
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 52/200
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3922
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 53/200
# 1/1 [==============================] - 0s 32ms/step - loss: 0.3951
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 54/200
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3862
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 55/200
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3917
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 56/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3835
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 57/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3911
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 58/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3823
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 59/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3941
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 60/200
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3772
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 61/200
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3834
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 62/200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3971
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 63/200
# 1/1 [==============================] - 0s 33ms/step - loss: 0.3930
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 64/200
# 1/1 [==============================] - 0s 33ms/step - loss: 0.3841
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 65/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3821
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 66/200
# 1/1 [==============================] - 0s 33ms/step - loss: 0.3844
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 67/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4006
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 68/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3909
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 69/200
# 1/1 [==============================] - 0s 32ms/step - loss: 0.3796
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 70/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3920
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 71/200
# 1/1 [==============================] - 0s 33ms/step - loss: 0.3825
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 72/200
# 1/1 [==============================] - 0s 32ms/step - loss: 0.3912
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 73/200
# 1/1 [==============================] - 0s 32ms/step - loss: 0.3882
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 74/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3893
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 75/200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3864
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 76/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3844
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 77/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3747
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 78/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3827
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 79/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3744
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 80/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3743
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 81/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3880
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 82/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3904
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 83/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3922
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 84/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3929
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 85/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3894
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 86/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.3713
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 87/200
# 1/1 [==============================] - 0s 33ms/step - loss: 0.3754
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 88/200
# 1/1 [==============================] - 0s 34ms/step - loss: 0.3787
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 89/200
# 1/1 [==============================] - 0s 32ms/step - loss: 0.3806
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 90/200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3868
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 91/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3915
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 92/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3777
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 93/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3800
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 94/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3781
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 95/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3770
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 96/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3864
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 97/200
# 1/1 [==============================] - 0s 34ms/step - loss: 0.3893
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 98/200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3852
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 99/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3866
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 100/200
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3867
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 101/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3801
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 102/200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3805
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 103/200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3742
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 104/200
# 1/1 [==============================] - 0s 32ms/step - loss: 0.3631
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 105/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3774
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 106/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3791
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 107/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3714
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 108/200
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3799
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 109/200
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3771
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 110/200
# 1/1 [==============================] - 0s 34ms/step - loss: 0.3823
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 111/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3946
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 112/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3812
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 113/200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3819
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 114/200
# 1/1 [==============================] - 0s 35ms/step - loss: 0.3766
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 115/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.3813
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 116/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3659
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 117/200
# 1/1 [==============================] - 0s 32ms/step - loss: 0.3734
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 118/200
# 1/1 [==============================] - 0s 32ms/step - loss: 0.3751
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 119/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3769
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 120/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3805
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 121/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3794
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 122/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.3747
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 123/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3728
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 124/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3754
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 125/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3796
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 126/200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3761
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 127/200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3828
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 128/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3708
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 129/200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3802
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 130/200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3719
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 131/200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3744
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 132/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3742
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 133/200
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3656
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 134/200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3722
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 135/200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3776
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 136/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3796
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 137/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3769
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 138/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3728
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 139/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3801
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 140/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3738
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 141/200
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3733
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 142/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3729
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 143/200
# 1/1 [==============================] - 0s 35ms/step - loss: 0.3753
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 144/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3573
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 145/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3792
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 146/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3793
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 147/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3741
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 148/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3747
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 149/200
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3790
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 150/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.3733
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 151/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3655
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 152/200
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3705
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 153/200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3587
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 154/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3601
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 155/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3749
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 156/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3815
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 157/200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3601
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 158/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3621
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 159/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3617
# generated text:
# is a bus a vehicle ? no .
#
# Epoch 160/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3656
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 161/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3691
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 162/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.3672
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 163/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3608
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 164/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3569
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 165/200
# 1/1 [==============================] - 0s 34ms/step - loss: 0.3626
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 166/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3489
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 167/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3590
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 168/200
# 1/1 [==============================] - 0s 32ms/step - loss: 0.3591
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 169/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3659
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 170/200
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3597
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 171/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3677
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 172/200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3596
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 173/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3593
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 174/200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3607
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 175/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3404
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 176/200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3392
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 177/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.3350
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 178/200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3435
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 179/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3547
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 180/200
# 1/1 [==============================] - 0s 32ms/step - loss: 0.3366
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 181/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3365
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 182/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3322
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 183/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3450
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 184/200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3343
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 185/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3384
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 186/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3249
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 187/200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3326
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 188/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3280
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 189/200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3368
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 190/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3234
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 191/200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3191
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 192/200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3100
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 193/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3201
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 194/200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3261
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 195/200
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3225
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 196/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3271
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 197/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3277
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 198/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3281
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 199/200
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3225
# generated text:
# is a bus a vehicle ? yes .
#
# Epoch 200/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3121
# generated text:
# is a bus a vehicle ? yes .

# %%
text_gen_callback.yes_count, text_gen_callback.no_count
# Out:
# (334, 127)

# %%
generator = callback('is a crane a vehicle ?', model, 1)
output = generator.on_epoch_end(0)
# Out:
# generated text:
# is a crane a vehicle ? no .

# %%
text_model = tf.keras.Model(inputs=model.input, outputs=model.get_layer('text_output').output)
graph_model = tf.keras.Model(inputs=model.input, outputs=model.get_layer('graph_output').output)
text = 'is a bus a vehicle ?'

# %%
generator = callback(text, text_model, 2)
output = generator.on_epoch_end(0)
# Out:
# generated text:
# is a bird a vehicle ? no .

# %%
generator = callback(text, graph_model, 2)
output = generator.on_epoch_end(0)
# Out:
# generated text:
# is a bus a vehicle ? yes . yes . yes yes yes yes  yes

# %%
generator = text_gen_callback

# %%
start_tokens, tokens_generated, num_tokens_generated, raw_output = generator.generate_token([_ for _ in generator.start_tokens], [])
index = len(generator.start_tokens) - 1
raw_output[0][index], tf.argmax(raw_output[0][index]), vocab[tf.argmax(raw_output[0][index])], tokens_generated, generator.get_text(tokens_generated)
# Out:
# (array([ 2.0955372 , -3.0209532 ,  2.682182  , -2.9715679 , -0.23640561,
#         -1.074734  ,  2.193915  ,  1.5707725 ,  7.677234  , -4.475061  ,
#          0.8244264 ,  0.42647576,  0.671003  ,  0.28879926,  1.978322  ,
#          1.0849502 ,  0.3982529 ,  1.6951898 ,  1.8205662 , -0.40323466,
#          0.49655104, -1.1897178 , -0.34702656, -5.505645  , -3.9477236 ,
#         -2.230582  , -1.7991381 , -5.3626685 , -4.0121093 , -1.3468823 ],
#        dtype=float32),
#  <tf.Tensor: shape=(), dtype=int64, numpy=8>,
#  'yes',
#  [<tf.Tensor: shape=(), dtype=int32, numpy=8>],
#  'is a bus a vehicle ? yes')

# %%
generator.sample_from(raw_output[0][5])
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=6>

# %%
(-4.4723473e+00 + 5.749256)
# Out:
# 1.2769087

# %%
tf.argmax(raw_output[0][0]), vocab
# Out:
# (<tf.Tensor: shape=(), dtype=int64, numpy=2>,
#  ['',
#   '[UNK]',
#   'a',
#   'is',
#   '?',
#   '.',
#   'an',
#   'animal',
#   'yes',
#   'no',
#   'vehicle',
#   'truck',
#   'motorcycle',
#   'lion',
#   'crane',
#   'cat',
#   'car',
#   'bus',
#   'boar',
#   'bird',
#   'bear',
#   'ariplane',
#   'airplane'])

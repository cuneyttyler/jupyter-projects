# %%
from __future__ import print_function

import tensorflow as tf

import os
import sys
import numpy as np
import pickle5 as pickle
import tempfile

import keras
from keras.preprocessing.text import Tokenizer
import keras.backend as K
from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from keras.layers import Dense, Input, Embedding, Activation, Softmax
from keras.layers import CuDNNLSTM
from keras.models import Model, Sequential
from keras.layers import Conv1D,Conv2D, ZeroPadding2D, MaxPooling1D, MaxPooling2D
from keras.layers import RepeatVector, Permute, Add, Concatenate, Reshape, Dot
from tensorflow.keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint

from stellargraph.data import BiasedRandomWalk
from stellargraph import StellarGraph, IndexedArray
from gensim.models import Word2Vec
import pandas as pd

from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import matplotlib.pyplot as plt

np.random.seed(100)

BASE_DIR = '.'
GLOVE_DIR = '/media/drived/Dev/Glove'
# TEXT_DATA_DIR = os.path.join(BASE_DIR, '20_newsgroup')
DATA_DIR = "/home/bhargav/nlu_project/keras_n20/data/Es_Rc"
DOC_PKL = "document_list.pick"
TARGET_PKL = "target_list.pick"

OUTPUT_PATH = './learning_beyond_datasets/node2vec/lstm_and_kg/'

MAX_SEQUENCE_LENGTH = 300
MAX_NUM_WORDS = 20000
VALIDATION_SPLIT = 0.1
TEST_SPLIT = 0.2

NUM_RELATIONS_PER_CLUSTER = 67
NUM_ENTITIES_PER_CLUSTER = 400
NUM_CLUSTERS = 20

EMBEDDING_DIM = 300

def get_clusters(cluster_file, num_things_per_cluster):
    clusters = []  # np.ones(shape=(NUM_RELATIONS_PER_CLUSTER,KG_EMBEDDING_DIM))

    with open(cluster_file, 'r', encoding='utf8') as f:
        lines = []
        for line in f:
            elements = line.split()
            x = [[e] for e in elements]
            lines.append(x)

    for i in range(0, len(lines) - num_things_per_cluster + 1, num_things_per_cluster):
        # print("appending: {} to {}".format(i,i+num_things_per_cluster))
        clusters.append(lines[i:i + num_things_per_cluster])

    clusters = np.asarray(clusters, dtype='float32')
    return clusters


def pickler(path, pkl_name, obj):
    with open(os.path.join(path, pkl_name), 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)


def unpickler(path, pkl_name):
    with open(os.path.join(path, pkl_name), 'rb') as f:
        obj = pickle.load(f)
    return obj

def get_labels(data):
    labels = []
    for d in data:
        labels.append(d['label']) if d['label'] not in labels else None

    return labels


def get_x_and_y(data):
    x, y = [], []
    for d in data:
        for dd in d['data']:
            tmp = dd['text'].replace('\n', '').replace('_', '')  # clean
            x.append({'label': d['label'], 'dbpedia_uri': dd['dbpedia_uri'], 'text': tmp, 'graph': dd['graph']}) if len(tmp) > 0 else None
            y.append(d['label']) if len(tmp) > 0 else None

    return x, y


def get_label_index(label):
    return [index for index, _label in enumerate(unique_labels) if label == _label][0]

# %% [markdown]
# ### LOAD DATA

# %%
texts = []  # list of text samples
labels_index = {}  # dictionary mapping label name to numeric id
labels = []  # list of label ids

with open(r'data/classification_data_with_graphs_v2.pkl', 'rb') as pickle_file:
    data = pickle.load(pickle_file)

# raw_docs = unpickler(DATA_DIR, DOC_PKL)
# labels = unpickler(DATA_DIR, TARGET_PKL)

unique_labels = get_labels(data)

x, y = get_x_and_y(data)
raw_docs = [d['text'] for d in x]
labels = [get_label_index(label) for label in y]

for doc in raw_docs:
    texts.append(" ".join(doc.split()[:MAX_SEQUENCE_LENGTH]))

print('Found %s texts.' % len(texts))
# Out:
# Found 6716 texts.

# %% [markdown]
# ### GET NODE2VEC CLUSTERS

# %%
graph_embedding_size=100

def get_embedding(G):
        walk_length = 100
        rw = BiasedRandomWalk(G)
        walks = rw.run(
            nodes=G.nodes(),  # root nodes
            length=walk_length,  # maximum length of a random walk
            n=10,  # number of random walks per root node
            p=0.5,  # Defines (unormalised) probability, 1/p, of returning to source node
            q=2.0,  # Defines (unormalised) probability, 1/q, for moving away from source node
            weighted=False,  # for weighted random walks
            seed=42,  # random seed fixed for reproducibility
        )

        model = Word2Vec(
            walks,  vector_size=graph_embedding_size, window=5, min_count=0, sg=1, workers=1
        )

        return model.wv.vectors
    
def get_graph():
    nodes, edges, edge_types = [], [], []
    for i1,d in enumerate(x):
        print('%.2f%%' % ((i1 * 100) / len(x))) if i1 % 100 == 0 else None
        g = d['graph']
        for node in g['nodes']:
            nodes.append(node) if not node in nodes else None

        for i, edge in enumerate(g['edges']):
            if not any(e['source'] == edge['source'] and e['target'] == edge['target'] for e in edges):
                edges.append({'source': edge['source'], 'target': edge['target']})
                edge_types.append(g['edge_types'][i])
    
    
    with open('graph.pkl', 'wb') as outp:
        pickle.dump({'nodes': nodes, 'edges': edges, 'edge_types': edge_types}, outp, pickle.HIGHEST_PROTOCOL)
        
    return {'nodes':nodes, 'edges': edges, 'edge_types': edge_types}

def get_embeddings():
    # graph = get_graph()
    graph = unpickler('.','graph.pkl')

    edges_ = pd.DataFrame({
            'source': [e['source'] for e in graph['edges']],
            'target': [e['target'] for e in graph['edges']],
            'type': graph['edge_types']
        })
    
    G = StellarGraph(IndexedArray(index=graph['nodes']), edges_, edge_type_column="type")

    node_embeddings = get_embedding(G)
    
    with open('node_embeddings_v3.pkl', 'wb') as outp:
        pickle.dump(node_embeddings, outp, pickle.HIGHEST_PROTOCOL)
        
    return node_embeddings, graph

# %%
with open(r'data/node_embeddings_v3.pkl', 'rb') as pickle_file:
    node_embeddings = pickle.load(pickle_file)
with open(r'data/graph.pkl', 'rb') as pickle_file:
    graph = pickle.load(pickle_file)
    
# node_embeddings, graph = get_embeddings()

# %%
# print(f'Node count: {node_count}, Edge count: {edge_count}')

# %%
any('Guernica' in g for g in graph['nodes'])
# Out:
# False

# %% [markdown]
# ### CLUSTER NODE EMBEDDINGS

# %%
# from k_means_constrained import KMeansConstrained
# import math
# NUM_CLUSTERS = min(NUM_CLUSTERS,int(len(node_embeddings)/NUM_ENTITIES_PER_CLUSTER))
# NUM_ENTITIES_PER_CLUSTER = math.ceil(len(node_embeddings) / NUM_CLUSTERS)

# print(f'Num of clusters: {NUM_CLUSTERS}, Num entities per cluster: {NUM_ENTITIES_PER_CLUSTER}')
# def cluster():
#     clf = KMeansConstrained(
#          n_clusters=NUM_CLUSTERS,
#          size_min=NUM_ENTITIES_PER_CLUSTER / 2,
#          size_max=NUM_ENTITIES_PER_CLUSTER,
#          random_state=0
#     )
#     clf.fit_predict(node_embeddings)
#     print(clf.cluster_centers_)
#     print(clf.labels_)
    
#     pickler('.','clusters_object_v3.pkl',clf)
    
#     return clf

# %%
# clf = unpickler('.','clusters_object.pkl')
# clf = cluster()

# %%
from sklearn.cluster import KMeans
def cluster():
    kmeans = KMeans(n_clusters=NUM_CLUSTERS, random_state=0).fit(node_embeddings)

    num = np.zeros(NUM_CLUSTERS)
    for i in range(NUM_CLUSTERS):
        n = np.where(kmeans.labels_==i)[0]
        num[i]=len(n)
    
    NUM_ENTITIES_PER_CLUSTER = int(np.min(num))
    print('NUM_ENTITIES_PER_CLUSTER: %d' % NUM_ENTITIES_PER_CLUSTER)
    
    pickler('.','clusters_object_v3.pkl',kmeans)
    pickler('.','num_entities_per_cluster_v3.pkl', NUM_ENTITIES_PER_CLUSTER)

    return kmeans, int(NUM_ENTITIES_PER_CLUSTER)

# %%
clf = unpickler('data','clusters_object_v3.pkl')
NUM_ENTITIES_PER_CLUSTER = unpickler('data','num_entities_per_cluster_v3.pkl')
# clf,NUM_ENTITIES_PER_CLUSTER = cluster()

# %%
clusters_dict = {}

for i in clf.labels_:
    indexes = np.where(clf.labels_==i)[0]
    clusters_dict[i] = node_embeddings[indexes[:NUM_ENTITIES_PER_CLUSTER]]

# %%
# pad clusters
embedding_clusters_2d,embedding_clusters_1d = [],[]
for key in range(NUM_CLUSTERS):
    if len(clusters_dict[key]) < NUM_ENTITIES_PER_CLUSTER:
        clusters_dict[key] = np.append(clusters_dict[key],[[0] * graph_embedding_size for i in range(0,NUM_ENTITIES_PER_CLUSTER - len(clusters_dict[key]))],axis=0)

    new_vecs_2d, new_vecs_1d = [], []
    for vec in clusters_dict[key]:
        new_vecs_2d.append([[val] for val in vec])
        new_vecs_1d.append(vec)
    
    embedding_clusters_2d.append(new_vecs_2d)
    embedding_clusters_1d.append(new_vecs_1d)
    
embedding_clusters_2d = np.asarray(embedding_clusters_2d, dtype='float32')
embedding_clusters_1d = np.asarray(embedding_clusters_1d, dtype='float32')

# %% [markdown]
# ### ANALYSE GRAPH VECTORS

# %%
from numpy.linalg import norm

def get_similarity(cluster):
    sums, c, avg = 0, 0, 0
    for i1 in range(0,len(cluster)):
        A = cluster[i1]
        for i2 in range(i1,len(cluster)):
            B = cluster[i2]
            if norm(A) == 0 or norm(B) == 0: continue
            cosine = np.dot(A,B)/(norm(A)*norm(B))
            sums += cosine
            c += 1

    return sums / c

def get_similarity_v2(cluster,i3):
    i3 += 1
    sums, c, avg = 0, 0, 0
    for i1 in range(0,len(cluster)):
        A = [val[0] for val in cluster[i1]]
        for i2 in range(i1,len(cluster)):
            B = [val[0] for val in cluster[i2]]
            if norm(A) == 0 or norm(B) == 0: continue
            cosine = np.dot(A,B)/(norm(A)*norm(B))
            sums += cosine
            c += 1

    return sums / c

# avg in-cluster similarity
# sum([get_similarity(clusters_dict[i]) for i in clusters_dict]) / len(clusters_dict)#, sum([get_similarity_v2(c,i) for i,c in enumerate(embedding_clusters_2d)]) / len(embedding_clusters_2d)

# %%
# Random Similarity
import random

def random_similarity():
    avg = 0
    for i in range(200):
        index1,index2 = random.randint(0,len(clusters_dict) - 1), random.randint(0,len(clusters_dict[0]) - 1)
        index3,index4 = random.randint(0,len(clusters_dict) - 1), random.randint(0,len(clusters_dict[0]) - 1)
        # print(f'({index1},{index2}) - ({index3},{index4})')
        A = clusters_dict[index1][index2]
        B = clusters_dict[index3][index4]
        lenA = len([v for v in A if v != 0])
        lenB = len([v for v in B if v != 0])
        # print('%d %d' % (lenA, lenB))

        sim = np.dot(A,B)/(norm(A)*norm(B))
        avg += sim

    return avg / 200

# %%
import random

def cosine_sim(i1,i2):
    A = node_embeddings[i1]
    B = node_embeddings[i2]
    return np.dot(A,B)/(norm(A)*norm(B))

def node_index(name):
    i = [i for i,node in enumerate(graph['nodes']) if node == name]
    if len(i) == 0: return None
    return i[0]

def to_name(uri):
    return uri.replace('http://dbpedia.org/resource/','').replace('_',' ')

def topic_similarity():
    topic = [xx for xx in x if xx['label'] == 'Culture']

    sims, c = 0, 0
    for i1, node in enumerate(topic):
        for i2 in range(i1,len(topic)):
            node1, node2 = topic[i1],topic[i2]
            if len(node1['graph']['nodes']) == 0 or len(node2['graph']['nodes']) == 0: continue
            sims += cosine_sim(node_index(to_name(node1['dbpedia_uri'])),node_index(to_name(node2['dbpedia_uri'])))
            c += 1

    return sims / c

def intra_topic_similarity():
    topic1 = [xx for xx in x if xx['label'] == 'Science-Biology']
    topic2 = [xx for xx in x if xx['label'] == 'Culture']

    sims, c = 0, 0
    for i1, node in enumerate(topic1):
        for i2 in range(len(topic2)):
            node1, node2 = topic1[i1],topic2[i2]
            if len(node1['graph']['nodes']) == 0 or len(node2['graph']['nodes']) == 0: continue
            sims += cosine_sim(node_index(to_name(node1['dbpedia_uri'])),node_index(to_name(node2['dbpedia_uri'])))
            c += 1

    return sims / c

def random_topic_similarity():
    topic1 = [xx for xx in x if xx['label'] == 'Science-Biology']
    topic2 = [xx for xx in x if xx['label'] == 'Military-Aviation']
    
    i1,i2 = random.randint(0,len(topic1) - 1), random.randint(0,len(topic2[0]) - 1)

    node1, node2 = topic1[i1],topic2[i2]
    print(i1,node1['dbpedia_uri'],i2,node2['dbpedia_uri'])
    
    if len(node1['graph']['nodes']) == 0 or len(node2['graph']['nodes']) == 0: return None
    
    return cosine_sim(node_index(to_name(node1['dbpedia_uri'])),node_index(to_name(node2['dbpedia_uri'])))

# topic_similarity()

# %%
def second_order_class_sim_topic():
    topic1 = [xx for xx in x if xx['label'] == 'Philosophy']

    sims, sims_random,c = 0, 0, 0 
    for i1, node in enumerate(topic1):
        # 
        if len(node['graph']['nodes']) == 0: continue
        sims_random += cosine_sim(random.randint(0,len(node_embeddings) - 1),node_index(to_name(node['dbpedia_uri'])))
        sims += cosine_sim(node_index('Second-order Class'),node_index(to_name(node['dbpedia_uri'])))
        
        c += 1
    
    return sims/c, sims_random/c

# second_order_class_sim_topic()

# %%
def second_order_class_sim():
    topic1 = [xx for xx in x if xx['label'] == 'Science-Biology']
    i1 = random.randint(0,len(topic1) - 1)
    
    node1 = topic1[i1]
    print(i1,node1['dbpedia_uri'])
    
    if len(node1['graph']['nodes']) == 0: return None

    return cosine_sim(node_index('Second-order Class'),node_index(to_name(node1['dbpedia_uri'])))

# second_order_class_sim()

# %%
from sklearn.manifold import TSNE
from sklearn.manifold import TSNE

# Apply t-SNE transformation on node embeddings
tsne = TSNE(n_components=2, random_state=42)

def plot_embeddings(emb):
    # draw the points
    alpha = 0.7

    plt.figure(figsize=(10, 8))
    plt.scatter(
        emb[:, 0],
        emb[:, 1],
        # c=node_targets.cat.codes,
        cmap="jet",
        alpha=0.7,
    )
    plt.show()

# %%
node_embeddings_2d = tsne.fit_transform(node_embeddings[:10000])

# %%
plot_embeddings(node_embeddings_2d)

# %%
clstr_0_1_2d = tsne.fit_transform(clusters_dict[0] + clusters_dict[1])

# %%
plot_embeddings(clstr_0_1_2d)

# %%
clstr_2d = tsne.fit_transform(clusters_dict[19] )

# %%
show_embedding_plot(clusters_dict[1])

# %%
plot_embeddings(np.asarray([[10,20],[50,60],[100,60]]))

# %%
plot_embeddings(node_embeddings[:1])

# %%
plot_embeddings(node_embeddings_2d[:1])

# %%
def plot_topic(topic_name):
    topic = [xx for xx in x if xx['label'] == topic_name]

    embeddings = []
    for i1, node in enumerate(topic):
        emb = node_embeddings[node_index(to_name(node['dbpedia_uri']))]
        if len(emb) != 100: continue
        embeddings.append(emb)

    embeddings_2d = tsne.fit_transform(embeddings)
    plot_embeddings(embeddings_2d)
    
plot_topic('Science-Biology')

# %%
A,B = clusters_dict[19][169], clusters_dict[19][170]
np.dot(A,B)/(norm(A)*norm(B))
# Out:
# 0.73899245

# %%
tmp = tsne.fit_transform([clusters_dict[19][169], clusters_dict[19][170],clusters_dict[19][175]])
tmp
# Out:
# array([[ -18.833384, -276.80054 ],
#        [-210.60179 ,  143.00536 ],
#        [-478.27985 , -232.9741  ]], dtype=float32)

# %%
plot_embeddings(np.asarray([clusters_dict[19][169], clusters_dict[19][170],clusters_dict[19][175]]))

# %%
v = [np.arange(100,100 + 100 * i,i) for i in range(1,101)]
mu, sigma = 0, 0.5
v = [np.random.normal(mu,sigma,100) for i in range(100)]
v_2d = tsne.fit_transform(v)
# plot_embeddings(np.asarray([clstr_2d[]]))
# for i, v in enumerate(clstr_2d):
#     print(i, v)
plot_embeddings(np.asarray(v_2d))

# %%
topic = [xx for xx in x if xx['label'] == 'Culture']

embeddings = []
for i1, node in enumerate(topic):
    embeddings.append(node_embeddings[node_index(to_name(node['dbpedia_uri']))])

len(embeddings[40])
# Out:
# 100

# %%
node_embeddings[node_index(to_name('http://dbpedia.org/resource/OpenWorm'))]
# Out:
# array([ 3.10337961e-01, -4.78675812e-02, -6.10486895e-04, -5.64123541e-02,
#        -1.79537952e-01,  3.86724360e-02,  1.17867261e-01, -9.98277962e-02,
#        -1.93168864e-01, -1.45029142e-01,  2.80993193e-01, -1.63496941e-01,
#         3.18608552e-01, -9.00978502e-03,  3.68569553e-01, -1.01031914e-01,
#         8.63397941e-02, -5.90289712e-01,  5.60533941e-01,  1.16211779e-01,
#         7.56691217e-01, -2.62195822e-02,  3.02382797e-01, -2.42153957e-01,
#        -7.26450384e-01,  6.27838612e-01, -7.40742564e-01, -2.64454305e-01,
#         2.52723671e-03, -1.56513557e-01,  2.91379422e-01,  2.49367833e-01,
#         2.09260434e-01, -3.95488560e-01, -2.56410778e-01,  2.87723631e-01,
#        -2.74626762e-01,  5.34079373e-01, -4.36195374e-01, -4.39266600e-02,
#         1.33575290e-01, -1.56317517e-01, -5.58875620e-01,  2.02757284e-01,
#        -2.45783076e-01,  3.03559117e-02, -1.19541414e-01, -1.17693782e-01,
#         3.94478559e-01,  1.06877364e-01, -7.50201792e-02,  2.25401029e-01,
#         3.80148411e-01, -2.66227305e-01,  9.29559112e-01,  2.34890625e-01,
#         3.10173720e-01, -3.51222962e-01, -1.94257513e-01, -4.17207211e-01,
#        -7.38074910e-03, -2.30480820e-01, -2.89574534e-01,  6.75499141e-01,
#        -3.89382578e-02, -4.26385641e-01, -4.01432425e-01,  2.75833875e-01,
#        -1.58501342e-01,  5.35035074e-01,  2.77390108e-02, -4.93486702e-01,
#         1.96800902e-01,  2.10655138e-01, -1.34012833e-01, -1.29929304e-01,
#        -2.60717124e-01,  3.83813053e-01, -4.10344124e-01,  3.14688206e-01,
#        -7.70537198e-01, -4.54866588e-01, -1.80463925e-01,  3.12793165e-01,
#         1.20218154e-02,  4.43667099e-02, -5.92338026e-01, -1.22562088e-01,
#         6.03736401e-01, -4.21761721e-01,  3.72381806e-02,  2.62083083e-01,
#         2.50279814e-01, -3.68039250e-01, -2.24980339e-01, -6.82562068e-02,
#        -5.13059497e-02, -3.89697969e-01,  7.37384409e-02, -5.30985177e-01],
#       dtype=float32)

# %% [markdown]
# ### TOKENIZE TEXTS, PREPARE GLOVE EMBEDDINGS

# %%
embeddings_index = {}
with open(os.path.join(GLOVE_DIR, '/media/drived/Dev/Glove/glove.6B.300d.txt'), encoding='utf8') as f:
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 400000 word vectors.

# %%
# finally, vectorize the text samples into a 2D integer tensor
tokenizer = Tokenizer(num_words=MAX_NUM_WORDS)
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)

word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))

data = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)

labels = to_categorical(np.asarray(labels))
print('Shape of data tensor:', data.shape)
print('Shape of label tensor:', labels.shape)

# split the data into a training set and a validation set
# indices = np.arange(data.shape[0])
# np.random.shuffle(indices)
indices = unpickler('data','indices.pkl')
y = np.array(y)[indices.astype(int)]
data = data[indices]
labels = labels[indices]

num_validation_samples = int(VALIDATION_SPLIT * data.shape[0])

x_t = data[:-num_validation_samples]
y_t = labels[:-num_validation_samples]
y_str_t = y[:-num_validation_samples]
x_val = data[-num_validation_samples:]
y_val = labels[-num_validation_samples:]

num_test_samples = int(TEST_SPLIT * x_t.shape[0])

x_train = x_t[:-num_test_samples]
y_train = y_t[:-num_test_samples]
x_test = x_t[-num_test_samples:]
y_test = y_t[-num_test_samples:]
y_str_test = y_str_t[-num_test_samples:]

print('x_train:{} y_train:{} x_val:{} y_val:{} '.format(x_train.shape, y_train.shape, x_val.shape, y_val.shape))
print('Preparing embedding matrix.')

# prepare embedding matrix
num_words = min(MAX_NUM_WORDS, len(word_index) + 1)
embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))

for word, i in word_index.items():
    if i >= MAX_NUM_WORDS:
        continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector
# Out:
# Found 129395 unique tokens.
# Shape of data tensor: (6716, 300)
# Shape of label tensor: (6716, 78, 2)
# x_train:(4836, 300) y_train:(4836, 78, 2) x_val:(671, 300) y_val:(671, 78, 2)
# Preparing embedding matrix.

# %% [markdown]
# ### PREPARE NEURAL NET MODEL CONV2D

# %%
# embedding_clusters_2d = tf.random.normal(embedding_clusters_2d.shape)

# %%
LSTM_HIDDEN_SIZE = 200
LEARNING_RATE = 0.001
KG_EMBEDDING_DIM = 300

# load pre-trained word embeddings into an Embedding layer
# note that we set trainable = False so as to keep the embeddings fixed
embedding_layer = Embedding(num_words,
                            EMBEDDING_DIM,
                            weights=[embedding_matrix],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

print('Preparing model.')

entity_clusters = K.variable(embedding_clusters_2d)

Avg = keras.layers.core.Lambda(lambda x: K.mean(x, axis=1))  # , output_shape=(KG_EMBEDDING_DIM, ))
DotProduct = keras.layers.core.Lambda(lambda x: K.dot(x[0], x[1]))  # , output_shape=(KG_EMBEDDING_DIM, ))
Sum = keras.layers.core.Lambda(lambda x: K.sum(x, axis=1))  # , output_shape=(KG_EMBEDDING_DIM, ))
RemoveLastCol = keras.layers.core.Lambda(lambda x: K.sum(x, axis=-1))
Transpose = keras.layers.core.Lambda(lambda x: K.transpose(x))
FakeEClusterIn = keras.layers.core.Lambda(lambda x: embedding_clusters_2d)

main_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32', name='main_input')

x = embedding_layer(main_input)
x = CuDNNLSTM(KG_EMBEDDING_DIM, return_sequences=True)(x)
x = Avg(x)
x = Dense(KG_EMBEDDING_DIM)(x)
x = Activation('relu')(x)
# entity_extraction = Reshape([KG_EMBEDDING_DIM])(x)
entity_extraction = Transpose(x)

x = embedding_layer(main_input)
x = CuDNNLSTM(LSTM_HIDDEN_SIZE, return_sequences=True)(x)
Avg = keras.layers.core.Lambda(lambda x: K.mean(x, axis=1), output_shape=(LSTM_HIDDEN_SIZE,))
x = Avg(x)
x = Dense(LSTM_HIDDEN_SIZE)(x)
main_lstm_out = Activation('relu')(x)

# get representation for entity clusters
# e_clusters = Input(tensor=entity_clusters,name='e_clusters')
x = FakeEClusterIn(x)
print("Shape", K.int_shape(x))
# x = e_clusters
x = Conv2D(filters=1, kernel_size=(5, 1), strides=(5, 1), input_shape=embedding_clusters_2d.shape[1:])(x)
x = MaxPooling2D(pool_size=(6, 1), strides=(6, 1))(x)
x = Conv2D(filters=1, kernel_size=(5, 1), strides=(5, 1))(x)
x = MaxPooling2D(pool_size=(5, 1), strides=(5, 1))(x)
print("Before removing last col", K.int_shape(x))
x = RemoveLastCol(x)
print("after removing last col", K.int_shape(x))
entity_cluster_reps = Reshape([KG_EMBEDDING_DIM], name='entity_cluster_reps')(x)
print("entity_cluster_reps(after reshape)", K.int_shape(entity_cluster_reps))

# attention over entities
att_scores = DotProduct([entity_cluster_reps, entity_extraction])
print("att_scores_entities", K.int_shape(att_scores))
# att_normalized = Activation('softmax',name='entity_attention')(att_scores)
att_normalized = Softmax(axis=-1, name='entity_attention')(att_scores)
print("att_normalized", K.int_shape(att_normalized))
the_entity = DotProduct([Transpose(entity_cluster_reps), att_normalized])
print("the_entity", K.int_shape(the_entity))

lstm_hidden_and_entity = Concatenate(axis=0)([Transpose(main_lstm_out), the_entity])
print("lstm_hidden_and_entity", K.int_shape(lstm_hidden_and_entity))
# input("continue?")

final_output = Dense(units=len(unique_labels), activation='softmax')(Transpose(lstm_hidden_and_entity))

optimizer = Adam(lr=LEARNING_RATE, clipvalue=0.25)

m = Model(inputs=main_input, outputs=final_output)

m.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['acc'])

_, tmpfn = tempfile.mkstemp()
# Save the best model during validation and bail out of training early if we're not improving
callbacks = [ModelCheckpoint(tmpfn, monitor='val_acc', save_best_only=True, save_weights_only=True)]

m.summary()

from tensorflow.keras.utils import plot_model
# plot_model(m, to_file='model.png')

_, tmpfn = tempfile.mkstemp()
# Save the best model during validation and bail out of training early if we're not improving
callbacks = [ModelCheckpoint(tmpfn,monitor='val_acc', save_best_only=True, save_weights_only=True)]
# Out:
# Preparing model.
# Shape (20, 2585, 100, 1)
# Before removing last col (20, 3, 100, 1)
# after removing last col (20, 3, 100)
# entity_cluster_reps(after reshape) (20, 300)
# att_scores_entities (20, None)
# att_normalized (20, None)
# the_entity (300, None)
# lstm_hidden_and_entity (500, None)
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input (InputLayer)         [(None, 300)]        0
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 300, 300)     6000000     main_input[0][0]
#                                                                  main_input[0][0]
# __________________________________________________________________________________________________
# cu_dnnlstm_7 (CuDNNLSTM)        (None, 300, 200)     401600      embedding_3[1][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, 200)          0           cu_dnnlstm_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 200)          40200       lambda_27[0][0]
# __________________________________________________________________________________________________
# lambda_26 (Lambda)              (20, 2585, 100, 1)   0           dense_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (20, 517, 100, 1)    6           lambda_26[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (20, 86, 100, 1)     0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (20, 17, 100, 1)     6           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# cu_dnnlstm_6 (CuDNNLSTM)        (None, 300, 300)     722400      embedding_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (20, 3, 100, 1)      0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 300)          0           cu_dnnlstm_6[0][0]
# __________________________________________________________________________________________________
# lambda_24 (Lambda)              (20, 3, 100)         0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 300)          90300       lambda_21[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 200)          0           dense_8[0][0]
# __________________________________________________________________________________________________
# entity_cluster_reps (Reshape)   (20, 300)            0           lambda_24[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 300)          0           dense_7[0][0]
# __________________________________________________________________________________________________
# lambda_25 (Lambda)              multiple             0           activation_6[0][0]
#                                                                  entity_cluster_reps[0][0]
#                                                                  activation_7[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              multiple             0           entity_cluster_reps[0][0]
#                                                                  lambda_25[0][0]
#                                                                  lambda_25[1][0]
#                                                                  entity_attention[0][0]
# __________________________________________________________________________________________________
# entity_attention (Softmax)      (20, None)           0           lambda_22[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (500, None)          0           lambda_25[2][0]
#                                                                  lambda_22[1][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 78)           39078       lambda_25[3][0]
# ==================================================================================================
# Total params: 7,293,590
# Trainable params: 1,293,590
# Non-trainable params: 6,000,000
# __________________________________________________________________________________________________

# %% [markdown]
# ### PREDICT CONV2D

# %%
BATCH_SIZE = 2
NUM_EPOCHS = 10

history = m.fit(x_train, y_train,
                batch_size=BATCH_SIZE,
                epochs=NUM_EPOCHS,
                validation_data=(x_val, y_val), 
                callbacks=callbacks)
m.save('node2vec_lstm_model')
# Out:
# Epoch 1/10
#  349/2418 [===>..........................] - ETA: 1:03:41 - loss: 4.4996 - acc: 0.0000e+ - ETA: 1:50 - loss: 7.3437 - acc: 0.0000e+00   - ETA: 1:49 - loss: 7.8418 - acc: 0.0000e+0 - ETA: 1:48 - loss: 7.4011 - acc: 0.0000e+0 - ETA: 1:47 - loss: 7.0167 - acc: 0.0000e+0 - ETA: 1:47 - loss: 6.8506 - acc: 0.0000e+0 - ETA: 1:46 - loss: 6.8360 - acc: 0.0000e+0 - ETA: 1:46 - loss: 6.9715 - acc: 0.0000e+0 - ETA: 1:46 - loss: 7.2541 - acc: 0.0000e+0 - ETA: 1:45 - loss: 7.4608 - acc: 0.0000e+0 - ETA: 1:45 - loss: 7.5667 - acc: 0.0000e+0 - ETA: 1:45 - loss: 7.5049 - acc: 0.0000e+0 - ETA: 1:45 - loss: 7.3822 - acc: 0.0000e+0 - ETA: 1:45 - loss: 7.3906 - acc: 0.0000e+0 - ETA: 1:45 - loss: 7.2569 - acc: 0.0000e+0 - ETA: 1:45 - loss: 7.1678 - acc: 0.0000e+0 - ETA: 1:45 - loss: 7.1228 - acc: 0.0000e+0 - ETA: 1:45 - loss: 6.9626 - acc: 0.0000e+0 - ETA: 1:44 - loss: 6.8294 - acc: 0.0000e+0 - ETA: 1:44 - loss: 6.7574 - acc: 0.0000e+0 - ETA: 1:44 - loss: 6.7398 - acc: 0.0122    - ETA: 1:44 - loss: 6.6293 - acc: 0.011 - ETA: 1:44 - loss: 6.5110 - acc: 0.011 - ETA: 1:44 - loss: 6.4289 - acc: 0.010 - ETA: 1:44 - loss: 6.4174 - acc: 0.010 - ETA: 1:44 - loss: 6.4139 - acc: 0.019 - ETA: 1:44 - loss: 6.3980 - acc: 0.018 - ETA: 1:44 - loss: 6.3357 - acc: 0.018 - ETA: 1:43 - loss: 6.2800 - acc: 0.017 - ETA: 1:43 - loss: 6.2110 - acc: 0.016 - ETA: 1:43 - loss: 6.1494 - acc: 0.016 - ETA: 1:43 - loss: 6.1320 - acc: 0.015 - ETA: 1:43 - loss: 6.1183 - acc: 0.015 - ETA: 1:43 - loss: 6.1100 - acc: 0.014 - ETA: 1:43 - loss: 6.0442 - acc: 0.014 - ETA: 1:43 - loss: 6.0207 - acc: 0.014 - ETA: 1:43 - loss: 5.9870 - acc: 0.013 - ETA: 1:43 - loss: 5.9378 - acc: 0.013 - ETA: 1:43 - loss: 5.8920 - acc: 0.019 - ETA: 1:42 - loss: 5.8380 - acc: 0.019 - ETA: 1:42 - loss: 5.8185 - acc: 0.018 - ETA: 1:42 - loss: 5.8091 - acc: 0.018 - ETA: 1:42 - loss: 5.7830 - acc: 0.017 - ETA: 1:42 - loss: 5.7492 - acc: 0.017 - ETA: 1:42 - loss: 5.7209 - acc: 0.016 - ETA: 1:42 - loss: 5.7242 - acc: 0.016 - ETA: 1:42 - loss: 5.7064 - acc: 0.016 - ETA: 1:42 - loss: 5.6843 - acc: 0.015 - ETA: 1:42 - loss: 5.6536 - acc: 0.015 - ETA: 1:42 - loss: 5.6195 - acc: 0.020 - ETA: 1:41 - loss: 5.5891 - acc: 0.019 - ETA: 1:41 - loss: 5.5771 - acc: 0.019 - ETA: 1:41 - loss: 5.5470 - acc: 0.019 - ETA: 1:41 - loss: 5.5330 - acc: 0.018 - ETA: 1:41 - loss: 5.5158 - acc: 0.018 - ETA: 1:41 - loss: 5.5163 - acc: 0.018 - ETA: 1:41 - loss: 5.5025 - acc: 0.017 - ETA: 1:41 - loss: 5.4765 - acc: 0.017 - ETA: 1:41 - loss: 5.4634 - acc: 0.017 - ETA: 1:41 - loss: 5.4503 - acc: 0.016 - ETA: 1:40 - loss: 5.4268 - acc: 0.016 - ETA: 1:40 - loss: 5.4203 - acc: 0.020 - ETA: 1:40 - loss: 5.4061 - acc: 0.020 - ETA: 1:40 - loss: 5.3915 - acc: 0.019 - ETA: 1:40 - loss: 5.3671 - acc: 0.019 - ETA: 1:40 - loss: 5.3603 - acc: 0.019 - ETA: 1:40 - loss: 5.3383 - acc: 0.018 - ETA: 1:40 - loss: 5.3274 - acc: 0.018 - ETA: 1:40 - loss: 5.3174 - acc: 0.018 - ETA: 1:40 - loss: 5.3057 - acc: 0.018 - ETA: 1:40 - loss: 5.2975 - acc: 0.017 - ETA: 1:39 - loss: 5.2776 - acc: 0.017 - ETA: 1:39 - loss: 5.2629 - acc: 0.017 - ETA: 1:39 - loss: 5.2516 - acc: 0.017 - ETA: 1:39 - loss: 5.2357 - acc: 0.016 - ETA: 1:39 - loss: 5.2206 - acc: 0.016 - ETA: 1:39 - loss: 5.2055 - acc: 0.016 - ETA: 1:39 - loss: 5.1965 - acc: 0.016 - ETA: 1:39 - loss: 5.1905 - acc: 0.015 - ETA: 1:39 - loss: 5.1705 - acc: 0.018 - ETA: 1:39 - loss: 5.1592 - acc: 0.018 - ETA: 1:39 - loss: 5.1421 - acc: 0.018 - ETA: 1:39 - loss: 5.1368 - acc: 0.018 - ETA: 1:39 - loss: 5.1304 - acc: 0.018 - ETA: 1:38 - loss: 5.1182 - acc: 0.017 - ETA: 1:38 - loss: 5.1089 - acc: 0.017 - ETA: 1:38 - loss: 5.1011 - acc: 0.017 - ETA: 1:38 - loss: 5.0882 - acc: 0.017 - ETA: 1:38 - loss: 5.0867 - acc: 0.016 - ETA: 1:38 - loss: 5.0809 - acc: 0.016 - ETA: 1:38 - loss: 5.0677 - acc: 0.019 - ETA: 1:38 - loss: 5.0560 - acc: 0.019 - ETA: 1:38 - loss: 5.0465 - acc: 0.018 - ETA: 1:38 - loss: 5.0373 - acc: 0.018 - ETA: 1:38 - loss: 5.0256 - acc: 0.021 - ETA: 1:37 - loss: 5.0199 - acc: 0.020 - ETA: 1:37 - loss: 5.0098 - ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# In  [26]:
# Line 8:     callbacks=callbacks)
#
# File /home/cnytync/Dev/anaconda3/envs/Python36/lib/python3.6/site-packages/keras/engine/training.py, in fit:
# Line 1189:  callbacks.on_train_batch_end(end_step, logs)
#
# File /home/cnytync/Dev/anaconda3/envs/Python36/lib/python3.6/site-packages/keras/callbacks.py, in on_train_batch_end:
# Line 435:   self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#
# File /home/cnytync/Dev/anaconda3/envs/Python36/lib/python3.6/site-packages/keras/callbacks.py, in _call_batch_hook:
# Line 295:   self._call_batch_end_hook(mode, batch, logs)
#
# File /home/cnytync/Dev/anaconda3/envs/Python36/lib/python3.6/site-packages/keras/callbacks.py, in _call_batch_end_hook:
# Line 315:   self._call_batch_hook_helper(hook_name, batch, logs)
#
# File /home/cnytync/Dev/anaconda3/envs/Python36/lib/python3.6/site-packages/keras/callbacks.py, in _call_batch_hook_helper:
# Line 353:   hook(batch, logs)
#
# File /home/cnytync/Dev/anaconda3/envs/Python36/lib/python3.6/site-packages/keras/callbacks.py, in on_train_batch_end:
# Line 1028:  self._batch_update_progbar(batch, logs)
#
# File /home/cnytync/Dev/anaconda3/envs/Python36/lib/python3.6/site-packages/keras/callbacks.py, in _batch_update_progbar:
# Line 1100:  logs = tf_utils.sync_to_numpy_or_python_type(logs)
#
# File /home/cnytync/Dev/anaconda3/envs/Python36/lib/python3.6/site-packages/keras/utils/tf_utils.py, in sync_to_numpy_or_python_type:
# Line 516:   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#
# File /home/cnytync/Dev/anaconda3/envs/Python36/lib/python3.6/site-packages/tensorflow/python/util/nest.py, in map_structure:
# Line 869:   structure[0], [func(*x) for x in entries],
#
# File /home/cnytync/Dev/anaconda3/envs/Python36/lib/python3.6/site-packages/tensorflow/python/util/nest.py, in <listcomp>:
# Line 869:   structure[0], [func(*x) for x in entries],
#
# File /home/cnytync/Dev/anaconda3/envs/Python36/lib/python3.6/site-packages/keras/utils/tf_utils.py, in _to_single_numpy_or_python_type:
# Line 512:   x = t.numpy()
#
# File /home/cnytync/Dev/anaconda3/envs/Python36/lib/python3.6/site-packages/tensorflow/python/framework/ops.py, in numpy:
# Line 1094:  maybe_arr = self._numpy()  # pylint: disable=protected-access
#
# File /home/cnytync/Dev/anaconda3/envs/Python36/lib/python3.6/site-packages/tensorflow/python/framework/ops.py, in _numpy:
# Line 1060:  return self._numpy_internal()
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------

# %%
# Restore the best found model during validation
# m.load_weights(tmpfn)

loss, acc = m.evaluate(x_test, y_test, batch_size=BATCH_SIZE)
print('Test loss / test accuracy = {:.4f} / {:.4f}'.format(loss, acc))
# Out:
# 605/605 [==============================] - ETA: 3:45 - loss: 3.1769e-04 - acc: 1.000 - ETA: 7s - loss: 2.7743 - acc: 0.6000      - ETA: 7s - loss: 1.5433 - acc: 0.777 - ETA: 7s - loss: 2.0892 - acc: 0.750 - ETA: 7s - loss: 2.4398 - acc: 0.710 - ETA: 7s - loss: 2.3416 - acc: 0.666 - ETA: 6s - loss: 2.2829 - acc: 0.655 - ETA: 6s - loss: 2.2964 - acc: 0.632 - ETA: 6s - loss: 2.2410 - acc: 0.628 - ETA: 6s - loss: 2.0426 - acc: 0.659 - ETA: 6s - loss: 1.9769 - acc: 0.653 - ETA: 6s - loss: 1.8795 - acc: 0.657 - ETA: 6s - loss: 1.8924 - acc: 0.644 - ETA: 6s - loss: 1.8377 - acc: 0.648 - ETA: 6s - loss: 1.8400 - acc: 0.644 - ETA: 6s - loss: 1.8671 - acc: 0.641 - ETA: 6s - loss: 1.8973 - acc: 0.645 - ETA: 5s - loss: 1.8080 - acc: 0.654 - ETA: 5s - loss: 1.8190 - acc: 0.646 - ETA: 5s - loss: 1.8212 - acc: 0.643 - ETA: 5s - loss: 1.8629 - acc: 0.636 - ETA: 5s - loss: 2.0627 - acc: 0.634 - ETA: 5s - loss: 2.0911 - acc: 0.633 - ETA: 5s - loss: 2.0960 - acc: 0.622 - ETA: 5s - loss: 2.0724 - acc: 0.621 - ETA: 5s - loss: 2.1147 - acc: 0.621 - ETA: 5s - loss: 2.0533 - acc: 0.627 - ETA: 5s - loss: 2.0496 - acc: 0.630 - ETA: 5s - loss: 2.0206 - acc: 0.636 - ETA: 5s - loss: 1.9644 - acc: 0.642 - ETA: 5s - loss: 1.9179 - acc: 0.647 - ETA: 5s - loss: 1.8881 - acc: 0.649 - ETA: 5s - loss: 1.9009 - acc: 0.647 - ETA: 5s - loss: 1.8930 - acc: 0.643 - ETA: 4s - loss: 1.8532 - acc: 0.647 - ETA: 4s - loss: 1.8444 - acc: 0.652 - ETA: 4s - loss: 1.8383 - acc: 0.653 - ETA: 4s - loss: 1.8144 - acc: 0.652 - ETA: 4s - loss: 1.7832 - acc: 0.658 - ETA: 4s - loss: 1.8224 - acc: 0.652 - ETA: 4s - loss: 1.8762 - acc: 0.650 - ETA: 4s - loss: 1.8546 - acc: 0.654 - ETA: 4s - loss: 1.8743 - acc: 0.648 - ETA: 4s - loss: 1.9150 - acc: 0.642 - ETA: 4s - loss: 1.8791 - acc: 0.646 - ETA: 4s - loss: 1.8492 - acc: 0.649 - ETA: 4s - loss: 1.8346 - acc: 0.650 - ETA: 4s - loss: 1.7976 - acc: 0.656 - ETA: 4s - loss: 1.7814 - acc: 0.659 - ETA: 4s - loss: 1.7900 - acc: 0.661 - ETA: 4s - loss: 1.7696 - acc: 0.664 - ETA: 3s - loss: 1.7643 - acc: 0.663 - ETA: 3s - loss: 1.7840 - acc: 0.656 - ETA: 3s - loss: 1.7750 - acc: 0.655 - ETA: 3s - loss: 1.7601 - acc: 0.656 - ETA: 3s - loss: 1.7292 - acc: 0.662 - ETA: 3s - loss: 1.7597 - acc: 0.657 - ETA: 3s - loss: 1.7455 - acc: 0.658 - ETA: 3s - loss: 1.7267 - acc: 0.660 - ETA: 3s - loss: 1.7069 - acc: 0.665 - ETA: 3s - loss: 1.7089 - acc: 0.663 - ETA: 3s - loss: 1.7085 - acc: 0.662 - ETA: 3s - loss: 1.7058 - acc: 0.661 - ETA: 3s - loss: 1.7087 - acc: 0.659 - ETA: 3s - loss: 1.7026 - acc: 0.656 - ETA: 3s - loss: 1.6924 - acc: 0.655 - ETA: 3s - loss: 1.6908 - acc: 0.655 - ETA: 3s - loss: 1.6915 - acc: 0.654 - ETA: 2s - loss: 1.6694 - acc: 0.657 - ETA: 2s - loss: 1.6945 - acc: 0.654 - ETA: 2s - loss: 1.6773 - acc: 0.656 - ETA: 2s - loss: 1.6773 - acc: 0.659 - ETA: 2s - loss: 1.6796 - acc: 0.657 - ETA: 2s - loss: 1.6964 - acc: 0.658 - ETA: 2s - loss: 1.7023 - acc: 0.658 - ETA: 2s - loss: 1.6961 - acc: 0.659 - ETA: 2s - loss: 1.6971 - acc: 0.657 - ETA: 2s - loss: 1.6799 - acc: 0.657 - ETA: 2s - loss: 1.6733 - acc: 0.659 - ETA: 2s - loss: 1.6662 - acc: 0.657 - ETA: 2s - loss: 1.6617 - acc: 0.659 - ETA: 2s - loss: 1.6872 - acc: 0.654 - ETA: 2s - loss: 1.6849 - acc: 0.655 - ETA: 2s - loss: 1.7451 - acc: 0.654 - ETA: 2s - loss: 1.7283 - acc: 0.656 - ETA: 2s - loss: 1.7203 - acc: 0.659 - ETA: 1s - loss: 1.7352 - acc: 0.656 - ETA: 1s - loss: 1.7283 - acc: 0.656 - ETA: 1s - loss: 1.7600 - acc: 0.653 - ETA: 1s - loss: 1.7443 - acc: 0.656 - ETA: 1s - loss: 1.7682 - acc: 0.654 - ETA: 1s - loss: 1.7648 - acc: 0.656 - ETA: 1s - loss: 1.7725 - acc: 0.656 - ETA: 1s - loss: 1.7646 - acc: 0.657 - ETA: 1s - loss: 1.7565 - acc: 0.656 - ETA: 1s - loss: 1.7701 - acc: 0.654 - ETA: 1s - loss: 1.7635 - acc: 0.653 - ETA: 1s - loss: 1.7549 - acc: 0.652 - ETA: 1s - loss: 1.7428 - acc: 0.654 - ETA: 1s - loss: 1.7372 - acc: 0.656 - ETA: 1s - loss: 1.7382 - acc: 0.657 - ETA: 1s - loss: 1.7306 - acc: 0.657 - ETA: 1s - loss: 1.7230 - acc: 0.658 - ETA: 1s - loss: 1.7270 - acc: 0 ...
# Test loss / test accuracy = 1.6824 / 0.6592

# %%
preds = m.predict(x_test, batch_size=BATCH_SIZE, verbose=0,
                  steps=None)

# %%
def get_result_labels(results):
    return [unique_labels[np.where(row==max(row))[0][0]] for row in results]

result_labels = get_result_labels(preds)

print('Accuracy score: %.2f' % accuracy_score(result_labels, y_str_test))
print(classification_report(y_str_test, result_labels))

# %% [markdown]
# ### PREPARE NEURAL NET MODEL CONV2D WITH PRE-TRAINING

# %%
LSTM_HIDDEN_SIZE = 200
LEARNING_RATE = 0.001
KG_EMBEDDING_DIM = 300

# load pre-trained word embeddings into an Embedding layer
# note that we set trainable = False so as to keep the embeddings fixed
embedding_layer = Embedding(num_words,
                            EMBEDDING_DIM,
                            weights=[embedding_matrix],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

print('Preparing model.')

entity_clusters = K.variable(embedding_clusters_2d)

Avg = keras.layers.core.Lambda(lambda x: K.mean(x, axis=1))  # , output_shape=(KG_EMBEDDING_DIM, ))
DotProduct = keras.layers.core.Lambda(lambda x: K.dot(x[0], x[1]))  # , output_shape=(KG_EMBEDDING_DIM, ))
Sum = keras.layers.core.Lambda(lambda x: K.sum(x, axis=1))  # , output_shape=(KG_EMBEDDING_DIM, ))
RemoveLastCol = keras.layers.core.Lambda(lambda x: K.sum(x, axis=-1))
Transpose = keras.layers.core.Lambda(lambda x: K.transpose(x))
FakeEClusterIn = keras.layers.core.Lambda(lambda x: embedding_clusters_2d)

main_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32', name='main_input')

x = embedding_layer(main_input)
x = CuDNNLSTM(KG_EMBEDDING_DIM, return_sequences=True)(x)
x = Avg(x)
x = Dense(KG_EMBEDDING_DIM)(x)
x = Activation('relu')(x)
# entity_extraction = Reshape([KG_EMBEDDING_DIM])(x)
entity_extraction = Transpose(x)

# get representation for entity clusters
# e_clusters = Input(tensor=entity_clusters,name='e_clusters')
x = FakeEClusterIn(x)
print("Shape", K.int_shape(x))
# x = e_clusters
x = Conv2D(filters=1, kernel_size=(5, 1), strides=(5, 1), input_shape=embedding_clusters_2d.shape[1:])(x)
x = MaxPooling2D(pool_size=(6, 1), strides=(6, 1))(x)
x = Conv2D(filters=1, kernel_size=(5, 1), strides=(5, 1))(x)
x = MaxPooling2D(pool_size=(5, 1), strides=(5, 1))(x)
print("Before removing last col", K.int_shape(x))
x = RemoveLastCol(x)
print("after removing last col", K.int_shape(x))
entity_cluster_reps = Reshape([KG_EMBEDDING_DIM], name='entity_cluster_reps')(x)
# entity_cluster_reps = x
print("entity_cluster_reps(after reshape)", K.int_shape(entity_cluster_reps))

# attention over entities
att_scores = DotProduct([entity_cluster_reps, entity_extraction])
print("att_scores_entities", K.int_shape(att_scores))
# att_normalized = Activation('softmax',name='entity_attention')(att_scores)
att_normalized = Softmax(axis=-1, name='entity_attention')(att_scores)
print("att_normalized", K.int_shape(att_normalized))
the_entity = DotProduct([Transpose(entity_cluster_reps), att_normalized])
print("the_entity", K.int_shape(the_entity))

final_output = Dense(units=len(unique_labels), activation='softmax')(Transpose(the_entity))

optimizer = Adam(lr=LEARNING_RATE, clipvalue=0.25)

m1 = Model(inputs=main_input, outputs=final_output)
m1.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['acc'])
m1.summary()

_, tmpfn = tempfile.mkstemp()
# Save the best model during validation and bail out of training early if we're not improving
callbacks = [ModelCheckpoint(tmpfn,monitor='val_acc', save_best_only=True, save_weights_only=True)]
# Out:
# Preparing model.
# Shape (20, 2585, 100, 1)
# Before removing last col (20, 3, 100, 1)
# after removing last col (20, 3, 100)
# entity_cluster_reps(after reshape) (20, 300)
# att_scores_entities (20, None)
# att_normalized (20, None)
# the_entity (300, None)
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input (InputLayer)         [(None, 300)]        0
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 300, 300)     6000000     main_input[0][0]
# __________________________________________________________________________________________________
# cu_dnnlstm_8 (CuDNNLSTM)        (None, 300, 300)     722400      embedding_4[0][0]
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None, 300)          0           cu_dnnlstm_8[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 300)          90300       lambda_28[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 300)          0           dense_10[0][0]
# __________________________________________________________________________________________________
# lambda_33 (Lambda)              (20, 2585, 100, 1)   0           activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (20, 517, 100, 1)    6           lambda_33[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (20, 86, 100, 1)     0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (20, 17, 100, 1)     6           max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (20, 3, 100, 1)      0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (20, 3, 100)         0           max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# entity_cluster_reps (Reshape)   (20, 300)            0           lambda_31[0][0]
# __________________________________________________________________________________________________
# lambda_32 (Lambda)              multiple             0           activation_8[0][0]
#                                                                  entity_cluster_reps[0][0]
#                                                                  lambda_29[1][0]
# __________________________________________________________________________________________________
# lambda_29 (Lambda)              multiple             0           entity_cluster_reps[0][0]
#                                                                  lambda_32[0][0]
#                                                                  lambda_32[1][0]
#                                                                  entity_attention[0][0]
# __________________________________________________________________________________________________
# entity_attention (Softmax)      (20, None)           0           lambda_29[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 78)           23478       lambda_32[2][0]
# ==================================================================================================
# Total params: 6,836,190
# Trainable params: 836,190
# Non-trainable params: 6,000,000
# __________________________________________________________________________________________________

# %%
BATCH_SIZE = 2
NUM_EPOCHS = 10

history = m1.fit(x_train, y_train,
                batch_size=BATCH_SIZE,
                epochs=NUM_EPOCHS,
                validation_data=(x_val, y_val), 
                callbacks=callbacks)
# m.save('node2vec_lstm_model')
# Out:
# Epoch 1/10
# 2418/2418 [==============================] - ETA: 40:56 - loss: 10.3863 - acc: 0.0000e+0 - ETA: 1:16 - loss: 12.2922 - acc: 0.0000e+0 - ETA: 1:16 - loss: 15.8091 - acc: 0.0000e+ - ETA: 1:15 - loss: 13.3108 - acc: 0.0000e+ - ETA: 1:14 - loss: 13.2390 - acc: 0.0000e+ - ETA: 1:14 - loss: 13.3350 - acc: 0.0000e+ - ETA: 1:13 - loss: 13.0776 - acc: 0.0000e+ - ETA: 1:12 - loss: 13.6432 - acc: 0.0000e+ - ETA: 1:12 - loss: 13.9234 - acc: 0.0000e+ - ETA: 1:11 - loss: 13.7730 - acc: 0.0000e+ - ETA: 1:11 - loss: 13.9598 - acc: 0.0000e+ - ETA: 1:11 - loss: 13.6261 - acc: 0.0000e+ - ETA: 1:11 - loss: 13.1156 - acc: 0.0000e+ - ETA: 1:10 - loss: 12.4118 - acc: 0.0000e+ - ETA: 1:10 - loss: 12.3702 - acc: 0.0000e+ - ETA: 1:10 - loss: 11.9515 - acc: 0.0000e+ - ETA: 1:10 - loss: 11.5258 - acc: 0.0152   - ETA: 1:10 - loss: 11.3274 - acc: 0.01 - ETA: 1:09 - loss: 11.2519 - acc: 0.01 - ETA: 1:09 - loss: 11.1360 - acc: 0.01 - ETA: 1:09 - loss: 10.9349 - acc: 0.02 - ETA: 1:09 - loss: 10.7922 - acc: 0.02 - ETA: 1:09 - loss: 10.5470 - acc: 0.02 - ETA: 1:09 - loss: 10.4127 - acc: 0.02 - ETA: 1:09 - loss: 10.2973 - acc: 0.03 - ETA: 1:08 - loss: 10.1114 - acc: 0.02 - ETA: 1:08 - loss: 9.9168 - acc: 0.0283 - ETA: 1:08 - loss: 9.7563 - acc: 0.027 - ETA: 1:08 - loss: 9.6300 - acc: 0.026 - ETA: 1:08 - loss: 9.4338 - acc: 0.025 - ETA: 1:08 - loss: 9.2740 - acc: 0.032 - ETA: 1:08 - loss: 9.1614 - acc: 0.031 - ETA: 1:08 - loss: 9.0537 - acc: 0.030 - ETA: 1:08 - loss: 8.9102 - acc: 0.029 - ETA: 1:08 - loss: 8.8532 - acc: 0.029 - ETA: 1:08 - loss: 8.7701 - acc: 0.028 - ETA: 1:07 - loss: 8.7054 - acc: 0.034 - ETA: 1:07 - loss: 8.5903 - acc: 0.033 - ETA: 1:07 - loss: 8.4821 - acc: 0.032 - ETA: 1:08 - loss: 8.3699 - acc: 0.038 - ETA: 1:07 - loss: 8.2796 - acc: 0.037 - ETA: 1:07 - loss: 8.1930 - acc: 0.036 - ETA: 1:07 - loss: 8.0968 - acc: 0.041 - ETA: 1:07 - loss: 8.0168 - acc: 0.040 - ETA: 1:07 - loss: 7.9817 - acc: 0.039 - ETA: 1:07 - loss: 7.8888 - acc: 0.038 - ETA: 1:07 - loss: 7.8372 - acc: 0.037 - ETA: 1:07 - loss: 7.7619 - acc: 0.042 - ETA: 1:07 - loss: 7.6876 - acc: 0.041 - ETA: 1:07 - loss: 7.6111 - acc: 0.040 - ETA: 1:07 - loss: 7.5499 - acc: 0.039 - ETA: 1:07 - loss: 7.4841 - acc: 0.038 - ETA: 1:07 - loss: 7.4595 - acc: 0.042 - ETA: 1:06 - loss: 7.4008 - acc: 0.042 - ETA: 1:06 - loss: 7.3472 - acc: 0.041 - ETA: 1:06 - loss: 7.3006 - acc: 0.040 - ETA: 1:06 - loss: 7.2548 - acc: 0.039 - ETA: 1:06 - loss: 7.2237 - acc: 0.039 - ETA: 1:06 - loss: 7.1687 - acc: 0.038 - ETA: 1:06 - loss: 7.1248 - acc: 0.037 - ETA: 1:06 - loss: 7.0820 - acc: 0.037 - ETA: 1:06 - loss: 7.0317 - acc: 0.036 - ETA: 1:06 - loss: 6.9959 - acc: 0.036 - ETA: 1:06 - loss: 6.9535 - acc: 0.035 - ETA: 1:06 - loss: 6.9331 - acc: 0.034 - ETA: 1:06 - loss: 6.8914 - acc: 0.034 - ETA: 1:06 - loss: 6.8400 - acc: 0.033 - ETA: 1:05 - loss: 6.8019 - acc: 0.033 - ETA: 1:05 - loss: 6.7679 - acc: 0.032 - ETA: 1:05 - loss: 6.7411 - acc: 0.032 - ETA: 1:05 - loss: 6.7057 - acc: 0.031 - ETA: 1:05 - loss: 6.6681 - acc: 0.031 - ETA: 1:05 - loss: 6.6592 - acc: 0.034 - ETA: 1:05 - loss: 6.6323 - acc: 0.034 - ETA: 1:05 - loss: 6.6039 - acc: 0.033 - ETA: 1:05 - loss: 6.5753 - acc: 0.036 - ETA: 1:05 - loss: 6.5542 - acc: 0.035 - ETA: 1:05 - loss: 6.5245 - acc: 0.035 - ETA: 1:05 - loss: 6.4919 - acc: 0.035 - ETA: 1:05 - loss: 6.4661 - acc: 0.034 - ETA: 1:05 - loss: 6.4493 - acc: 0.034 - ETA: 1:04 - loss: 6.4193 - acc: 0.033 - ETA: 1:04 - loss: 6.3975 - acc: 0.033 - ETA: 1:04 - loss: 6.3720 - acc: 0.032 - ETA: 1:04 - loss: 6.3474 - acc: 0.032 - ETA: 1:04 - loss: 6.3260 - acc: 0.032 - ETA: 1:04 - loss: 6.3076 - acc: 0.031 - ETA: 1:04 - loss: 6.2951 - acc: 0.031 - ETA: 1:04 - loss: 6.2736 - acc: 0.031 - ETA: 1:04 - loss: 6.2468 - acc: 0.030 - ETA: 1:04 - loss: 6.2269 - acc: 0.030 - ETA: 1:04 - loss: 6.2085 - acc: 0.030 - ETA: 1:04 - loss: 6.1879 - acc: 0.029 - ETA: 1:04 - loss: 6.1692 - acc: 0.029 - ETA: 1:04 - loss: 6.1575 - acc: 0.029 - ETA: 1:04 - loss: 6.1370 - acc: 0.028 - ETA: 1:04 - loss: 6.1216 - acc: 0.028 - ETA ...
# Epoch 2/10
# 2418/2418 [==============================] - ETA: 1:07 - loss: 4.5899 - acc: 0.0000e+0 - ETA: 1:08 - loss: 4.0806 - acc: 0.0000e+0 - ETA: 1:07 - loss: 3.9558 - acc: 0.0000e+0 - ETA: 1:07 - loss: 3.9162 - acc: 0.0000e+0 - ETA: 1:07 - loss: 3.9795 - acc: 0.0000e+0 - ETA: 1:07 - loss: 4.1736 - acc: 0.0000e+0 - ETA: 1:07 - loss: 4.2331 - acc: 0.0000e+0 - ETA: 1:07 - loss: 4.1723 - acc: 0.0000e+0 - ETA: 1:06 - loss: 4.2227 - acc: 0.0000e+0 - ETA: 1:06 - loss: 4.2318 - acc: 0.0000e+0 - ETA: 1:06 - loss: 4.2361 - acc: 0.0000e+0 - ETA: 1:06 - loss: 4.2218 - acc: 0.0000e+0 - ETA: 1:06 - loss: 4.2081 - acc: 0.0000e+0 - ETA: 1:07 - loss: 4.1866 - acc: 0.0185    - ETA: 1:07 - loss: 4.1713 - acc: 0.017 - ETA: 1:07 - loss: 4.1686 - acc: 0.016 - ETA: 1:07 - loss: 4.1807 - acc: 0.015 - ETA: 1:07 - loss: 4.1824 - acc: 0.014 - ETA: 1:06 - loss: 4.1813 - acc: 0.013 - ETA: 1:06 - loss: 4.1822 - acc: 0.012 - ETA: 1:06 - loss: 4.1961 - acc: 0.012 - ETA: 1:06 - loss: 4.1762 - acc: 0.011 - ETA: 1:06 - loss: 4.1624 - acc: 0.033 - ETA: 1:06 - loss: 4.1570 - acc: 0.031 - ETA: 1:06 - loss: 4.1578 - acc: 0.030 - ETA: 1:06 - loss: 4.1352 - acc: 0.029 - ETA: 1:06 - loss: 4.1247 - acc: 0.037 - ETA: 1:06 - loss: 4.1142 - acc: 0.036 - ETA: 1:06 - loss: 4.1092 - acc: 0.035 - ETA: 1:06 - loss: 4.0923 - acc: 0.042 - ETA: 1:06 - loss: 4.0873 - acc: 0.041 - ETA: 1:05 - loss: 4.0840 - acc: 0.039 - ETA: 1:05 - loss: 4.0619 - acc: 0.046 - ETA: 1:05 - loss: 4.0455 - acc: 0.044 - ETA: 1:05 - loss: 4.0535 - acc: 0.043 - ETA: 1:05 - loss: 4.0531 - acc: 0.042 - ETA: 1:05 - loss: 4.0633 - acc: 0.041 - ETA: 1:05 - loss: 4.0457 - acc: 0.046 - ETA: 1:05 - loss: 4.0502 - acc: 0.045 - ETA: 1:05 - loss: 4.0462 - acc: 0.050 - ETA: 1:05 - loss: 4.0279 - acc: 0.055 - ETA: 1:05 - loss: 4.0263 - acc: 0.054 - ETA: 1:05 - loss: 4.0262 - acc: 0.052 - ETA: 1:05 - loss: 4.0348 - acc: 0.051 - ETA: 1:05 - loss: 4.0407 - acc: 0.050 - ETA: 1:05 - loss: 4.0443 - acc: 0.049 - ETA: 1:05 - loss: 4.0487 - acc: 0.048 - ETA: 1:05 - loss: 4.0512 - acc: 0.047 - ETA: 1:05 - loss: 4.0464 - acc: 0.051 - ETA: 1:05 - loss: 4.0473 - acc: 0.055 - ETA: 1:05 - loss: 4.0500 - acc: 0.054 - ETA: 1:05 - loss: 4.0490 - acc: 0.053 - ETA: 1:04 - loss: 4.0473 - acc: 0.052 - ETA: 1:04 - loss: 4.0482 - acc: 0.051 - ETA: 1:04 - loss: 4.0425 - acc: 0.055 - ETA: 1:04 - loss: 4.0476 - acc: 0.054 - ETA: 1:04 - loss: 4.0432 - acc: 0.053 - ETA: 1:04 - loss: 4.0402 - acc: 0.052 - ETA: 1:04 - loss: 4.0483 - acc: 0.051 - ETA: 1:04 - loss: 4.0505 - acc: 0.050 - ETA: 1:04 - loss: 4.0550 - acc: 0.049 - ETA: 1:04 - loss: 4.0488 - acc: 0.052 - ETA: 1:04 - loss: 4.0462 - acc: 0.052 - ETA: 1:04 - loss: 4.0499 - acc: 0.055 - ETA: 1:04 - loss: 4.0501 - acc: 0.058 - ETA: 1:04 - loss: 4.0541 - acc: 0.057 - ETA: 1:04 - loss: 4.0593 - acc: 0.056 - ETA: 1:04 - loss: 4.0697 - acc: 0.055 - ETA: 1:04 - loss: 4.0678 - acc: 0.054 - ETA: 1:03 - loss: 4.0646 - acc: 0.054 - ETA: 1:03 - loss: 4.0609 - acc: 0.053 - ETA: 1:03 - loss: 4.0583 - acc: 0.052 - ETA: 1:03 - loss: 4.0604 - acc: 0.051 - ETA: 1:03 - loss: 4.0608 - acc: 0.051 - ETA: 1:03 - loss: 4.0589 - acc: 0.050 - ETA: 1:03 - loss: 4.0579 - acc: 0.049 - ETA: 1:03 - loss: 4.0594 - acc: 0.049 - ETA: 1:03 - loss: 4.0630 - acc: 0.048 - ETA: 1:03 - loss: 4.0685 - acc: 0.047 - ETA: 1:03 - loss: 4.0700 - acc: 0.047 - ETA: 1:03 - loss: 4.0686 - acc: 0.049 - ETA: 1:03 - loss: 4.0684 - acc: 0.049 - ETA: 1:03 - loss: 4.0676 - acc: 0.048 - ETA: 1:03 - loss: 4.0748 - acc: 0.047 - ETA: 1:03 - loss: 4.0759 - acc: 0.047 - ETA: 1:03 - loss: 4.0814 - acc: 0.046 - ETA: 1:03 - loss: 4.0744 - acc: 0.049 - ETA: 1:03 - loss: 4.0746 - acc: 0.048 - ETA: 1:03 - loss: 4.0747 - acc: 0.048 - ETA: 1:02 - loss: 4.0663 - acc: 0.050 - ETA: 1:02 - loss: 4.0623 - acc: 0.049 - ETA: 1:02 - loss: 4.0595 - acc: 0.049 - ETA: 1:02 - loss: 4.0578 - acc: 0.048 - ETA: 1:02 - loss: 4.0617 - acc: 0.048 - ETA: 1:02 - loss: 4.0593 - acc: 0.047 - ETA: 1:02 - loss: 4.0622 - acc: 0.047 - ETA: 1:02 - loss: 4.0642 - acc: 0.046 - ETA: 1:02 - loss: 4 ...
# Epoch 3/10
# 2417/2418 [============================>.] - ETA: 1:08 - loss: 3.9360 - acc: 0.0000e+0 - ETA: 1:07 - loss: 3.6995 - acc: 0.0000e+0 - ETA: 1:07 - loss: 3.8961 - acc: 0.0000e+0 - ETA: 1:07 - loss: 3.7929 - acc: 0.0000e+0 - ETA: 1:07 - loss: 3.7789 - acc: 0.0000e+0 - ETA: 1:07 - loss: 3.5740 - acc: 0.0455    - ETA: 1:07 - loss: 3.5904 - acc: 0.038 - ETA: 1:07 - loss: 3.5699 - acc: 0.033 - ETA: 1:07 - loss: 3.4828 - acc: 0.058 - ETA: 1:07 - loss: 3.5074 - acc: 0.052 - ETA: 1:07 - loss: 3.6083 - acc: 0.047 - ETA: 1:08 - loss: 3.6365 - acc: 0.043 - ETA: 1:08 - loss: 3.5342 - acc: 0.080 - ETA: 1:08 - loss: 3.4737 - acc: 0.111 - ETA: 1:08 - loss: 3.4715 - acc: 0.103 - ETA: 1:07 - loss: 3.4616 - acc: 0.096 - ETA: 1:07 - loss: 3.4634 - acc: 0.106 - ETA: 1:07 - loss: 3.4086 - acc: 0.128 - ETA: 1:07 - loss: 3.4238 - acc: 0.135 - ETA: 1:07 - loss: 3.4369 - acc: 0.141 - ETA: 1:07 - loss: 3.4486 - acc: 0.134 - ETA: 1:07 - loss: 3.4056 - acc: 0.151 - ETA: 1:07 - loss: 3.4254 - acc: 0.155 - ETA: 1:07 - loss: 3.4740 - acc: 0.148 - ETA: 1:06 - loss: 3.5039 - acc: 0.153 - ETA: 1:06 - loss: 3.5151 - acc: 0.147 - ETA: 1:06 - loss: 3.5526 - acc: 0.141 - ETA: 1:06 - loss: 3.5369 - acc: 0.136 - ETA: 1:06 - loss: 3.5695 - acc: 0.140 - ETA: 1:06 - loss: 3.5667 - acc: 0.144 - ETA: 1:06 - loss: 3.5518 - acc: 0.147 - ETA: 1:06 - loss: 3.5520 - acc: 0.142 - ETA: 1:06 - loss: 3.5400 - acc: 0.138 - ETA: 1:06 - loss: 3.5303 - acc: 0.134 - ETA: 1:06 - loss: 3.5336 - acc: 0.130 - ETA: 1:06 - loss: 3.5331 - acc: 0.126 - ETA: 1:06 - loss: 3.5290 - acc: 0.123 - ETA: 1:06 - loss: 3.5418 - acc: 0.120 - ETA: 1:06 - loss: 3.5347 - acc: 0.123 - ETA: 1:06 - loss: 3.5338 - acc: 0.126 - ETA: 1:06 - loss: 3.5289 - acc: 0.129 - ETA: 1:06 - loss: 3.5275 - acc: 0.126 - ETA: 1:06 - loss: 3.5194 - acc: 0.129 - ETA: 1:06 - loss: 3.5174 - acc: 0.126 - ETA: 1:06 - loss: 3.5078 - acc: 0.129 - ETA: 1:05 - loss: 3.5017 - acc: 0.131 - ETA: 1:05 - loss: 3.5013 - acc: 0.129 - ETA: 1:05 - loss: 3.4993 - acc: 0.131 - ETA: 1:05 - loss: 3.5045 - acc: 0.128 - ETA: 1:05 - loss: 3.5149 - acc: 0.131 - ETA: 1:05 - loss: 3.5210 - acc: 0.128 - ETA: 1:05 - loss: 3.5203 - acc: 0.126 - ETA: 1:05 - loss: 3.5342 - acc: 0.123 - ETA: 1:05 - loss: 3.5258 - acc: 0.126 - ETA: 1:05 - loss: 3.5245 - acc: 0.123 - ETA: 1:05 - loss: 3.5198 - acc: 0.126 - ETA: 1:05 - loss: 3.5281 - acc: 0.123 - ETA: 1:05 - loss: 3.5230 - acc: 0.126 - ETA: 1:05 - loss: 3.5599 - acc: 0.123 - ETA: 1:04 - loss: 3.5528 - acc: 0.121 - ETA: 1:04 - loss: 3.5638 - acc: 0.119 - ETA: 1:04 - loss: 3.5628 - acc: 0.117 - ETA: 1:04 - loss: 3.5565 - acc: 0.116 - ETA: 1:04 - loss: 3.5491 - acc: 0.114 - ETA: 1:04 - loss: 3.5414 - acc: 0.112 - ETA: 1:04 - loss: 3.5438 - acc: 0.114 - ETA: 1:04 - loss: 3.5426 - acc: 0.112 - ETA: 1:04 - loss: 3.5351 - acc: 0.118 - ETA: 1:04 - loss: 3.5193 - acc: 0.124 - ETA: 1:04 - loss: 3.5146 - acc: 0.122 - ETA: 1:04 - loss: 3.5133 - acc: 0.120 - ETA: 1:04 - loss: 3.5155 - acc: 0.118 - ETA: 1:04 - loss: 3.5102 - acc: 0.120 - ETA: 1:04 - loss: 3.5048 - acc: 0.119 - ETA: 1:04 - loss: 3.5003 - acc: 0.120 - ETA: 1:03 - loss: 3.4895 - acc: 0.122 - ETA: 1:03 - loss: 3.4764 - acc: 0.124 - ETA: 1:03 - loss: 3.4667 - acc: 0.125 - ETA: 1:03 - loss: 3.4881 - acc: 0.124 - ETA: 1:03 - loss: 3.4952 - acc: 0.122 - ETA: 1:03 - loss: 3.5134 - acc: 0.121 - ETA: 1:03 - loss: 3.5013 - acc: 0.128 - ETA: 1:03 - loss: 3.5023 - acc: 0.127 - ETA: 1:03 - loss: 3.5047 - acc: 0.125 - ETA: 1:03 - loss: 3.4966 - acc: 0.130 - ETA: 1:03 - loss: 3.4951 - acc: 0.131 - ETA: 1:03 - loss: 3.4955 - acc: 0.130 - ETA: 1:03 - loss: 3.4821 - acc: 0.131 - ETA: 1:03 - loss: 3.4890 - acc: 0.129 - ETA: 1:03 - loss: 3.4896 - acc: 0.128 - ETA: 1:03 - loss: 3.4938 - acc: 0.127 - ETA: 1:03 - loss: 3.4887 - acc: 0.125 - ETA: 1:03 - loss: 3.4919 - acc: 0.124 - ETA: 1:02 - loss: 3.4871 - acc: 0.125 - ETA: 1:02 - loss: 3.4983 - acc: 0.124 - ETA: 1:02 - loss: 3.5031 - acc: 0.125 - ETA: 1:02 - loss: 3.5047 - acc: 0.126 - ETA: 1:02 - loss: 3.4929 - acc: 0.130 - ETA: 1:02 - ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# In  [28]:
# Line 8:     callbacks=callbacks)
#
# File /home/cnytync/Dev/anaconda3/envs/Python36/lib/python3.6/site-packages/keras/engine/training.py, in fit:
# Line 1226:  _use_cached_eval_dataset=True)
#
# File /home/cnytync/Dev/anaconda3/envs/Python36/lib/python3.6/site-packages/keras/engine/training.py, in evaluate:
# Line 1501:  tmp_logs = self.test_function(iterator)
#
# File /home/cnytync/Dev/anaconda3/envs/Python36/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py, in __call__:
# Line 885:   result = self._call(*args, **kwds)
#
# File /home/cnytync/Dev/anaconda3/envs/Python36/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py, in _call:
# Line 924:   results = self._stateful_fn(*args, **kwds)
#
# File /home/cnytync/Dev/anaconda3/envs/Python36/lib/python3.6/site-packages/tensorflow/python/eager/function.py, in __call__:
# Line 3040:  filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#
# File /home/cnytync/Dev/anaconda3/envs/Python36/lib/python3.6/site-packages/tensorflow/python/eager/function.py, in _call_flat:
# Line 1964:  ctx, args, cancellation_manager=cancellation_manager))
#
# File /home/cnytync/Dev/anaconda3/envs/Python36/lib/python3.6/site-packages/tensorflow/python/eager/function.py, in call:
# Line 596:   ctx=ctx)
#
# File /home/cnytync/Dev/anaconda3/envs/Python36/lib/python3.6/site-packages/tensorflow/python/eager/execute.py, in quick_execute:
# Line 60:    inputs, attrs, num_outputs)
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------

# %%
x = embedding_layer(main_input)
x = CuDNNLSTM(LSTM_HIDDEN_SIZE, return_sequences=True)(x)
Avg = keras.layers.core.Lambda(lambda x: K.mean(x, axis=1), output_shape=(LSTM_HIDDEN_SIZE,))
x = Avg(x)
x = Dense(LSTM_HIDDEN_SIZE)(x)
main_lstm_out = Activation('relu')(x)


lstm_hidden_and_entity = Concatenate(axis=0)([Transpose(main_lstm_out), the_entity])
# lstm_hidden_and_entity = the_entity
print("lstm_hidden_and_entity", K.int_shape(lstm_hidden_and_entity))
# input("continue?")

final_output = Dense(units=len(unique_labels), activation='softmax')(Transpose(lstm_hidden_and_entity))

optimizer = Adam(lr=LEARNING_RATE, clipvalue=0.25)

m2 = Model(inputs=main_input, outputs=final_output)

m2.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['acc'])

_, tmpfn = tempfile.mkstemp()
# Save the best model during validation and bail out of training early if we're not improving
callbacks = [ModelCheckpoint(tmpfn, monitor='val_acc', save_best_only=True, save_weights_only=True)]

m2.summary()

from tensorflow.keras.utils import plot_model
# plot_model(m, to_file='model.png')

_, tmpfn = tempfile.mkstemp()
# Save the best model during validation and bail out of training early if we're not improving
callbacks = [ModelCheckpoint(tmpfn,monitor='val_acc', save_best_only=True, save_weights_only=True)]

# %%
# Restore the best found model during validation
# m.load_weights(tmpfn)

loss, acc = m2.evaluate(x_test, y_test, batch_size=BATCH_SIZE)
print('Test loss / test accuracy = {:.4f} / {:.4f}'.format(loss, acc))

preds = m2.predict(x_test, batch_size=BATCH_SIZE, verbose=0,
                  steps=None)

def get_result_labels(results):
    return [unique_labels[np.where(row==max(row))[0][0]] for row in results]

result_labels = get_result_labels(preds)

print('Accuracy score: %.2f' % accuracy_score(result_labels, y_str_test))
print(classification_report(y_str_test, result_labels))

# %% [markdown]
# ### PREPARE NEURAL NET MODEL CONV1D

# %%
# embedding_clusters_1d = tf.random.normal([20,2585,100])
embedding_clusters_1d.shape
# Out:
# (20, 2585, 100)

# %%
LSTM_HIDDEN_SIZE = 200
LEARNING_RATE = 0.001
KG_EMBEDDING_DIM = 44

# load pre-trained word embeddings into an Embedding layer
# note that we set trainable = False so as to keep the embeddings fixed
embedding_layer = Embedding(num_words,
                            EMBEDDING_DIM,
                            weights=[embedding_matrix],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

print('Preparing model.')

entity_clusters = K.variable(embedding_clusters_1d)

Avg = keras.layers.core.Lambda(lambda x: K.mean(x, axis=1))  # , output_shape=(KG_EMBEDDING_DIM, ))
DotProduct = keras.layers.core.Lambda(lambda x: K.dot(x[0], x[1]))  # , output_shape=(KG_EMBEDDING_DIM, ))
Sum = keras.layers.core.Lambda(lambda x: K.sum(x, axis=1))  # , output_shape=(KG_EMBEDDING_DIM, ))
RemoveLastCol = keras.layers.core.Lambda(lambda x: K.sum(x, axis=-1))
Transpose = keras.layers.core.Lambda(lambda x: K.transpose(x))
FakeEClusterIn = keras.layers.core.Lambda(lambda x: embedding_clusters_1d)

main_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32', name='main_input')

x = embedding_layer(main_input)
x = CuDNNLSTM(KG_EMBEDDING_DIM, return_sequences=True)(x)
x = Avg(x)
x = Dense(KG_EMBEDDING_DIM)(x)
x = Activation('relu')(x)
# entity_extraction = Reshape([KG_EMBEDDING_DIM])(x)
entity_extraction = Transpose(x)
# entity_extraction = x
print("entity_extraction(after transpose)", K.int_shape(entity_extraction))

x = embedding_layer(main_input)
x = CuDNNLSTM(LSTM_HIDDEN_SIZE, return_sequences=True)(x)
Avg = keras.layers.core.Lambda(lambda x: K.mean(x, axis=1), output_shape=(LSTM_HIDDEN_SIZE,))
x = Avg(x)
x = Dense(LSTM_HIDDEN_SIZE)(x)
main_lstm_out = Activation('relu')(x)
print("main_lstm_out", K.int_shape(main_lstm_out))

# get representation for entity clusters
# e_clusters = Input(tensor=entity_clusters,name='e_clusters')
x = FakeEClusterIn(x)
print("FakeEClusterIn", K.int_shape(x))
# x = e_clusters
x = Conv1D(filters=1, kernel_size=3, strides=3, input_shape=embedding_clusters_1d.shape[1:])(x)
x = MaxPooling1D(pool_size=3, strides=3)(x)
x = Conv1D(filters=1, kernel_size=2, strides=2)(x)
x = MaxPooling1D(pool_size=2, strides=1)(x)
print("Before removing last col", K.int_shape(x))
x = RemoveLastCol(x)
print("after removing last col", K.int_shape(x))
entity_cluster_reps = Reshape([KG_EMBEDDING_DIM], name='entity_cluster_reps')(x)
# entity_cluster_reps = x
print("entity_cluster_reps(after reshape)", K.int_shape(entity_cluster_reps))

# attention over entities
att_scores = DotProduct([entity_cluster_reps, entity_extraction])
print("att_scores_entities", K.int_shape(att_scores))
# att_normalized = Activation('softmax',name='entity_attention')(att_scores)
att_normalized = Softmax(axis=-1, name='entity_attention')(att_scores)
print("att_normalized", K.int_shape(att_normalized))
the_entity = DotProduct([Transpose(entity_cluster_reps), att_normalized])
print("the_entity", K.int_shape(the_entity))

lstm_hidden_and_entity = Concatenate(axis=0)([Transpose(main_lstm_out), the_entity])
# lstm_hidden_and_entity = the_entity
print("lstm_hidden_and_entity", K.int_shape(lstm_hidden_and_entity))
# input("continue?")

final_output = Dense(units=len(unique_labels), activation='softmax')(Transpose(lstm_hidden_and_entity))

optimizer = Adam(lr=LEARNING_RATE, clipvalue=0.25)

m = Model(inputs=main_input, outputs=final_output)

m.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['acc'])

_, tmpfn = tempfile.mkstemp()
# Save the best model during validation and bail out of training early if we're not improving
callbacks = [ModelCheckpoint(tmpfn, monitor='val_acc', save_best_only=True, save_weights_only=True)]

m.summary()

from tensorflow.keras.utils import plot_model
# plot_model(m, to_file='model.png')

_, tmpfn = tempfile.mkstemp()
# Save the best model during validation and bail out of training early if we're not improving
callbacks = [ModelCheckpoint(tmpfn,monitor='val_acc', save_best_only=True, save_weights_only=True)]
# Out:
# Preparing model.
# entity_extraction(after transpose) (44, None)
# main_lstm_out (None, 200)
# FakeEClusterIn (20, 827, 100)
# Before removing last col (20, 44, 1)
# after removing last col (20, 44)
# entity_cluster_reps(after reshape) (20, 44)
# att_scores_entities (20, None)
# att_normalized (20, None)
# the_entity (44, None)
# lstm_hidden_and_entity (244, None)
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input (InputLayer)         [(None, 300)]        0
# __________________________________________________________________________________________________
# embedding_12 (Embedding)        (None, 300, 300)     6000000     main_input[0][0]
#                                                                  main_input[0][0]
# __________________________________________________________________________________________________
# cu_dnnlstm_25 (CuDNNLSTM)       (None, 300, 200)     401600      embedding_12[1][0]
# __________________________________________________________________________________________________
# lambda_90 (Lambda)              (None, 200)          0           cu_dnnlstm_25[0][0]
# __________________________________________________________________________________________________
# dense_31 (Dense)                (None, 200)          40200       lambda_90[0][0]
# __________________________________________________________________________________________________
# lambda_89 (Lambda)              (20, 827, 100)       0           dense_31[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (20, 275, 1)         301         lambda_89[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_24 (MaxPooling1D) (20, 91, 1)          0           conv1d_24[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (20, 45, 1)          3           max_pooling1d_24[0][0]
# __________________________________________________________________________________________________
# cu_dnnlstm_24 (CuDNNLSTM)       (None, 300, 44)      60896       embedding_12[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_25 (MaxPooling1D) (20, 44, 1)          0           conv1d_25[0][0]
# __________________________________________________________________________________________________
# lambda_84 (Lambda)              (None, 44)           0           cu_dnnlstm_24[0][0]
# __________________________________________________________________________________________________
# lambda_87 (Lambda)              (20, 44)             0           max_pooling1d_25[0][0]
# __________________________________________________________________________________________________
# dense_30 (Dense)                (None, 44)           1980        lambda_84[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 200)          0           dense_31[0][0]
# __________________________________________________________________________________________________
# entity_cluster_reps (Reshape)   (20, 44)             0           lambda_87[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 44)           0           dense_30[0][0]
# __________________________________________________________________________________________________
# lambda_88 (Lambda)              multiple             0           activation_24[0][0]
#                                                                  entity_cluster_reps[0][0]
#                                                                  activation_25[0][0]
#                                                                  concatenate_6[0][0]
# __________________________________________________________________________________________________
# lambda_85 (Lambda)              multiple             0           entity_cluster_reps[0][0]
#                                                                  lambda_88[0][0]
#                                                                  lambda_88[1][0]
#                                                                  entity_attention[0][0]
# __________________________________________________________________________________________________
# entity_attention (Softmax)      (20, None)           0           lambda_85[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (244, None)          0           lambda_88[2][0]
#                                                                  lambda_85[1][0]
# __________________________________________________________________________________________________
# dense_32 (Dense)                (None, 78)           19110       lambda_88[3][0]
# ==================================================================================================
# Total params: 6,524,090
# Trainable params: 524,090
# Non-trainable params: 6,000,000
# __________________________________________________________________________________________________

# %% [markdown]
# ### PREDICT CONV1D

# %%
BATCH_SIZE = 2
NUM_EPOCHS = 10

history = m.fit(x_train, y_train,
                batch_size=BATCH_SIZE,
                epochs=NUM_EPOCHS,
                validation_data=(x_val, y_val), 
                callbacks=callbacks)
# m.save('node2vec_lstm_model')
# Out:
# Epoch 1/10
# WARNING:tensorflow:Gradients do not exist for variables ['cu_dnnlstm_1/kernel:0', 'cu_dnnlstm_1/recurrent_kernel:0', 'cu_dnnlstm_1/bias:0', 'dense_1/kernel:0', 'dense_1/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['cu_dnnlstm_1/kernel:0', 'cu_dnnlstm_1/recurrent_kernel:0', 'cu_dnnlstm_1/bias:0', 'dense_1/kernel:0', 'dense_1/bias:0'] when minimizing the loss.
# 2418/2418 [==============================] - ETA: 1:53:45 - loss: 3.5129 - acc: 0.0000e+ - ETA: 25s - loss: 5.6136 - acc: 0.0000e+00   - ETA: 23s - loss: 5.0456 - acc: 0.0000e+ - ETA: 22s - loss: 5.1064 - acc: 0.0263   - ETA: 22s - loss: 4.9897 - acc: 0.04 - ETA: 22s - loss: 4.9160 - acc: 0.05 - ETA: 23s - loss: 4.8433 - acc: 0.04 - ETA: 23s - loss: 4.8403 - acc: 0.03 - ETA: 23s - loss: 4.8297 - acc: 0.03 - ETA: 23s - loss: 4.7921 - acc: 0.02 - ETA: 22s - loss: 4.7696 - acc: 0.02 - ETA: 22s - loss: 4.7518 - acc: 0.02 - ETA: 22s - loss: 4.7202 - acc: 0.02 - ETA: 22s - loss: 4.7041 - acc: 0.01 - ETA: 22s - loss: 4.6982 - acc: 0.01 - ETA: 22s - loss: 4.6798 - acc: 0.01 - ETA: 22s - loss: 4.6636 - acc: 0.02 - ETA: 22s - loss: 4.6576 - acc: 0.02 - ETA: 22s - loss: 4.6300 - acc: 0.01 - ETA: 22s - loss: 4.6003 - acc: 0.02 - ETA: 22s - loss: 4.5751 - acc: 0.02 - ETA: 22s - loss: 4.5623 - acc: 0.02 - ETA: 22s - loss: 4.5686 - acc: 0.02 - ETA: 22s - loss: 4.5674 - acc: 0.02 - ETA: 21s - loss: 4.5488 - acc: 0.02 - ETA: 21s - loss: 4.5398 - acc: 0.02 - ETA: 21s - loss: 4.5313 - acc: 0.01 - ETA: 21s - loss: 4.5253 - acc: 0.01 - ETA: 21s - loss: 4.5229 - acc: 0.01 - ETA: 21s - loss: 4.5206 - acc: 0.01 - ETA: 21s - loss: 4.5144 - acc: 0.01 - ETA: 21s - loss: 4.5131 - acc: 0.01 - ETA: 21s - loss: 4.5050 - acc: 0.01 - ETA: 21s - loss: 4.5119 - acc: 0.01 - ETA: 21s - loss: 4.5074 - acc: 0.01 - ETA: 21s - loss: 4.5036 - acc: 0.01 - ETA: 21s - loss: 4.5018 - acc: 0.01 - ETA: 21s - loss: 4.4973 - acc: 0.01 - ETA: 21s - loss: 4.4951 - acc: 0.01 - ETA: 21s - loss: 4.4913 - acc: 0.01 - ETA: 21s - loss: 4.4818 - acc: 0.01 - ETA: 21s - loss: 4.4772 - acc: 0.01 - ETA: 21s - loss: 4.4754 - acc: 0.01 - ETA: 20s - loss: 4.4727 - acc: 0.01 - ETA: 20s - loss: 4.4717 - acc: 0.01 - ETA: 20s - loss: 4.4689 - acc: 0.01 - ETA: 20s - loss: 4.4688 - acc: 0.01 - ETA: 20s - loss: 4.4630 - acc: 0.01 - ETA: 20s - loss: 4.4624 - acc: 0.01 - ETA: 20s - loss: 4.4588 - acc: 0.01 - ETA: 20s - loss: 4.4566 - acc: 0.01 - ETA: 20s - loss: 4.4514 - acc: 0.01 - ETA: 20s - loss: 4.4446 - acc: 0.01 - ETA: 20s - loss: 4.4441 - acc: 0.01 - ETA: 20s - loss: 4.4445 - acc: 0.01 - ETA: 20s - loss: 4.4445 - acc: 0.01 - ETA: 20s - loss: 4.4447 - acc: 0.01 - ETA: 20s - loss: 4.4410 - acc: 0.01 - ETA: 20s - loss: 4.4391 - acc: 0.01 - ETA: 20s - loss: 4.4386 - acc: 0.01 - ETA: 19s - loss: 4.4402 - acc: 0.01 - ETA: 20s - loss: 4.4398 - acc: 0.01 - ETA: 20s - loss: 4.4364 - acc: 0.01 - ETA: 20s - loss: 4.4379 - acc: 0.01 - ETA: 20s - loss: 4.4350 - acc: 0.01 - ETA: 20s - loss: 4.4345 - acc: 0.01 - ETA: 20s - loss: 4.4349 - acc: 0.01 - ETA: 20s - loss: 4.4325 - acc: 0.01 - ETA: 20s - loss: 4.4330 - acc: 0.01 - ETA: 19s - loss: 4.4295 - acc: 0.01 - ETA: 19s - loss: 4.4262 - acc: 0.01 - ETA: 19s - loss: 4.4271 - acc: 0.01 - ETA: 19s - loss: 4.4242 - acc: 0.01 - ETA: 19s - loss: 4.4216 - acc: 0.01 - ETA: 19s - loss: 4.4190 - acc: 0.01 - ETA: 19s - loss: 4.4154 - acc: 0.01 - ETA: 19s - loss: 4.4172 - acc: 0.01 - ETA: 19s - loss: 4.4177 - acc: 0.01 - ETA: 19s - loss: 4.4156 - acc: 0.01 - ETA: 19s - loss: 4.4142 - acc: 0.01 - ETA: 19s - loss: 4.4161 - acc: 0.01 - ETA: 19s - loss: 4.4161 - acc: 0.01 - ETA: 19s - loss: 4.4171 - acc: 0.00 - ETA: 19s - loss: 4.4143 - acc: 0.00 - ETA: 19s - loss: 4.4112 - acc: 0.01 - ETA: 19s - loss: 4.4067 - acc: 0.01 - ETA: 19s - loss: 4.4026 - acc: 0.01 - ETA: 19s - loss: 4.4044 - acc: 0.01 - ETA: 19s - loss: 4.4042 - acc: 0.01 - ETA: 19s - loss: 4.4034 - acc: 0.01 - ETA: 18s - loss: 4.4023 - acc: 0.01 - ETA: 18s - loss: 4.3998 - acc: 0.01 - ETA: 18s - loss: 4.3964 - acc: 0.01 - ETA: 18s - loss: 4.3949 - acc: 0.01 - ETA: 18s - loss: 4.3929 - acc: 0.01 - ETA: 18s - loss: 4.3893 - acc: 0.01 - ETA: 18s - loss: 4.3885 - acc: 0.01 - ETA: 18s - loss: 4.3864 - acc: 0.01 - ETA: 18s - loss: 4.3868 - acc: 0.01 - ETA: 18s - loss: 4.3853 - acc: 0.01 - ETA: 18s - loss: 4.3837 - acc: 0.01 - ETA: 18s - loss: 4.3851 - acc: 0.01 - ETA: 18s - loss: 4.3836 - acc: 0.01 - ETA: 18s - loss:  ...
# Epoch 2/10
# 1584/2418 [==================>...........] - ETA: 26s - loss: 3.6419 - acc: 0.50 - ETA: 28s - loss: 3.9844 - acc: 0.08 - ETA: 28s - loss: 3.9936 - acc: 0.09 - ETA: 27s - loss: 4.0489 - acc: 0.06 - ETA: 28s - loss: 4.0484 - acc: 0.04 - ETA: 27s - loss: 4.0773 - acc: 0.03 - ETA: 27s - loss: 4.0827 - acc: 0.03 - ETA: 26s - loss: 4.0833 - acc: 0.02 - ETA: 26s - loss: 4.0771 - acc: 0.03 - ETA: 26s - loss: 4.0567 - acc: 0.04 - ETA: 27s - loss: 4.0487 - acc: 0.03 - ETA: 26s - loss: 4.0727 - acc: 0.03 - ETA: 26s - loss: 4.0660 - acc: 0.03 - ETA: 26s - loss: 4.0479 - acc: 0.02 - ETA: 26s - loss: 4.0518 - acc: 0.03 - ETA: 25s - loss: 4.0670 - acc: 0.03 - ETA: 25s - loss: 4.0661 - acc: 0.03 - ETA: 25s - loss: 4.0679 - acc: 0.03 - ETA: 25s - loss: 4.0799 - acc: 0.03 - ETA: 25s - loss: 4.0894 - acc: 0.03 - ETA: 25s - loss: 4.0853 - acc: 0.03 - ETA: 25s - loss: 4.0946 - acc: 0.03 - ETA: 24s - loss: 4.0997 - acc: 0.03 - ETA: 24s - loss: 4.0960 - acc: 0.03 - ETA: 24s - loss: 4.0956 - acc: 0.03 - ETA: 24s - loss: 4.0857 - acc: 0.03 - ETA: 24s - loss: 4.0857 - acc: 0.03 - ETA: 24s - loss: 4.0864 - acc: 0.03 - ETA: 24s - loss: 4.0900 - acc: 0.04 - ETA: 24s - loss: 4.0967 - acc: 0.03 - ETA: 23s - loss: 4.0935 - acc: 0.04 - ETA: 23s - loss: 4.0963 - acc: 0.03 - ETA: 23s - loss: 4.0972 - acc: 0.04 - ETA: 23s - loss: 4.0961 - acc: 0.03 - ETA: 23s - loss: 4.0964 - acc: 0.03 - ETA: 23s - loss: 4.0992 - acc: 0.03 - ETA: 23s - loss: 4.0955 - acc: 0.03 - ETA: 22s - loss: 4.0923 - acc: 0.03 - ETA: 22s - loss: 4.0954 - acc: 0.03 - ETA: 22s - loss: 4.0917 - acc: 0.04 - ETA: 22s - loss: 4.0877 - acc: 0.04 - ETA: 22s - loss: 4.0919 - acc: 0.04 - ETA: 22s - loss: 4.0938 - acc: 0.04 - ETA: 22s - loss: 4.0908 - acc: 0.04 - ETA: 22s - loss: 4.0944 - acc: 0.04 - ETA: 22s - loss: 4.0913 - acc: 0.04 - ETA: 22s - loss: 4.0896 - acc: 0.04 - ETA: 22s - loss: 4.0907 - acc: 0.04 - ETA: 21s - loss: 4.0904 - acc: 0.04 - ETA: 22s - loss: 4.0895 - acc: 0.04 - ETA: 21s - loss: 4.0922 - acc: 0.04 - ETA: 21s - loss: 4.0921 - acc: 0.03 - ETA: 21s - loss: 4.0945 - acc: 0.03 - ETA: 21s - loss: 4.0970 - acc: 0.03 - ETA: 21s - loss: 4.0941 - acc: 0.04 - ETA: 21s - loss: 4.0962 - acc: 0.04 - ETA: 21s - loss: 4.0926 - acc: 0.04 - ETA: 21s - loss: 4.0915 - acc: 0.04 - ETA: 21s - loss: 4.0902 - acc: 0.04 - ETA: 21s - loss: 4.0927 - acc: 0.04 - ETA: 21s - loss: 4.0916 - acc: 0.04 - ETA: 21s - loss: 4.0886 - acc: 0.04 - ETA: 21s - loss: 4.0889 - acc: 0.04 - ETA: 21s - loss: 4.0922 - acc: 0.04 - ETA: 21s - loss: 4.0939 - acc: 0.04 - ETA: 21s - loss: 4.0963 - acc: 0.04 - ETA: 21s - loss: 4.0922 - acc: 0.04 - ETA: 21s - loss: 4.0933 - acc: 0.04 - ETA: 20s - loss: 4.0938 - acc: 0.04 - ETA: 20s - loss: 4.0941 - acc: 0.04 - ETA: 20s - loss: 4.0941 - acc: 0.04 - ETA: 20s - loss: 4.0939 - acc: 0.04 - ETA: 20s - loss: 4.0923 - acc: 0.04 - ETA: 20s - loss: 4.0942 - acc: 0.04 - ETA: 20s - loss: 4.0917 - acc: 0.04 - ETA: 20s - loss: 4.0907 - acc: 0.04 - ETA: 20s - loss: 4.0897 - acc: 0.04 - ETA: 20s - loss: 4.0972 - acc: 0.04 - ETA: 20s - loss: 4.0954 - acc: 0.04 - ETA: 20s - loss: 4.0975 - acc: 0.04 - ETA: 20s - loss: 4.0970 - acc: 0.04 - ETA: 20s - loss: 4.0938 - acc: 0.04 - ETA: 20s - loss: 4.0921 - acc: 0.04 - ETA: 20s - loss: 4.0916 - acc: 0.04 - ETA: 20s - loss: 4.0884 - acc: 0.04 - ETA: 20s - loss: 4.0887 - acc: 0.04 - ETA: 20s - loss: 4.0882 - acc: 0.04 - ETA: 20s - loss: 4.0886 - acc: 0.04 - ETA: 20s - loss: 4.0909 - acc: 0.04 - ETA: 20s - loss: 4.0908 - acc: 0.04 - ETA: 19s - loss: 4.0905 - acc: 0.04 - ETA: 19s - loss: 4.0898 - acc: 0.04 - ETA: 19s - loss: 4.0887 - acc: 0.04 - ETA: 19s - loss: 4.0904 - acc: 0.04 - ETA: 19s - loss: 4.0887 - acc: 0.04 - ETA: 19s - loss: 4.0889 - acc: 0.04 - ETA: 19s - loss: 4.0886 - acc: 0.04 - ETA: 19s - loss: 4.0899 - acc: 0.04 - ETA: 19s - loss: 4.0891 - acc: 0.04 - ETA: 19s - loss: 4.0883 - acc: 0.04 - ETA: 19s - loss: 4.0887 - acc: 0.04 - ETA: 19s - loss: 4.0870 - acc: 0.04 - ETA: 19s - loss: 4.0867 - acc: 0.04 - ETA: 19s - loss: 4.0880 - acc: 0.04 - ETA ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# In  [16]:
# Line 8:     callbacks=callbacks)
#
# File /home/cnytync/Dev/anaconda3/envs/Python36/lib/python3.6/site-packages/keras/engine/training.py, in fit:
# Line 1184:  tmp_logs = self.train_function(iterator)
#
# File /home/cnytync/Dev/anaconda3/envs/Python36/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py, in __call__:
# Line 885:   result = self._call(*args, **kwds)
#
# File /home/cnytync/Dev/anaconda3/envs/Python36/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py, in _call:
# Line 917:   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#
# File /home/cnytync/Dev/anaconda3/envs/Python36/lib/python3.6/site-packages/tensorflow/python/eager/function.py, in __call__:
# Line 3040:  filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#
# File /home/cnytync/Dev/anaconda3/envs/Python36/lib/python3.6/site-packages/tensorflow/python/eager/function.py, in _call_flat:
# Line 1964:  ctx, args, cancellation_manager=cancellation_manager))
#
# File /home/cnytync/Dev/anaconda3/envs/Python36/lib/python3.6/site-packages/tensorflow/python/eager/function.py, in call:
# Line 596:   ctx=ctx)
#
# File /home/cnytync/Dev/anaconda3/envs/Python36/lib/python3.6/site-packages/tensorflow/python/eager/execute.py, in quick_execute:
# Line 60:    inputs, attrs, num_outputs)
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------

# %%
# Restore the best found model during validation
# m.load_weights(tmpfn)

loss, acc = m.evaluate(x_test, y_test, batch_size=BATCH_SIZE)
print('Test loss / test accuracy = {:.4f} / {:.4f}'.format(loss, acc))
# Out:
# 605/605 [==============================] - ETA: 15s - loss: 1.5139e-05 - acc: 1.00 - ETA: 7s - loss: 2.7896 - acc: 0.5000     - ETA: 7s - loss: 1.7440 - acc: 0.681 - ETA: 6s - loss: 2.5087 - acc: 0.625 - ETA: 6s - loss: 2.4329 - acc: 0.642 - ETA: 6s - loss: 2.7014 - acc: 0.596 - ETA: 6s - loss: 2.6991 - acc: 0.596 - ETA: 6s - loss: 2.6376 - acc: 0.597 - ETA: 6s - loss: 2.3546 - acc: 0.634 - ETA: 6s - loss: 2.3133 - acc: 0.652 - ETA: 6s - loss: 2.2076 - acc: 0.647 - ETA: 6s - loss: 2.1066 - acc: 0.642 - ETA: 6s - loss: 1.9704 - acc: 0.655 - ETA: 5s - loss: 1.9482 - acc: 0.659 - ETA: 5s - loss: 1.9340 - acc: 0.662 - ETA: 5s - loss: 1.9714 - acc: 0.664 - ETA: 5s - loss: 1.9631 - acc: 0.666 - ETA: 5s - loss: 1.9490 - acc: 0.662 - ETA: 5s - loss: 2.0060 - acc: 0.653 - ETA: 5s - loss: 2.0442 - acc: 0.651 - ETA: 5s - loss: 2.0696 - acc: 0.638 - ETA: 5s - loss: 2.0571 - acc: 0.646 - ETA: 5s - loss: 2.1445 - acc: 0.630 - ETA: 5s - loss: 2.1266 - acc: 0.633 - ETA: 5s - loss: 2.1215 - acc: 0.632 - ETA: 5s - loss: 2.1241 - acc: 0.634 - ETA: 5s - loss: 2.0742 - acc: 0.641 - ETA: 5s - loss: 2.0657 - acc: 0.639 - ETA: 4s - loss: 2.0185 - acc: 0.638 - ETA: 4s - loss: 1.9699 - acc: 0.643 - ETA: 4s - loss: 1.9481 - acc: 0.645 - ETA: 4s - loss: 1.9309 - acc: 0.647 - ETA: 4s - loss: 1.9521 - acc: 0.642 - ETA: 4s - loss: 1.9357 - acc: 0.638 - ETA: 4s - loss: 1.9248 - acc: 0.640 - ETA: 4s - loss: 1.9080 - acc: 0.642 - ETA: 4s - loss: 1.9023 - acc: 0.643 - ETA: 4s - loss: 1.8934 - acc: 0.642 - ETA: 4s - loss: 1.8535 - acc: 0.650 - ETA: 4s - loss: 1.9026 - acc: 0.646 - ETA: 4s - loss: 1.9445 - acc: 0.642 - ETA: 4s - loss: 1.9660 - acc: 0.641 - ETA: 4s - loss: 1.9580 - acc: 0.640 - ETA: 4s - loss: 1.9381 - acc: 0.644 - ETA: 4s - loss: 1.9256 - acc: 0.647 - ETA: 4s - loss: 1.9243 - acc: 0.646 - ETA: 4s - loss: 1.8851 - acc: 0.654 - ETA: 3s - loss: 1.8563 - acc: 0.657 - ETA: 3s - loss: 1.8419 - acc: 0.662 - ETA: 3s - loss: 1.8515 - acc: 0.661 - ETA: 3s - loss: 1.8252 - acc: 0.664 - ETA: 3s - loss: 1.8285 - acc: 0.664 - ETA: 3s - loss: 1.8362 - acc: 0.661 - ETA: 3s - loss: 1.8159 - acc: 0.662 - ETA: 3s - loss: 1.8097 - acc: 0.661 - ETA: 3s - loss: 1.8124 - acc: 0.661 - ETA: 3s - loss: 1.7989 - acc: 0.662 - ETA: 3s - loss: 1.7843 - acc: 0.666 - ETA: 3s - loss: 1.7716 - acc: 0.667 - ETA: 3s - loss: 1.7596 - acc: 0.669 - ETA: 3s - loss: 1.7485 - acc: 0.670 - ETA: 3s - loss: 1.7464 - acc: 0.667 - ETA: 3s - loss: 1.7269 - acc: 0.671 - ETA: 3s - loss: 1.7405 - acc: 0.671 - ETA: 3s - loss: 1.7446 - acc: 0.671 - ETA: 3s - loss: 1.7418 - acc: 0.667 - ETA: 2s - loss: 1.7422 - acc: 0.665 - ETA: 2s - loss: 1.7377 - acc: 0.664 - ETA: 2s - loss: 1.7300 - acc: 0.664 - ETA: 2s - loss: 1.7665 - acc: 0.660 - ETA: 2s - loss: 1.7571 - acc: 0.662 - ETA: 2s - loss: 1.7693 - acc: 0.664 - ETA: 2s - loss: 1.7907 - acc: 0.662 - ETA: 2s - loss: 1.7983 - acc: 0.661 - ETA: 2s - loss: 1.8136 - acc: 0.660 - ETA: 2s - loss: 1.8158 - acc: 0.661 - ETA: 2s - loss: 1.8269 - acc: 0.660 - ETA: 2s - loss: 1.8137 - acc: 0.659 - ETA: 2s - loss: 1.8149 - acc: 0.660 - ETA: 2s - loss: 1.8027 - acc: 0.662 - ETA: 2s - loss: 1.8031 - acc: 0.661 - ETA: 2s - loss: 1.8177 - acc: 0.658 - ETA: 2s - loss: 1.8240 - acc: 0.656 - ETA: 2s - loss: 1.8648 - acc: 0.655 - ETA: 1s - loss: 1.8449 - acc: 0.659 - ETA: 1s - loss: 1.8375 - acc: 0.661 - ETA: 1s - loss: 1.8481 - acc: 0.658 - ETA: 1s - loss: 1.8571 - acc: 0.657 - ETA: 1s - loss: 1.8756 - acc: 0.655 - ETA: 1s - loss: 1.8606 - acc: 0.657 - ETA: 1s - loss: 1.8736 - acc: 0.654 - ETA: 1s - loss: 1.8785 - acc: 0.653 - ETA: 1s - loss: 1.8846 - acc: 0.653 - ETA: 1s - loss: 1.8755 - acc: 0.653 - ETA: 1s - loss: 1.8874 - acc: 0.650 - ETA: 1s - loss: 1.8853 - acc: 0.649 - ETA: 1s - loss: 1.8780 - acc: 0.649 - ETA: 1s - loss: 1.8668 - acc: 0.650 - ETA: 1s - loss: 1.8694 - acc: 0.650 - ETA: 1s - loss: 1.8612 - acc: 0.651 - ETA: 1s - loss: 1.8670 - acc: 0.650 - ETA: 1s - loss: 1.8624 - acc: 0.650 - ETA: 1s - loss: 1.8534 - acc: 0.652 - ETA: 0s - loss: 1.8456 - acc: 0.65 ...
# Test loss / test accuracy = 1.8339 / 0.6510

# %%
preds = m.predict(x_test, batch_size=BATCH_SIZE, verbose=0,
                  steps=None)

# %%
def get_result_labels(results):
    return [unique_labels[np.where(row==max(row))[0][0]] for row in results]

result_labels = get_result_labels(preds)

print('Accuracy score: %.2f' % accuracy_score(result_labels, y_str_test))
print(classification_report(y_str_test, result_labels))
# Out:
# Accuracy score: 0.65
# /home/cnytync/Dev/anaconda3/envs/Python36/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/cnytync/Dev/anaconda3/envs/Python36/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/cnytync/Dev/anaconda3/envs/Python36/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                               precision    recall  f1-score   support
#
#                 Architecture       0.93      0.87      0.90        15
#       Architecture-Structure       0.74      0.93      0.82        15
#                   Art-Cinema       0.73      0.57      0.64        14
#             Art-Cinema-Actor       0.19      0.17      0.18        18
#                    Art-Dance       1.00      0.77      0.87        13
#             Art-Dance-Dancer       0.61      0.74      0.67        19
#                  Art-Fashion       0.76      0.87      0.81        15
#         Art-Fashion-Designer       0.75      0.43      0.55        21
#            Art-Fashion-Model       1.00      0.25      0.40         4
#               Art-Literature       0.80      0.57      0.67        14
#        Art-Literature-Writer       0.39      0.64      0.49        14
#                    Art-Music       0.78      1.00      0.88        18
#         Art-Music-Instrument       0.88      1.00      0.93        14
#                 Art-Painting       0.85      0.79      0.81        14
#          Art-Painting-Artist       0.58      0.58      0.58        24
#              Art-Photography       1.00      0.50      0.67         4
# Art-Photography-Photographer       0.79      0.46      0.58        24
#                Art-Sculpting       0.90      0.75      0.82        12
#         Art-Sculpting-Artist       0.55      0.89      0.68        18
#                  Art-Theatre       0.91      0.67      0.77        15
#            Art-Theatre-Actor       0.25      0.29      0.27        14
#                    Astronomy       0.82      0.78      0.80        18
#            Astronomy-Program       1.00      1.00      1.00         3
#                      Culture       0.29      0.08      0.12        26
#              Culture-Country       0.00      0.00      0.00        26
#    Culture-Historical Figure       0.29      0.88      0.43        16
#                        Media       0.67      0.86      0.75        14
#                  Media-Anime       0.61      0.82      0.70        17
#                Media-Cartoon       0.88      0.54      0.67        13
#            Media-Documentary       0.75      0.79      0.77        19
#                   Media-News       1.00      0.53      0.69        19
#      Media-TV Series & Shows       0.57      0.62      0.59        13
#                     Military       0.33      0.43      0.38        14
#            Military-Aviation       0.67      0.50      0.57        12
#                Military-Land       0.94      0.83      0.88        18
#               Military-Naval       0.67      0.86      0.75        14
#              Military-Weapon       0.87      0.90      0.88        29
#                    Mythology       0.34      0.81      0.48        16
#       Mythology-Supernatural       0.38      0.31      0.34        16
#                Nature-Animal       0.77      0.59      0.67        17
#                  Nature-Food       0.38      0.67      0.48        24
#         Nature-Microorganism       0.67      0.36      0.47        11
#                 Nature-Plant       0.60      0.94      0.73        16
#                        Other       0.85      1.00      0.92        17
#                   Philosophy       0.21      0.29      0.25        24
#                     Religion       0.43      0.56      0.49        16
#          Science-Agriculture       1.00      0.36      0.53        14
#          Science-Antropology       0.67      0.44      0.53        18
#           Science-Archeology       0.90      0.69      0.78        13
#              Science-Biology       0.73      0.83      0.78        23
#            Science-Chemistry       0.75      0.53      0.62        17
#       Science-Earth Sciences       0.95      0.86      0.90        21
#            Science-Economics       0.65      0.68      0.67        19
#          Science-Mathematics       0.94      0.83      0.88        18
#             Science-Medicine       0.80      0.50      0.62         8
#          Science-Meteorology       0.71      0.71      0.71         7
#        Science-Paleonthology       0.67      0.93      0.78        15
#              Science-Physics       0.71      0.75      0.73        20
#             Science-Politics       0.58      0.69      0.63        16
#           Science-Psychology       0.44      0.22      0.30        18
#      Science-Social Sciences       0.43      0.50      0.47        20
#                       Sports       0.00      0.00      0.00        17
# Technology-Civil Engineering       0.88      0.74      0.80        19
#  Technology-Computer Science       0.57      0.57      0.57        23
#       Technology-Electronics       0.90      0.56      0.69        16
#         Technology-Mechanics       0.71      0.71      0.71        21
#      Technology-Mechatronics       0.00      0.00      0.00         1
#          Technology-Robotics       0.83      0.71      0.77        14
#        Technology-Video Game       0.91      1.00      0.95        21
#               Transportation       0.95      0.95      0.95        21
#      Transportation-Aviation       0.44      0.67      0.53        12
#          Transportation-Land       1.00      1.00      1.00        14
#         Transportation-Naval       0.92      0.80      0.86        15
#       Transportation-Railway       0.88      1.00      0.93        21
#
#                     accuracy                           0.65      1209
#                    macro avg       0.68      0.65      0.64      1209
#                 weighted avg       0.67      0.65      0.64      1209

# %% [markdown]
# ### PREPARE NEURAL NET MODEL CONV1D WITH PRE-TRAINING

# %%
LSTM_HIDDEN_SIZE = 200
LEARNING_RATE = 0.001
KG_EMBEDDING_DIM = 47

# load pre-trained word embeddings into an Embedding layer
# note that we set trainable = False so as to keep the embeddings fixed
embedding_layer = Embedding(num_words,
                            EMBEDDING_DIM,
                            weights=[embedding_matrix],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

print('Preparing model.')

entity_clusters = K.variable(embedding_clusters_1d)

Avg = keras.layers.core.Lambda(lambda x: K.mean(x, axis=1))  # , output_shape=(KG_EMBEDDING_DIM, ))
DotProduct = keras.layers.core.Lambda(lambda x: K.dot(x[0], x[1]))  # , output_shape=(KG_EMBEDDING_DIM, ))
Sum = keras.layers.core.Lambda(lambda x: K.sum(x, axis=1))  # , output_shape=(KG_EMBEDDING_DIM, ))
RemoveLastCol = keras.layers.core.Lambda(lambda x: K.sum(x, axis=-1))
Transpose = keras.layers.core.Lambda(lambda x: K.transpose(x))
FakeEClusterIn = keras.layers.core.Lambda(lambda x: embedding_clusters_1d)

main_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32', name='main_input')

x = embedding_layer(main_input)
x = CuDNNLSTM(KG_EMBEDDING_DIM, return_sequences=True)(x)
x = Avg(x)
x = Dense(KG_EMBEDDING_DIM)(x)
x = Activation('relu')(x)
# entity_extraction = Reshape([KG_EMBEDDING_DIM])(x)
entity_extraction = Transpose(x)

# get representation for entity clusters
# e_clusters = Input(tensor=entity_clusters,name='e_clusters')
x = FakeEClusterIn(x)
print("Shape", K.int_shape(x))
# x = e_clusters
x = Conv1D(filters=1, kernel_size=3, strides=3, input_shape=embedding_clusters_1d.shape[1:])(x)
x = MaxPooling1D(pool_size=3, strides=3)(x)
x = Conv1D(filters=1, kernel_size=3, strides=3)(x)
x = MaxPooling1D(pool_size=3, strides=2)(x)
print("Before removing last col", K.int_shape(x))
x = RemoveLastCol(x)
print("after removing last col", K.int_shape(x))
entity_cluster_reps = Reshape([KG_EMBEDDING_DIM], name='entity_cluster_reps')(x)
# entity_cluster_reps = x
print("entity_cluster_reps(after reshape)", K.int_shape(entity_cluster_reps))

# attention over entities
att_scores = DotProduct([entity_cluster_reps, entity_extraction])
print("att_scores_entities", K.int_shape(att_scores))
# att_normalized = Activation('softmax',name='entity_attention')(att_scores)
att_normalized = Softmax(axis=-1, name='entity_attention')(att_scores)
print("att_normalized", K.int_shape(att_normalized))
the_entity = DotProduct([Transpose(entity_cluster_reps), att_normalized])
print("the_entity", K.int_shape(the_entity))

final_output = Dense(units=len(unique_labels), activation='softmax')(Transpose(the_entity))

optimizer = Adam(lr=LEARNING_RATE, clipvalue=0.25)

m1 = Model(inputs=main_input, outputs=final_output)
m1.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['acc'])
m1.summary()

_, tmpfn = tempfile.mkstemp()
# Save the best model during validation and bail out of training early if we're not improving
callbacks = [ModelCheckpoint(tmpfn,monitor='val_acc', save_best_only=True, save_weights_only=True)]
# Out:
# Preparing model.
# Shape (20, 2585, 100)
# Before removing last col (20, 47, 1)
# after removing last col (20, 47)
# entity_cluster_reps(after reshape) (20, 47)
# att_scores_entities (20, None)
# att_normalized (20, None)
# the_entity (47, None)
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input (InputLayer)         [(None, 300)]        0
# __________________________________________________________________________________________________
# embedding_7 (Embedding)         (None, 300, 300)     6000000     main_input[0][0]
# __________________________________________________________________________________________________
# cu_dnnlstm_11 (CuDNNLSTM)       (None, 300, 47)      65612       embedding_7[0][0]
# __________________________________________________________________________________________________
# lambda_46 (Lambda)              (None, 47)           0           cu_dnnlstm_11[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 47)           2256        lambda_46[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 47)           0           dense_11[0][0]
# __________________________________________________________________________________________________
# lambda_51 (Lambda)              (20, 2585, 100)      0           activation_11[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (20, 861, 1)         301         lambda_51[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_14 (MaxPooling1D) (20, 287, 1)         0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (20, 95, 1)          4           max_pooling1d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_15 (MaxPooling1D) (20, 47, 1)          0           conv1d_15[0][0]
# __________________________________________________________________________________________________
# lambda_49 (Lambda)              (20, 47)             0           max_pooling1d_15[0][0]
# __________________________________________________________________________________________________
# entity_cluster_reps (Reshape)   (20, 47)             0           lambda_49[0][0]
# __________________________________________________________________________________________________
# lambda_50 (Lambda)              multiple             0           activation_11[0][0]
#                                                                  entity_cluster_reps[0][0]
#                                                                  lambda_47[1][0]
# __________________________________________________________________________________________________
# lambda_47 (Lambda)              multiple             0           entity_cluster_reps[0][0]
#                                                                  lambda_50[0][0]
#                                                                  lambda_50[1][0]
#                                                                  entity_attention[0][0]
# __________________________________________________________________________________________________
# entity_attention (Softmax)      (20, None)           0           lambda_47[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 78)           3744        lambda_50[2][0]
# ==================================================================================================
# Total params: 6,071,917
# Trainable params: 71,917
# Non-trainable params: 6,000,000
# __________________________________________________________________________________________________

# %%
BATCH_SIZE = 2
NUM_EPOCHS = 10

history = m1.fit(x_train, y_train,
                batch_size=BATCH_SIZE,
                epochs=NUM_EPOCHS,
                validation_data=(x_val, y_val), 
                callbacks=callbacks)
# m.save('node2vec_lstm_model')
# Out:
# Epoch 1/10
# 2418/2418 [==============================] - ETA: 1:56:07 - loss: 9.3908 - acc: 0.0000e+ - ETA: 25s - loss: 6.8890 - acc: 0.0000e+00   - ETA: 24s - loss: 5.9955 - acc: 0.0000e+ - ETA: 24s - loss: 5.4131 - acc: 0.0000e+ - ETA: 24s - loss: 5.1841 - acc: 0.0000e+ - ETA: 23s - loss: 4.9887 - acc: 0.0357   - ETA: 23s - loss: 4.8827 - acc: 0.02 - ETA: 22s - loss: 4.8003 - acc: 0.02 - ETA: 22s - loss: 4.7341 - acc: 0.03 - ETA: 22s - loss: 4.7200 - acc: 0.02 - ETA: 22s - loss: 4.6796 - acc: 0.03 - ETA: 22s - loss: 4.6678 - acc: 0.03 - ETA: 22s - loss: 4.6449 - acc: 0.04 - ETA: 22s - loss: 4.6196 - acc: 0.04 - ETA: 22s - loss: 4.6000 - acc: 0.03 - ETA: 22s - loss: 4.6002 - acc: 0.03 - ETA: 22s - loss: 4.5912 - acc: 0.03 - ETA: 21s - loss: 4.5729 - acc: 0.03 - ETA: 21s - loss: 4.5602 - acc: 0.03 - ETA: 21s - loss: 4.5400 - acc: 0.03 - ETA: 21s - loss: 4.5362 - acc: 0.03 - ETA: 21s - loss: 4.5289 - acc: 0.04 - ETA: 21s - loss: 4.5241 - acc: 0.03 - ETA: 21s - loss: 4.5123 - acc: 0.04 - ETA: 21s - loss: 4.5052 - acc: 0.04 - ETA: 21s - loss: 4.4988 - acc: 0.04 - ETA: 21s - loss: 4.4982 - acc: 0.03 - ETA: 21s - loss: 4.4976 - acc: 0.03 - ETA: 21s - loss: 4.4921 - acc: 0.03 - ETA: 21s - loss: 4.4941 - acc: 0.03 - ETA: 21s - loss: 4.4905 - acc: 0.03 - ETA: 20s - loss: 4.4852 - acc: 0.03 - ETA: 20s - loss: 4.4778 - acc: 0.03 - ETA: 20s - loss: 4.4746 - acc: 0.03 - ETA: 20s - loss: 4.4706 - acc: 0.03 - ETA: 20s - loss: 4.4642 - acc: 0.02 - ETA: 20s - loss: 4.4611 - acc: 0.02 - ETA: 20s - loss: 4.4612 - acc: 0.02 - ETA: 20s - loss: 4.4549 - acc: 0.02 - ETA: 20s - loss: 4.4491 - acc: 0.02 - ETA: 20s - loss: 4.4439 - acc: 0.02 - ETA: 20s - loss: 4.4410 - acc: 0.02 - ETA: 20s - loss: 4.4315 - acc: 0.02 - ETA: 20s - loss: 4.4410 - acc: 0.02 - ETA: 20s - loss: 4.4358 - acc: 0.02 - ETA: 20s - loss: 4.4372 - acc: 0.02 - ETA: 20s - loss: 4.4348 - acc: 0.02 - ETA: 20s - loss: 4.4331 - acc: 0.02 - ETA: 20s - loss: 4.4311 - acc: 0.02 - ETA: 20s - loss: 4.4312 - acc: 0.02 - ETA: 20s - loss: 4.4292 - acc: 0.02 - ETA: 20s - loss: 4.4285 - acc: 0.02 - ETA: 20s - loss: 4.4247 - acc: 0.02 - ETA: 20s - loss: 4.4241 - acc: 0.02 - ETA: 20s - loss: 4.4251 - acc: 0.02 - ETA: 20s - loss: 4.4241 - acc: 0.02 - ETA: 20s - loss: 4.4230 - acc: 0.02 - ETA: 20s - loss: 4.4216 - acc: 0.02 - ETA: 20s - loss: 4.4204 - acc: 0.02 - ETA: 20s - loss: 4.4196 - acc: 0.02 - ETA: 20s - loss: 4.4168 - acc: 0.02 - ETA: 20s - loss: 4.4114 - acc: 0.02 - ETA: 20s - loss: 4.4089 - acc: 0.02 - ETA: 20s - loss: 4.4115 - acc: 0.02 - ETA: 20s - loss: 4.4133 - acc: 0.02 - ETA: 20s - loss: 4.4099 - acc: 0.02 - ETA: 20s - loss: 4.4081 - acc: 0.02 - ETA: 20s - loss: 4.4038 - acc: 0.02 - ETA: 20s - loss: 4.4035 - acc: 0.02 - ETA: 20s - loss: 4.4008 - acc: 0.02 - ETA: 20s - loss: 4.4011 - acc: 0.02 - ETA: 20s - loss: 4.4014 - acc: 0.02 - ETA: 19s - loss: 4.4016 - acc: 0.02 - ETA: 19s - loss: 4.4010 - acc: 0.02 - ETA: 19s - loss: 4.3999 - acc: 0.02 - ETA: 19s - loss: 4.3993 - acc: 0.02 - ETA: 19s - loss: 4.3991 - acc: 0.02 - ETA: 19s - loss: 4.3991 - acc: 0.02 - ETA: 19s - loss: 4.3982 - acc: 0.02 - ETA: 19s - loss: 4.3970 - acc: 0.02 - ETA: 19s - loss: 4.3960 - acc: 0.02 - ETA: 19s - loss: 4.3944 - acc: 0.02 - ETA: 19s - loss: 4.3933 - acc: 0.02 - ETA: 19s - loss: 4.3936 - acc: 0.02 - ETA: 19s - loss: 4.3926 - acc: 0.02 - ETA: 19s - loss: 4.3926 - acc: 0.02 - ETA: 19s - loss: 4.3915 - acc: 0.02 - ETA: 18s - loss: 4.3908 - acc: 0.02 - ETA: 18s - loss: 4.3886 - acc: 0.02 - ETA: 18s - loss: 4.3895 - acc: 0.02 - ETA: 18s - loss: 4.3901 - acc: 0.02 - ETA: 18s - loss: 4.3888 - acc: 0.02 - ETA: 18s - loss: 4.3873 - acc: 0.02 - ETA: 18s - loss: 4.3852 - acc: 0.02 - ETA: 18s - loss: 4.3846 - acc: 0.02 - ETA: 18s - loss: 4.3860 - acc: 0.02 - ETA: 18s - loss: 4.3865 - acc: 0.02 - ETA: 18s - loss: 4.3863 - acc: 0.02 - ETA: 18s - loss: 4.3864 - acc: 0.02 - ETA: 18s - loss: 4.3855 - acc: 0.02 - ETA: 18s - loss: 4.3841 - acc: 0.02 - ETA: 18s - loss: 4.3834 - acc: 0.02 - ETA: 18s - loss: 4.3839 - acc: 0.02 - ETA: 17s  ...
# Epoch 2/10
# 2418/2418 [==============================] - ETA: 22s - loss: 4.0321 - acc: 0.0000e+ - ETA: 19s - loss: 4.4027 - acc: 0.0000e+ - ETA: 19s - loss: 4.2650 - acc: 0.0000e+ - ETA: 19s - loss: 4.2726 - acc: 0.0000e+ - ETA: 19s - loss: 4.2622 - acc: 0.0000e+ - ETA: 19s - loss: 4.2481 - acc: 0.0147   - ETA: 19s - loss: 4.2315 - acc: 0.02 - ETA: 19s - loss: 4.2195 - acc: 0.02 - ETA: 19s - loss: 4.2147 - acc: 0.01 - ETA: 19s - loss: 4.2018 - acc: 0.01 - ETA: 19s - loss: 4.2053 - acc: 0.01 - ETA: 19s - loss: 4.1957 - acc: 0.01 - ETA: 19s - loss: 4.1972 - acc: 0.01 - ETA: 20s - loss: 4.1816 - acc: 0.01 - ETA: 20s - loss: 4.1968 - acc: 0.01 - ETA: 19s - loss: 4.1879 - acc: 0.01 - ETA: 19s - loss: 4.1950 - acc: 0.01 - ETA: 19s - loss: 4.1967 - acc: 0.01 - ETA: 19s - loss: 4.1980 - acc: 0.01 - ETA: 19s - loss: 4.2111 - acc: 0.01 - ETA: 19s - loss: 4.2158 - acc: 0.01 - ETA: 19s - loss: 4.2230 - acc: 0.01 - ETA: 19s - loss: 4.2190 - acc: 0.02 - ETA: 19s - loss: 4.2133 - acc: 0.02 - ETA: 19s - loss: 4.2083 - acc: 0.01 - ETA: 19s - loss: 4.2058 - acc: 0.02 - ETA: 19s - loss: 4.2018 - acc: 0.02 - ETA: 19s - loss: 4.2021 - acc: 0.02 - ETA: 19s - loss: 4.2066 - acc: 0.01 - ETA: 19s - loss: 4.2062 - acc: 0.01 - ETA: 19s - loss: 4.2060 - acc: 0.01 - ETA: 19s - loss: 4.2055 - acc: 0.01 - ETA: 18s - loss: 4.2070 - acc: 0.01 - ETA: 18s - loss: 4.2101 - acc: 0.01 - ETA: 18s - loss: 4.2189 - acc: 0.01 - ETA: 18s - loss: 4.2165 - acc: 0.01 - ETA: 18s - loss: 4.2112 - acc: 0.01 - ETA: 18s - loss: 4.2121 - acc: 0.01 - ETA: 18s - loss: 4.2136 - acc: 0.01 - ETA: 18s - loss: 4.2143 - acc: 0.01 - ETA: 18s - loss: 4.2095 - acc: 0.01 - ETA: 18s - loss: 4.2122 - acc: 0.01 - ETA: 18s - loss: 4.2102 - acc: 0.01 - ETA: 18s - loss: 4.2084 - acc: 0.01 - ETA: 18s - loss: 4.2057 - acc: 0.01 - ETA: 17s - loss: 4.2059 - acc: 0.01 - ETA: 17s - loss: 4.2066 - acc: 0.01 - ETA: 17s - loss: 4.2039 - acc: 0.01 - ETA: 17s - loss: 4.2047 - acc: 0.01 - ETA: 17s - loss: 4.2090 - acc: 0.01 - ETA: 17s - loss: 4.2104 - acc: 0.01 - ETA: 17s - loss: 4.2110 - acc: 0.01 - ETA: 17s - loss: 4.2111 - acc: 0.01 - ETA: 17s - loss: 4.2097 - acc: 0.01 - ETA: 17s - loss: 4.2073 - acc: 0.01 - ETA: 17s - loss: 4.2100 - acc: 0.01 - ETA: 17s - loss: 4.2127 - acc: 0.01 - ETA: 17s - loss: 4.2107 - acc: 0.01 - ETA: 17s - loss: 4.2122 - acc: 0.01 - ETA: 17s - loss: 4.2124 - acc: 0.01 - ETA: 17s - loss: 4.2092 - acc: 0.01 - ETA: 17s - loss: 4.2070 - acc: 0.01 - ETA: 17s - loss: 4.2070 - acc: 0.01 - ETA: 17s - loss: 4.2065 - acc: 0.01 - ETA: 17s - loss: 4.2068 - acc: 0.01 - ETA: 17s - loss: 4.2096 - acc: 0.01 - ETA: 17s - loss: 4.2115 - acc: 0.01 - ETA: 17s - loss: 4.2116 - acc: 0.01 - ETA: 17s - loss: 4.2145 - acc: 0.01 - ETA: 17s - loss: 4.2154 - acc: 0.01 - ETA: 17s - loss: 4.2136 - acc: 0.01 - ETA: 17s - loss: 4.2124 - acc: 0.01 - ETA: 17s - loss: 4.2133 - acc: 0.01 - ETA: 17s - loss: 4.2122 - acc: 0.01 - ETA: 17s - loss: 4.2142 - acc: 0.01 - ETA: 17s - loss: 4.2142 - acc: 0.01 - ETA: 17s - loss: 4.2162 - acc: 0.01 - ETA: 17s - loss: 4.2165 - acc: 0.01 - ETA: 17s - loss: 4.2164 - acc: 0.01 - ETA: 17s - loss: 4.2165 - acc: 0.01 - ETA: 17s - loss: 4.2164 - acc: 0.01 - ETA: 16s - loss: 4.2177 - acc: 0.01 - ETA: 16s - loss: 4.2189 - acc: 0.01 - ETA: 16s - loss: 4.2189 - acc: 0.01 - ETA: 16s - loss: 4.2186 - acc: 0.01 - ETA: 16s - loss: 4.2183 - acc: 0.01 - ETA: 16s - loss: 4.2174 - acc: 0.01 - ETA: 16s - loss: 4.2188 - acc: 0.01 - ETA: 16s - loss: 4.2186 - acc: 0.01 - ETA: 16s - loss: 4.2201 - acc: 0.01 - ETA: 16s - loss: 4.2187 - acc: 0.01 - ETA: 16s - loss: 4.2180 - acc: 0.01 - ETA: 16s - loss: 4.2177 - acc: 0.01 - ETA: 16s - loss: 4.2183 - acc: 0.01 - ETA: 16s - loss: 4.2185 - acc: 0.01 - ETA: 16s - loss: 4.2178 - acc: 0.01 - ETA: 15s - loss: 4.2175 - acc: 0.01 - ETA: 15s - loss: 4.2177 - acc: 0.01 - ETA: 15s - loss: 4.2195 - acc: 0.01 - ETA: 15s - loss: 4.2181 - acc: 0.01 - ETA: 15s - loss: 4.2185 - acc: 0.01 - ETA: 15s - loss: 4.2192 - acc: 0.01 - ETA: 15s - loss: 4.2197 - acc: 0.01 - ETA: 15s - loss:  ...
# Epoch 3/10
# 2418/2418 [==============================] - ETA: 22s - loss: 4.3189 - acc: 0.0000e+ - ETA: 22s - loss: 4.1862 - acc: 0.0000e+ - ETA: 20s - loss: 4.2326 - acc: 0.0000e+ - ETA: 20s - loss: 4.2453 - acc: 0.0000e+ - ETA: 20s - loss: 4.2100 - acc: 0.0000e+ - ETA: 20s - loss: 4.2369 - acc: 0.0000e+ - ETA: 20s - loss: 4.2353 - acc: 0.0000e+ - ETA: 20s - loss: 4.2253 - acc: 0.0000e+ - ETA: 20s - loss: 4.2004 - acc: 0.0192   - ETA: 20s - loss: 4.2059 - acc: 0.02 - ETA: 20s - loss: 4.2142 - acc: 0.02 - ETA: 19s - loss: 4.2082 - acc: 0.02 - ETA: 19s - loss: 4.2045 - acc: 0.01 - ETA: 19s - loss: 4.2127 - acc: 0.01 - ETA: 19s - loss: 4.2195 - acc: 0.01 - ETA: 19s - loss: 4.2230 - acc: 0.01 - ETA: 19s - loss: 4.2215 - acc: 0.01 - ETA: 19s - loss: 4.2170 - acc: 0.01 - ETA: 19s - loss: 4.2187 - acc: 0.01 - ETA: 19s - loss: 4.2186 - acc: 0.01 - ETA: 19s - loss: 4.2162 - acc: 0.01 - ETA: 19s - loss: 4.2124 - acc: 0.01 - ETA: 19s - loss: 4.2155 - acc: 0.01 - ETA: 19s - loss: 4.2141 - acc: 0.01 - ETA: 19s - loss: 4.2136 - acc: 0.01 - ETA: 19s - loss: 4.2211 - acc: 0.01 - ETA: 19s - loss: 4.2227 - acc: 0.01 - ETA: 19s - loss: 4.2198 - acc: 0.01 - ETA: 19s - loss: 4.2206 - acc: 0.01 - ETA: 19s - loss: 4.2142 - acc: 0.01 - ETA: 19s - loss: 4.2141 - acc: 0.01 - ETA: 19s - loss: 4.2156 - acc: 0.01 - ETA: 19s - loss: 4.2179 - acc: 0.01 - ETA: 19s - loss: 4.2204 - acc: 0.01 - ETA: 19s - loss: 4.2238 - acc: 0.01 - ETA: 18s - loss: 4.2244 - acc: 0.01 - ETA: 18s - loss: 4.2257 - acc: 0.01 - ETA: 18s - loss: 4.2245 - acc: 0.01 - ETA: 18s - loss: 4.2279 - acc: 0.01 - ETA: 18s - loss: 4.2289 - acc: 0.01 - ETA: 18s - loss: 4.2277 - acc: 0.01 - ETA: 18s - loss: 4.2253 - acc: 0.01 - ETA: 18s - loss: 4.2273 - acc: 0.01 - ETA: 18s - loss: 4.2287 - acc: 0.01 - ETA: 18s - loss: 4.2243 - acc: 0.02 - ETA: 18s - loss: 4.2238 - acc: 0.02 - ETA: 18s - loss: 4.2250 - acc: 0.02 - ETA: 18s - loss: 4.2253 - acc: 0.02 - ETA: 18s - loss: 4.2258 - acc: 0.01 - ETA: 18s - loss: 4.2248 - acc: 0.01 - ETA: 18s - loss: 4.2234 - acc: 0.02 - ETA: 18s - loss: 4.2207 - acc: 0.02 - ETA: 18s - loss: 4.2195 - acc: 0.02 - ETA: 18s - loss: 4.2210 - acc: 0.01 - ETA: 18s - loss: 4.2201 - acc: 0.01 - ETA: 18s - loss: 4.2199 - acc: 0.01 - ETA: 18s - loss: 4.2232 - acc: 0.01 - ETA: 18s - loss: 4.2222 - acc: 0.01 - ETA: 18s - loss: 4.2248 - acc: 0.01 - ETA: 18s - loss: 4.2237 - acc: 0.01 - ETA: 17s - loss: 4.2221 - acc: 0.01 - ETA: 17s - loss: 4.2221 - acc: 0.01 - ETA: 17s - loss: 4.2175 - acc: 0.02 - ETA: 17s - loss: 4.2178 - acc: 0.02 - ETA: 17s - loss: 4.2188 - acc: 0.02 - ETA: 17s - loss: 4.2181 - acc: 0.02 - ETA: 17s - loss: 4.2171 - acc: 0.02 - ETA: 17s - loss: 4.2168 - acc: 0.02 - ETA: 17s - loss: 4.2162 - acc: 0.02 - ETA: 17s - loss: 4.2170 - acc: 0.01 - ETA: 17s - loss: 4.2150 - acc: 0.01 - ETA: 17s - loss: 4.2136 - acc: 0.01 - ETA: 17s - loss: 4.2123 - acc: 0.01 - ETA: 17s - loss: 4.2128 - acc: 0.01 - ETA: 17s - loss: 4.2138 - acc: 0.01 - ETA: 17s - loss: 4.2136 - acc: 0.01 - ETA: 17s - loss: 4.2127 - acc: 0.01 - ETA: 16s - loss: 4.2113 - acc: 0.01 - ETA: 16s - loss: 4.2078 - acc: 0.01 - ETA: 16s - loss: 4.2081 - acc: 0.01 - ETA: 16s - loss: 4.2068 - acc: 0.01 - ETA: 16s - loss: 4.2064 - acc: 0.01 - ETA: 16s - loss: 4.2072 - acc: 0.01 - ETA: 16s - loss: 4.2078 - acc: 0.01 - ETA: 16s - loss: 4.2072 - acc: 0.01 - ETA: 16s - loss: 4.2058 - acc: 0.01 - ETA: 16s - loss: 4.2061 - acc: 0.01 - ETA: 16s - loss: 4.2068 - acc: 0.01 - ETA: 16s - loss: 4.2063 - acc: 0.01 - ETA: 16s - loss: 4.2073 - acc: 0.01 - ETA: 16s - loss: 4.2086 - acc: 0.01 - ETA: 16s - loss: 4.2080 - acc: 0.01 - ETA: 15s - loss: 4.2078 - acc: 0.01 - ETA: 15s - loss: 4.2065 - acc: 0.01 - ETA: 15s - loss: 4.2061 - acc: 0.01 - ETA: 15s - loss: 4.2057 - acc: 0.01 - ETA: 15s - loss: 4.2054 - acc: 0.01 - ETA: 15s - loss: 4.2043 - acc: 0.01 - ETA: 15s - loss: 4.2043 - acc: 0.01 - ETA: 15s - loss: 4.2048 - acc: 0.01 - ETA: 15s - loss: 4.2044 - acc: 0.01 - ETA: 15s - loss: 4.2045 - acc: 0.01 - ETA: 15s - loss: 4.2048 - acc: 0.01 - ETA:  ...
# Epoch 4/10
# 2418/2418 [==============================] - ETA: 23s - loss: 4.3892 - acc: 0.0000e+ - ETA: 19s - loss: 4.2742 - acc: 0.0000e+ - ETA: 20s - loss: 4.2297 - acc: 0.0000e+ - ETA: 20s - loss: 4.1957 - acc: 0.0000e+ - ETA: 20s - loss: 4.1849 - acc: 0.0000e+ - ETA: 20s - loss: 4.1968 - acc: 0.0156   - ETA: 20s - loss: 4.1981 - acc: 0.03 - ETA: 20s - loss: 4.1853 - acc: 0.03 - ETA: 20s - loss: 4.1826 - acc: 0.03 - ETA: 20s - loss: 4.1926 - acc: 0.02 - ETA: 21s - loss: 4.1909 - acc: 0.02 - ETA: 22s - loss: 4.1955 - acc: 0.02 - ETA: 22s - loss: 4.1935 - acc: 0.02 - ETA: 22s - loss: 4.1760 - acc: 0.02 - ETA: 21s - loss: 4.1836 - acc: 0.02 - ETA: 21s - loss: 4.1830 - acc: 0.02 - ETA: 21s - loss: 4.1798 - acc: 0.03 - ETA: 21s - loss: 4.1818 - acc: 0.03 - ETA: 21s - loss: 4.1729 - acc: 0.03 - ETA: 21s - loss: 4.1763 - acc: 0.03 - ETA: 20s - loss: 4.1866 - acc: 0.03 - ETA: 20s - loss: 4.1892 - acc: 0.03 - ETA: 20s - loss: 4.1893 - acc: 0.03 - ETA: 20s - loss: 4.1873 - acc: 0.03 - ETA: 20s - loss: 4.1873 - acc: 0.03 - ETA: 20s - loss: 4.1829 - acc: 0.03 - ETA: 20s - loss: 4.1840 - acc: 0.03 - ETA: 20s - loss: 4.1864 - acc: 0.03 - ETA: 20s - loss: 4.1831 - acc: 0.03 - ETA: 19s - loss: 4.1823 - acc: 0.03 - ETA: 19s - loss: 4.1788 - acc: 0.03 - ETA: 19s - loss: 4.1746 - acc: 0.03 - ETA: 19s - loss: 4.1701 - acc: 0.03 - ETA: 19s - loss: 4.1660 - acc: 0.03 - ETA: 19s - loss: 4.1631 - acc: 0.02 - ETA: 19s - loss: 4.1581 - acc: 0.03 - ETA: 19s - loss: 4.1646 - acc: 0.03 - ETA: 19s - loss: 4.1627 - acc: 0.03 - ETA: 19s - loss: 4.1680 - acc: 0.03 - ETA: 19s - loss: 4.1675 - acc: 0.03 - ETA: 19s - loss: 4.1673 - acc: 0.03 - ETA: 19s - loss: 4.1657 - acc: 0.03 - ETA: 19s - loss: 4.1658 - acc: 0.03 - ETA: 18s - loss: 4.1624 - acc: 0.03 - ETA: 18s - loss: 4.1664 - acc: 0.03 - ETA: 18s - loss: 4.1664 - acc: 0.03 - ETA: 18s - loss: 4.1671 - acc: 0.03 - ETA: 19s - loss: 4.1677 - acc: 0.03 - ETA: 19s - loss: 4.1711 - acc: 0.03 - ETA: 19s - loss: 4.1702 - acc: 0.03 - ETA: 19s - loss: 4.1696 - acc: 0.03 - ETA: 18s - loss: 4.1737 - acc: 0.03 - ETA: 18s - loss: 4.1736 - acc: 0.03 - ETA: 18s - loss: 4.1759 - acc: 0.03 - ETA: 18s - loss: 4.1761 - acc: 0.03 - ETA: 18s - loss: 4.1753 - acc: 0.03 - ETA: 18s - loss: 4.1725 - acc: 0.03 - ETA: 18s - loss: 4.1733 - acc: 0.03 - ETA: 18s - loss: 4.1745 - acc: 0.03 - ETA: 18s - loss: 4.1731 - acc: 0.02 - ETA: 18s - loss: 4.1720 - acc: 0.02 - ETA: 18s - loss: 4.1716 - acc: 0.02 - ETA: 18s - loss: 4.1709 - acc: 0.02 - ETA: 18s - loss: 4.1676 - acc: 0.03 - ETA: 18s - loss: 4.1684 - acc: 0.02 - ETA: 18s - loss: 4.1667 - acc: 0.03 - ETA: 18s - loss: 4.1657 - acc: 0.03 - ETA: 18s - loss: 4.1649 - acc: 0.03 - ETA: 17s - loss: 4.1621 - acc: 0.03 - ETA: 17s - loss: 4.1646 - acc: 0.03 - ETA: 17s - loss: 4.1634 - acc: 0.02 - ETA: 17s - loss: 4.1620 - acc: 0.03 - ETA: 17s - loss: 4.1624 - acc: 0.03 - ETA: 17s - loss: 4.1659 - acc: 0.02 - ETA: 17s - loss: 4.1661 - acc: 0.02 - ETA: 17s - loss: 4.1646 - acc: 0.02 - ETA: 17s - loss: 4.1646 - acc: 0.02 - ETA: 17s - loss: 4.1658 - acc: 0.02 - ETA: 17s - loss: 4.1658 - acc: 0.02 - ETA: 17s - loss: 4.1654 - acc: 0.02 - ETA: 17s - loss: 4.1642 - acc: 0.02 - ETA: 17s - loss: 4.1613 - acc: 0.02 - ETA: 17s - loss: 4.1623 - acc: 0.02 - ETA: 17s - loss: 4.1620 - acc: 0.02 - ETA: 17s - loss: 4.1617 - acc: 0.03 - ETA: 17s - loss: 4.1614 - acc: 0.03 - ETA: 17s - loss: 4.1606 - acc: 0.02 - ETA: 17s - loss: 4.1609 - acc: 0.02 - ETA: 17s - loss: 4.1612 - acc: 0.02 - ETA: 17s - loss: 4.1606 - acc: 0.02 - ETA: 17s - loss: 4.1607 - acc: 0.02 - ETA: 17s - loss: 4.1601 - acc: 0.02 - ETA: 17s - loss: 4.1600 - acc: 0.02 - ETA: 17s - loss: 4.1610 - acc: 0.02 - ETA: 16s - loss: 4.1600 - acc: 0.02 - ETA: 16s - loss: 4.1611 - acc: 0.02 - ETA: 16s - loss: 4.1603 - acc: 0.02 - ETA: 16s - loss: 4.1627 - acc: 0.03 - ETA: 16s - loss: 4.1610 - acc: 0.03 - ETA: 16s - loss: 4.1620 - acc: 0.03 - ETA: 16s - loss: 4.1603 - acc: 0.03 - ETA: 16s - loss: 4.1592 - acc: 0.03 - ETA: 16s - loss: 4.1600 - acc: 0.03 - ETA: 16s - loss:  ...
# Epoch 5/10
# 2418/2418 [==============================] - ETA: 29s - loss: 3.9915 - acc: 0.0000e+ - ETA: 22s - loss: 4.2103 - acc: 0.0000e+ - ETA: 21s - loss: 4.1294 - acc: 0.0000e+ - ETA: 21s - loss: 4.2456 - acc: 0.0000e+ - ETA: 21s - loss: 4.2284 - acc: 0.0000e+ - ETA: 21s - loss: 4.1904 - acc: 0.0161   - ETA: 20s - loss: 4.2074 - acc: 0.02 - ETA: 20s - loss: 4.1837 - acc: 0.02 - ETA: 21s - loss: 4.1634 - acc: 0.03 - ETA: 20s - loss: 4.1609 - acc: 0.03 - ETA: 21s - loss: 4.1448 - acc: 0.03 - ETA: 21s - loss: 4.1375 - acc: 0.03 - ETA: 22s - loss: 4.1303 - acc: 0.02 - ETA: 22s - loss: 4.1044 - acc: 0.03 - ETA: 22s - loss: 4.0963 - acc: 0.03 - ETA: 22s - loss: 4.0907 - acc: 0.04 - ETA: 22s - loss: 4.0799 - acc: 0.03 - ETA: 21s - loss: 4.0727 - acc: 0.04 - ETA: 21s - loss: 4.0765 - acc: 0.04 - ETA: 21s - loss: 4.0779 - acc: 0.04 - ETA: 21s - loss: 4.0787 - acc: 0.04 - ETA: 21s - loss: 4.0756 - acc: 0.04 - ETA: 21s - loss: 4.0749 - acc: 0.05 - ETA: 21s - loss: 4.0767 - acc: 0.04 - ETA: 21s - loss: 4.0847 - acc: 0.04 - ETA: 21s - loss: 4.0809 - acc: 0.04 - ETA: 21s - loss: 4.0759 - acc: 0.04 - ETA: 21s - loss: 4.0749 - acc: 0.04 - ETA: 21s - loss: 4.0744 - acc: 0.04 - ETA: 21s - loss: 4.0817 - acc: 0.04 - ETA: 21s - loss: 4.0818 - acc: 0.04 - ETA: 21s - loss: 4.0787 - acc: 0.04 - ETA: 21s - loss: 4.0774 - acc: 0.04 - ETA: 21s - loss: 4.0829 - acc: 0.04 - ETA: 21s - loss: 4.0831 - acc: 0.05 - ETA: 21s - loss: 4.0887 - acc: 0.05 - ETA: 21s - loss: 4.0865 - acc: 0.04 - ETA: 21s - loss: 4.0918 - acc: 0.04 - ETA: 21s - loss: 4.0915 - acc: 0.04 - ETA: 21s - loss: 4.0854 - acc: 0.04 - ETA: 21s - loss: 4.0814 - acc: 0.05 - ETA: 21s - loss: 4.0757 - acc: 0.05 - ETA: 21s - loss: 4.0728 - acc: 0.05 - ETA: 21s - loss: 4.0742 - acc: 0.04 - ETA: 21s - loss: 4.0731 - acc: 0.04 - ETA: 21s - loss: 4.0766 - acc: 0.04 - ETA: 21s - loss: 4.0800 - acc: 0.04 - ETA: 21s - loss: 4.0809 - acc: 0.04 - ETA: 21s - loss: 4.0785 - acc: 0.04 - ETA: 21s - loss: 4.0790 - acc: 0.04 - ETA: 20s - loss: 4.0810 - acc: 0.04 - ETA: 20s - loss: 4.0854 - acc: 0.04 - ETA: 20s - loss: 4.0856 - acc: 0.04 - ETA: 20s - loss: 4.0862 - acc: 0.04 - ETA: 20s - loss: 4.0879 - acc: 0.04 - ETA: 20s - loss: 4.0857 - acc: 0.04 - ETA: 20s - loss: 4.0836 - acc: 0.04 - ETA: 20s - loss: 4.0820 - acc: 0.04 - ETA: 20s - loss: 4.0785 - acc: 0.05 - ETA: 20s - loss: 4.0796 - acc: 0.05 - ETA: 20s - loss: 4.0828 - acc: 0.05 - ETA: 19s - loss: 4.0808 - acc: 0.05 - ETA: 19s - loss: 4.0817 - acc: 0.05 - ETA: 19s - loss: 4.0788 - acc: 0.05 - ETA: 19s - loss: 4.0777 - acc: 0.05 - ETA: 19s - loss: 4.0823 - acc: 0.05 - ETA: 19s - loss: 4.0821 - acc: 0.05 - ETA: 19s - loss: 4.0847 - acc: 0.05 - ETA: 19s - loss: 4.0844 - acc: 0.05 - ETA: 19s - loss: 4.0818 - acc: 0.05 - ETA: 19s - loss: 4.0823 - acc: 0.05 - ETA: 18s - loss: 4.0833 - acc: 0.05 - ETA: 18s - loss: 4.0847 - acc: 0.05 - ETA: 18s - loss: 4.0880 - acc: 0.05 - ETA: 18s - loss: 4.0905 - acc: 0.05 - ETA: 18s - loss: 4.0907 - acc: 0.05 - ETA: 18s - loss: 4.0912 - acc: 0.05 - ETA: 18s - loss: 4.0936 - acc: 0.04 - ETA: 18s - loss: 4.0926 - acc: 0.04 - ETA: 18s - loss: 4.0932 - acc: 0.04 - ETA: 18s - loss: 4.0917 - acc: 0.05 - ETA: 18s - loss: 4.0931 - acc: 0.04 - ETA: 18s - loss: 4.0914 - acc: 0.04 - ETA: 18s - loss: 4.0899 - acc: 0.05 - ETA: 18s - loss: 4.0899 - acc: 0.05 - ETA: 18s - loss: 4.0877 - acc: 0.05 - ETA: 18s - loss: 4.0878 - acc: 0.05 - ETA: 18s - loss: 4.0854 - acc: 0.05 - ETA: 18s - loss: 4.0835 - acc: 0.05 - ETA: 17s - loss: 4.0824 - acc: 0.05 - ETA: 17s - loss: 4.0818 - acc: 0.05 - ETA: 17s - loss: 4.0832 - acc: 0.05 - ETA: 17s - loss: 4.0822 - acc: 0.04 - ETA: 17s - loss: 4.0835 - acc: 0.04 - ETA: 17s - loss: 4.0857 - acc: 0.04 - ETA: 17s - loss: 4.0869 - acc: 0.04 - ETA: 17s - loss: 4.0868 - acc: 0.04 - ETA: 17s - loss: 4.0868 - acc: 0.04 - ETA: 17s - loss: 4.0878 - acc: 0.04 - ETA: 17s - loss: 4.0894 - acc: 0.04 - ETA: 17s - loss: 4.0874 - acc: 0.04 - ETA: 17s - loss: 4.0847 - acc: 0.04 - ETA: 17s - loss: 4.0844 - acc: 0.04 - ETA: 17s - loss:  ...
# Epoch 6/10
# 2418/2418 [==============================] - ETA: 31s - loss: 4.3167 - acc: 0.0000e+ - ETA: 31s - loss: 3.8707 - acc: 0.1000   - ETA: 28s - loss: 3.8248 - acc: 0.10 - ETA: 25s - loss: 3.8700 - acc: 0.09 - ETA: 24s - loss: 3.8734 - acc: 0.06 - ETA: 23s - loss: 3.8334 - acc: 0.08 - ETA: 23s - loss: 3.8515 - acc: 0.07 - ETA: 23s - loss: 3.8713 - acc: 0.07 - ETA: 23s - loss: 3.8581 - acc: 0.10 - ETA: 23s - loss: 3.8549 - acc: 0.09 - ETA: 22s - loss: 3.8235 - acc: 0.10 - ETA: 22s - loss: 3.8456 - acc: 0.09 - ETA: 22s - loss: 3.8574 - acc: 0.08 - ETA: 21s - loss: 3.8339 - acc: 0.10 - ETA: 22s - loss: 3.8445 - acc: 0.10 - ETA: 22s - loss: 3.8469 - acc: 0.09 - ETA: 23s - loss: 3.8356 - acc: 0.09 - ETA: 23s - loss: 3.8349 - acc: 0.09 - ETA: 23s - loss: 3.8392 - acc: 0.10 - ETA: 22s - loss: 3.8572 - acc: 0.09 - ETA: 22s - loss: 3.8530 - acc: 0.09 - ETA: 22s - loss: 3.8621 - acc: 0.09 - ETA: 22s - loss: 3.8688 - acc: 0.08 - ETA: 22s - loss: 3.8785 - acc: 0.08 - ETA: 21s - loss: 3.8717 - acc: 0.09 - ETA: 21s - loss: 3.8724 - acc: 0.09 - ETA: 21s - loss: 3.8774 - acc: 0.09 - ETA: 21s - loss: 3.8778 - acc: 0.09 - ETA: 21s - loss: 3.8746 - acc: 0.09 - ETA: 21s - loss: 3.8721 - acc: 0.09 - ETA: 21s - loss: 3.8789 - acc: 0.08 - ETA: 21s - loss: 3.8770 - acc: 0.08 - ETA: 21s - loss: 3.8861 - acc: 0.08 - ETA: 21s - loss: 3.8862 - acc: 0.09 - ETA: 21s - loss: 3.8948 - acc: 0.09 - ETA: 21s - loss: 3.8941 - acc: 0.09 - ETA: 20s - loss: 3.8910 - acc: 0.09 - ETA: 21s - loss: 3.8932 - acc: 0.09 - ETA: 21s - loss: 3.8917 - acc: 0.09 - ETA: 21s - loss: 3.8877 - acc: 0.09 - ETA: 21s - loss: 3.8812 - acc: 0.10 - ETA: 21s - loss: 3.8862 - acc: 0.10 - ETA: 21s - loss: 3.8898 - acc: 0.10 - ETA: 21s - loss: 3.8966 - acc: 0.10 - ETA: 21s - loss: 3.9035 - acc: 0.10 - ETA: 20s - loss: 3.9002 - acc: 0.10 - ETA: 20s - loss: 3.9077 - acc: 0.10 - ETA: 20s - loss: 3.9069 - acc: 0.10 - ETA: 20s - loss: 3.9078 - acc: 0.10 - ETA: 20s - loss: 3.9068 - acc: 0.10 - ETA: 20s - loss: 3.9037 - acc: 0.10 - ETA: 20s - loss: 3.9052 - acc: 0.10 - ETA: 20s - loss: 3.9085 - acc: 0.10 - ETA: 20s - loss: 3.9070 - acc: 0.10 - ETA: 20s - loss: 3.9076 - acc: 0.10 - ETA: 20s - loss: 3.9093 - acc: 0.10 - ETA: 19s - loss: 3.9052 - acc: 0.10 - ETA: 19s - loss: 3.9035 - acc: 0.10 - ETA: 19s - loss: 3.9040 - acc: 0.10 - ETA: 19s - loss: 3.8995 - acc: 0.10 - ETA: 19s - loss: 3.8976 - acc: 0.10 - ETA: 19s - loss: 3.8947 - acc: 0.11 - ETA: 19s - loss: 3.8933 - acc: 0.11 - ETA: 19s - loss: 3.8936 - acc: 0.11 - ETA: 19s - loss: 3.8926 - acc: 0.11 - ETA: 19s - loss: 3.8936 - acc: 0.11 - ETA: 19s - loss: 3.8915 - acc: 0.11 - ETA: 19s - loss: 3.8895 - acc: 0.11 - ETA: 19s - loss: 3.8908 - acc: 0.11 - ETA: 19s - loss: 3.8921 - acc: 0.11 - ETA: 19s - loss: 3.8949 - acc: 0.11 - ETA: 19s - loss: 3.8979 - acc: 0.11 - ETA: 18s - loss: 3.8979 - acc: 0.11 - ETA: 18s - loss: 3.8987 - acc: 0.11 - ETA: 18s - loss: 3.8980 - acc: 0.11 - ETA: 18s - loss: 3.9018 - acc: 0.11 - ETA: 18s - loss: 3.9017 - acc: 0.11 - ETA: 18s - loss: 3.9014 - acc: 0.10 - ETA: 18s - loss: 3.9003 - acc: 0.10 - ETA: 18s - loss: 3.9026 - acc: 0.10 - ETA: 18s - loss: 3.9017 - acc: 0.10 - ETA: 18s - loss: 3.9033 - acc: 0.10 - ETA: 18s - loss: 3.9003 - acc: 0.10 - ETA: 18s - loss: 3.9025 - acc: 0.10 - ETA: 18s - loss: 3.9048 - acc: 0.10 - ETA: 18s - loss: 3.9047 - acc: 0.10 - ETA: 18s - loss: 3.9062 - acc: 0.10 - ETA: 18s - loss: 3.9072 - acc: 0.10 - ETA: 18s - loss: 3.9065 - acc: 0.10 - ETA: 18s - loss: 3.9035 - acc: 0.10 - ETA: 18s - loss: 3.9014 - acc: 0.10 - ETA: 17s - loss: 3.9017 - acc: 0.10 - ETA: 17s - loss: 3.9041 - acc: 0.10 - ETA: 17s - loss: 3.9070 - acc: 0.10 - ETA: 17s - loss: 3.9064 - acc: 0.10 - ETA: 17s - loss: 3.9077 - acc: 0.10 - ETA: 17s - loss: 3.9072 - acc: 0.10 - ETA: 17s - loss: 3.9090 - acc: 0.10 - ETA: 17s - loss: 3.9099 - acc: 0.10 - ETA: 17s - loss: 3.9113 - acc: 0.10 - ETA: 17s - loss: 3.9114 - acc: 0.10 - ETA: 17s - loss: 3.9089 - acc: 0.10 - ETA: 17s - loss: 3.9095 - acc: 0.10 - ETA: 17s - loss: 3.9099 - acc: 0. ...
# Epoch 7/10
# 2418/2418 [==============================] - ETA: 20s - loss: 4.4573 - acc: 0.0000e+ - ETA: 19s - loss: 3.8500 - acc: 0.1250   - ETA: 19s - loss: 3.8744 - acc: 0.13 - ETA: 20s - loss: 3.8637 - acc: 0.14 - ETA: 20s - loss: 3.8543 - acc: 0.14 - ETA: 20s - loss: 3.8340 - acc: 0.13 - ETA: 20s - loss: 3.8689 - acc: 0.11 - ETA: 20s - loss: 3.8680 - acc: 0.12 - ETA: 20s - loss: 3.8719 - acc: 0.11 - ETA: 21s - loss: 3.8497 - acc: 0.12 - ETA: 22s - loss: 3.8638 - acc: 0.12 - ETA: 22s - loss: 3.8593 - acc: 0.12 - ETA: 22s - loss: 3.8480 - acc: 0.13 - ETA: 22s - loss: 3.8504 - acc: 0.12 - ETA: 22s - loss: 3.8490 - acc: 0.12 - ETA: 22s - loss: 3.8470 - acc: 0.12 - ETA: 21s - loss: 3.8295 - acc: 0.12 - ETA: 21s - loss: 3.8328 - acc: 0.12 - ETA: 21s - loss: 3.8348 - acc: 0.12 - ETA: 21s - loss: 3.8449 - acc: 0.11 - ETA: 21s - loss: 3.8261 - acc: 0.13 - ETA: 21s - loss: 3.8412 - acc: 0.12 - ETA: 21s - loss: 3.8375 - acc: 0.13 - ETA: 21s - loss: 3.8258 - acc: 0.12 - ETA: 20s - loss: 3.8206 - acc: 0.12 - ETA: 20s - loss: 3.8200 - acc: 0.12 - ETA: 21s - loss: 3.8193 - acc: 0.12 - ETA: 21s - loss: 3.8198 - acc: 0.12 - ETA: 21s - loss: 3.8196 - acc: 0.12 - ETA: 21s - loss: 3.8121 - acc: 0.12 - ETA: 21s - loss: 3.8104 - acc: 0.12 - ETA: 21s - loss: 3.8123 - acc: 0.12 - ETA: 21s - loss: 3.8132 - acc: 0.12 - ETA: 21s - loss: 3.8195 - acc: 0.12 - ETA: 21s - loss: 3.8087 - acc: 0.12 - ETA: 21s - loss: 3.8142 - acc: 0.12 - ETA: 21s - loss: 3.8147 - acc: 0.12 - ETA: 21s - loss: 3.8117 - acc: 0.12 - ETA: 21s - loss: 3.8015 - acc: 0.13 - ETA: 21s - loss: 3.7994 - acc: 0.13 - ETA: 21s - loss: 3.8017 - acc: 0.13 - ETA: 20s - loss: 3.7979 - acc: 0.13 - ETA: 20s - loss: 3.7951 - acc: 0.14 - ETA: 20s - loss: 3.7948 - acc: 0.14 - ETA: 20s - loss: 3.7985 - acc: 0.14 - ETA: 20s - loss: 3.7964 - acc: 0.14 - ETA: 20s - loss: 3.7983 - acc: 0.13 - ETA: 20s - loss: 3.7911 - acc: 0.14 - ETA: 20s - loss: 3.7908 - acc: 0.14 - ETA: 20s - loss: 3.7905 - acc: 0.14 - ETA: 20s - loss: 3.7950 - acc: 0.14 - ETA: 20s - loss: 3.7959 - acc: 0.14 - ETA: 20s - loss: 3.7890 - acc: 0.14 - ETA: 20s - loss: 3.7907 - acc: 0.14 - ETA: 20s - loss: 3.7959 - acc: 0.13 - ETA: 20s - loss: 3.8041 - acc: 0.13 - ETA: 20s - loss: 3.8064 - acc: 0.13 - ETA: 20s - loss: 3.8003 - acc: 0.13 - ETA: 20s - loss: 3.7973 - acc: 0.14 - ETA: 20s - loss: 3.7962 - acc: 0.14 - ETA: 19s - loss: 3.7954 - acc: 0.14 - ETA: 19s - loss: 3.7985 - acc: 0.13 - ETA: 19s - loss: 3.7949 - acc: 0.13 - ETA: 19s - loss: 3.7974 - acc: 0.13 - ETA: 19s - loss: 3.7959 - acc: 0.13 - ETA: 19s - loss: 3.8002 - acc: 0.13 - ETA: 19s - loss: 3.8017 - acc: 0.13 - ETA: 19s - loss: 3.8038 - acc: 0.13 - ETA: 19s - loss: 3.8070 - acc: 0.13 - ETA: 19s - loss: 3.8085 - acc: 0.13 - ETA: 19s - loss: 3.8070 - acc: 0.13 - ETA: 19s - loss: 3.8076 - acc: 0.13 - ETA: 19s - loss: 3.8094 - acc: 0.13 - ETA: 19s - loss: 3.8043 - acc: 0.13 - ETA: 19s - loss: 3.8074 - acc: 0.13 - ETA: 19s - loss: 3.8097 - acc: 0.13 - ETA: 19s - loss: 3.8130 - acc: 0.13 - ETA: 19s - loss: 3.8143 - acc: 0.12 - ETA: 19s - loss: 3.8117 - acc: 0.13 - ETA: 18s - loss: 3.8105 - acc: 0.13 - ETA: 18s - loss: 3.8138 - acc: 0.13 - ETA: 18s - loss: 3.8146 - acc: 0.13 - ETA: 18s - loss: 3.8177 - acc: 0.13 - ETA: 18s - loss: 3.8179 - acc: 0.13 - ETA: 18s - loss: 3.8165 - acc: 0.13 - ETA: 18s - loss: 3.8198 - acc: 0.13 - ETA: 18s - loss: 3.8208 - acc: 0.13 - ETA: 18s - loss: 3.8213 - acc: 0.13 - ETA: 18s - loss: 3.8233 - acc: 0.13 - ETA: 18s - loss: 3.8226 - acc: 0.13 - ETA: 18s - loss: 3.8226 - acc: 0.13 - ETA: 18s - loss: 3.8207 - acc: 0.13 - ETA: 18s - loss: 3.8192 - acc: 0.13 - ETA: 18s - loss: 3.8183 - acc: 0.13 - ETA: 18s - loss: 3.8184 - acc: 0.13 - ETA: 18s - loss: 3.8188 - acc: 0.13 - ETA: 18s - loss: 3.8182 - acc: 0.13 - ETA: 18s - loss: 3.8198 - acc: 0.13 - ETA: 18s - loss: 3.8195 - acc: 0.13 - ETA: 18s - loss: 3.8180 - acc: 0.12 - ETA: 18s - loss: 3.8171 - acc: 0.13 - ETA: 18s - loss: 3.8167 - acc: 0.13 - ETA: 18s - loss: 3.8175 - acc: 0.13 - ETA: 18s - loss: 3.8166 - acc: 0. ...
# Epoch 8/10
# 2418/2418 [==============================] - ETA: 29s - loss: 4.1023 - acc: 0.0000e+ - ETA: 28s - loss: 4.0722 - acc: 0.0000e+ - ETA: 27s - loss: 4.1785 - acc: 0.0000e+ - ETA: 26s - loss: 3.9793 - acc: 0.0938   - ETA: 28s - loss: 3.9263 - acc: 0.12 - ETA: 29s - loss: 3.9352 - acc: 0.10 - ETA: 29s - loss: 3.8893 - acc: 0.10 - ETA: 28s - loss: 3.8955 - acc: 0.12 - ETA: 28s - loss: 3.9267 - acc: 0.11 - ETA: 28s - loss: 3.9161 - acc: 0.11 - ETA: 28s - loss: 3.8425 - acc: 0.12 - ETA: 27s - loss: 3.8238 - acc: 0.12 - ETA: 28s - loss: 3.8611 - acc: 0.11 - ETA: 28s - loss: 3.8636 - acc: 0.11 - ETA: 27s - loss: 3.8760 - acc: 0.11 - ETA: 27s - loss: 3.8761 - acc: 0.11 - ETA: 28s - loss: 3.8744 - acc: 0.11 - ETA: 27s - loss: 3.8674 - acc: 0.10 - ETA: 27s - loss: 3.8490 - acc: 0.11 - ETA: 27s - loss: 3.8286 - acc: 0.11 - ETA: 27s - loss: 3.8240 - acc: 0.12 - ETA: 27s - loss: 3.8148 - acc: 0.12 - ETA: 27s - loss: 3.8055 - acc: 0.11 - ETA: 27s - loss: 3.7947 - acc: 0.12 - ETA: 27s - loss: 3.7924 - acc: 0.12 - ETA: 27s - loss: 3.7859 - acc: 0.13 - ETA: 27s - loss: 3.7867 - acc: 0.13 - ETA: 27s - loss: 3.7729 - acc: 0.14 - ETA: 27s - loss: 3.7786 - acc: 0.13 - ETA: 27s - loss: 3.7678 - acc: 0.14 - ETA: 26s - loss: 3.7583 - acc: 0.14 - ETA: 26s - loss: 3.7592 - acc: 0.14 - ETA: 26s - loss: 3.7668 - acc: 0.14 - ETA: 26s - loss: 3.7704 - acc: 0.14 - ETA: 26s - loss: 3.7738 - acc: 0.14 - ETA: 26s - loss: 3.7778 - acc: 0.14 - ETA: 26s - loss: 3.7828 - acc: 0.13 - ETA: 26s - loss: 3.7872 - acc: 0.13 - ETA: 26s - loss: 3.7804 - acc: 0.13 - ETA: 26s - loss: 3.7772 - acc: 0.13 - ETA: 26s - loss: 3.7712 - acc: 0.14 - ETA: 26s - loss: 3.7748 - acc: 0.14 - ETA: 26s - loss: 3.7804 - acc: 0.14 - ETA: 26s - loss: 3.7801 - acc: 0.14 - ETA: 26s - loss: 3.7719 - acc: 0.14 - ETA: 26s - loss: 3.7712 - acc: 0.14 - ETA: 26s - loss: 3.7710 - acc: 0.14 - ETA: 25s - loss: 3.7723 - acc: 0.14 - ETA: 25s - loss: 3.7774 - acc: 0.14 - ETA: 25s - loss: 3.7804 - acc: 0.14 - ETA: 25s - loss: 3.7840 - acc: 0.14 - ETA: 25s - loss: 3.7835 - acc: 0.14 - ETA: 25s - loss: 3.7799 - acc: 0.14 - ETA: 25s - loss: 3.7807 - acc: 0.14 - ETA: 25s - loss: 3.7751 - acc: 0.14 - ETA: 25s - loss: 3.7731 - acc: 0.15 - ETA: 25s - loss: 3.7691 - acc: 0.15 - ETA: 24s - loss: 3.7683 - acc: 0.15 - ETA: 24s - loss: 3.7735 - acc: 0.15 - ETA: 24s - loss: 3.7678 - acc: 0.15 - ETA: 24s - loss: 3.7689 - acc: 0.14 - ETA: 24s - loss: 3.7638 - acc: 0.15 - ETA: 24s - loss: 3.7649 - acc: 0.15 - ETA: 24s - loss: 3.7630 - acc: 0.15 - ETA: 23s - loss: 3.7651 - acc: 0.15 - ETA: 23s - loss: 3.7642 - acc: 0.14 - ETA: 23s - loss: 3.7671 - acc: 0.14 - ETA: 23s - loss: 3.7651 - acc: 0.14 - ETA: 23s - loss: 3.7656 - acc: 0.14 - ETA: 23s - loss: 3.7646 - acc: 0.14 - ETA: 23s - loss: 3.7632 - acc: 0.14 - ETA: 23s - loss: 3.7662 - acc: 0.14 - ETA: 23s - loss: 3.7708 - acc: 0.14 - ETA: 22s - loss: 3.7690 - acc: 0.14 - ETA: 22s - loss: 3.7689 - acc: 0.14 - ETA: 22s - loss: 3.7704 - acc: 0.14 - ETA: 22s - loss: 3.7649 - acc: 0.14 - ETA: 22s - loss: 3.7669 - acc: 0.14 - ETA: 22s - loss: 3.7688 - acc: 0.14 - ETA: 22s - loss: 3.7733 - acc: 0.14 - ETA: 22s - loss: 3.7723 - acc: 0.14 - ETA: 22s - loss: 3.7744 - acc: 0.14 - ETA: 22s - loss: 3.7696 - acc: 0.14 - ETA: 22s - loss: 3.7717 - acc: 0.14 - ETA: 22s - loss: 3.7684 - acc: 0.15 - ETA: 22s - loss: 3.7703 - acc: 0.15 - ETA: 22s - loss: 3.7735 - acc: 0.14 - ETA: 21s - loss: 3.7731 - acc: 0.14 - ETA: 21s - loss: 3.7739 - acc: 0.14 - ETA: 21s - loss: 3.7729 - acc: 0.14 - ETA: 21s - loss: 3.7747 - acc: 0.14 - ETA: 21s - loss: 3.7766 - acc: 0.14 - ETA: 21s - loss: 3.7777 - acc: 0.14 - ETA: 21s - loss: 3.7752 - acc: 0.14 - ETA: 21s - loss: 3.7746 - acc: 0.14 - ETA: 21s - loss: 3.7730 - acc: 0.14 - ETA: 21s - loss: 3.7716 - acc: 0.14 - ETA: 21s - loss: 3.7698 - acc: 0.15 - ETA: 21s - loss: 3.7668 - acc: 0.15 - ETA: 21s - loss: 3.7654 - acc: 0.15 - ETA: 21s - loss: 3.7650 - acc: 0.15 - ETA: 20s - loss: 3.7632 - acc: 0.15 - ETA: 21s - loss: 3.7634 - acc: 0.15 - ETA: 21s - loss: 3.7636 - ...
# Epoch 9/10
# 2418/2418 [==============================] - ETA: 23s - loss: 4.5454 - acc: 0.0000e+ - ETA: 29s - loss: 3.6425 - acc: 0.2500   - ETA: 32s - loss: 3.6879 - acc: 0.20 - ETA: 29s - loss: 3.5552 - acc: 0.23 - ETA: 27s - loss: 3.5919 - acc: 0.21 - ETA: 26s - loss: 3.6759 - acc: 0.17 - ETA: 26s - loss: 3.6755 - acc: 0.20 - ETA: 26s - loss: 3.6697 - acc: 0.20 - ETA: 25s - loss: 3.6874 - acc: 0.20 - ETA: 25s - loss: 3.6992 - acc: 0.19 - ETA: 25s - loss: 3.6875 - acc: 0.19 - ETA: 25s - loss: 3.6675 - acc: 0.20 - ETA: 25s - loss: 3.6847 - acc: 0.20 - ETA: 25s - loss: 3.6797 - acc: 0.22 - ETA: 25s - loss: 3.6645 - acc: 0.21 - ETA: 24s - loss: 3.6716 - acc: 0.20 - ETA: 24s - loss: 3.7001 - acc: 0.19 - ETA: 25s - loss: 3.7089 - acc: 0.18 - ETA: 25s - loss: 3.7174 - acc: 0.17 - ETA: 25s - loss: 3.7280 - acc: 0.16 - ETA: 25s - loss: 3.7289 - acc: 0.16 - ETA: 25s - loss: 3.7143 - acc: 0.16 - ETA: 25s - loss: 3.7150 - acc: 0.17 - ETA: 25s - loss: 3.7207 - acc: 0.17 - ETA: 25s - loss: 3.7001 - acc: 0.19 - ETA: 25s - loss: 3.6798 - acc: 0.19 - ETA: 24s - loss: 3.6709 - acc: 0.19 - ETA: 24s - loss: 3.6692 - acc: 0.19 - ETA: 24s - loss: 3.6755 - acc: 0.19 - ETA: 24s - loss: 3.6745 - acc: 0.19 - ETA: 24s - loss: 3.6693 - acc: 0.19 - ETA: 24s - loss: 3.6612 - acc: 0.19 - ETA: 24s - loss: 3.6494 - acc: 0.19 - ETA: 24s - loss: 3.6537 - acc: 0.19 - ETA: 24s - loss: 3.6554 - acc: 0.19 - ETA: 24s - loss: 3.6373 - acc: 0.20 - ETA: 24s - loss: 3.6480 - acc: 0.19 - ETA: 24s - loss: 3.6489 - acc: 0.20 - ETA: 24s - loss: 3.6448 - acc: 0.20 - ETA: 24s - loss: 3.6477 - acc: 0.20 - ETA: 24s - loss: 3.6597 - acc: 0.19 - ETA: 24s - loss: 3.6637 - acc: 0.19 - ETA: 23s - loss: 3.6618 - acc: 0.19 - ETA: 23s - loss: 3.6649 - acc: 0.19 - ETA: 23s - loss: 3.6630 - acc: 0.19 - ETA: 23s - loss: 3.6643 - acc: 0.19 - ETA: 23s - loss: 3.6733 - acc: 0.18 - ETA: 23s - loss: 3.6740 - acc: 0.18 - ETA: 23s - loss: 3.6808 - acc: 0.18 - ETA: 23s - loss: 3.6799 - acc: 0.18 - ETA: 23s - loss: 3.6832 - acc: 0.18 - ETA: 23s - loss: 3.6828 - acc: 0.17 - ETA: 23s - loss: 3.6885 - acc: 0.17 - ETA: 23s - loss: 3.6877 - acc: 0.17 - ETA: 23s - loss: 3.6898 - acc: 0.17 - ETA: 23s - loss: 3.6967 - acc: 0.17 - ETA: 23s - loss: 3.7047 - acc: 0.17 - ETA: 22s - loss: 3.7064 - acc: 0.17 - ETA: 22s - loss: 3.7032 - acc: 0.17 - ETA: 23s - loss: 3.7098 - acc: 0.16 - ETA: 22s - loss: 3.7107 - acc: 0.16 - ETA: 22s - loss: 3.7067 - acc: 0.16 - ETA: 22s - loss: 3.7114 - acc: 0.16 - ETA: 22s - loss: 3.7135 - acc: 0.16 - ETA: 22s - loss: 3.7156 - acc: 0.16 - ETA: 22s - loss: 3.7181 - acc: 0.16 - ETA: 22s - loss: 3.7186 - acc: 0.16 - ETA: 22s - loss: 3.7197 - acc: 0.16 - ETA: 22s - loss: 3.7232 - acc: 0.16 - ETA: 22s - loss: 3.7310 - acc: 0.16 - ETA: 22s - loss: 3.7273 - acc: 0.16 - ETA: 22s - loss: 3.7314 - acc: 0.16 - ETA: 22s - loss: 3.7344 - acc: 0.16 - ETA: 22s - loss: 3.7333 - acc: 0.16 - ETA: 22s - loss: 3.7336 - acc: 0.16 - ETA: 22s - loss: 3.7342 - acc: 0.16 - ETA: 22s - loss: 3.7362 - acc: 0.16 - ETA: 22s - loss: 3.7377 - acc: 0.16 - ETA: 22s - loss: 3.7360 - acc: 0.16 - ETA: 22s - loss: 3.7367 - acc: 0.16 - ETA: 22s - loss: 3.7417 - acc: 0.16 - ETA: 22s - loss: 3.7434 - acc: 0.16 - ETA: 22s - loss: 3.7461 - acc: 0.16 - ETA: 22s - loss: 3.7497 - acc: 0.16 - ETA: 22s - loss: 3.7520 - acc: 0.15 - ETA: 22s - loss: 3.7485 - acc: 0.15 - ETA: 22s - loss: 3.7528 - acc: 0.15 - ETA: 22s - loss: 3.7507 - acc: 0.15 - ETA: 22s - loss: 3.7550 - acc: 0.15 - ETA: 22s - loss: 3.7554 - acc: 0.15 - ETA: 22s - loss: 3.7560 - acc: 0.15 - ETA: 22s - loss: 3.7553 - acc: 0.15 - ETA: 22s - loss: 3.7602 - acc: 0.15 - ETA: 22s - loss: 3.7606 - acc: 0.15 - ETA: 22s - loss: 3.7628 - acc: 0.15 - ETA: 22s - loss: 3.7592 - acc: 0.15 - ETA: 22s - loss: 3.7612 - acc: 0.15 - ETA: 22s - loss: 3.7610 - acc: 0.15 - ETA: 22s - loss: 3.7603 - acc: 0.15 - ETA: 21s - loss: 3.7632 - acc: 0.15 - ETA: 21s - loss: 3.7668 - acc: 0.15 - ETA: 21s - loss: 3.7693 - acc: 0.15 - ETA: 21s - loss: 3.7687 - acc: 0.15 - ETA: 21s - loss: 3.7677 - acc: 0. ...
# Epoch 10/10
# 2418/2418 [==============================] - ETA: 24s - loss: 5.0574 - acc: 0.0000e+ - ETA: 24s - loss: 3.9333 - acc: 0.2500   - ETA: 26s - loss: 3.9388 - acc: 0.18 - ETA: 27s - loss: 3.7160 - acc: 0.18 - ETA: 26s - loss: 3.7557 - acc: 0.16 - ETA: 26s - loss: 3.7199 - acc: 0.16 - ETA: 25s - loss: 3.7275 - acc: 0.16 - ETA: 25s - loss: 3.6725 - acc: 0.18 - ETA: 25s - loss: 3.6233 - acc: 0.19 - ETA: 24s - loss: 3.6176 - acc: 0.20 - ETA: 24s - loss: 3.6116 - acc: 0.20 - ETA: 23s - loss: 3.6334 - acc: 0.18 - ETA: 23s - loss: 3.5943 - acc: 0.17 - ETA: 23s - loss: 3.6200 - acc: 0.16 - ETA: 23s - loss: 3.6130 - acc: 0.16 - ETA: 23s - loss: 3.5915 - acc: 0.16 - ETA: 23s - loss: 3.6277 - acc: 0.15 - ETA: 23s - loss: 3.6457 - acc: 0.15 - ETA: 23s - loss: 3.6723 - acc: 0.14 - ETA: 23s - loss: 3.6694 - acc: 0.15 - ETA: 23s - loss: 3.6911 - acc: 0.14 - ETA: 23s - loss: 3.6789 - acc: 0.15 - ETA: 23s - loss: 3.6775 - acc: 0.15 - ETA: 23s - loss: 3.6711 - acc: 0.15 - ETA: 23s - loss: 3.6894 - acc: 0.14 - ETA: 23s - loss: 3.6987 - acc: 0.14 - ETA: 23s - loss: 3.7013 - acc: 0.15 - ETA: 23s - loss: 3.7057 - acc: 0.15 - ETA: 23s - loss: 3.7139 - acc: 0.15 - ETA: 23s - loss: 3.7053 - acc: 0.15 - ETA: 23s - loss: 3.7080 - acc: 0.15 - ETA: 23s - loss: 3.7139 - acc: 0.15 - ETA: 23s - loss: 3.7136 - acc: 0.15 - ETA: 23s - loss: 3.7033 - acc: 0.15 - ETA: 23s - loss: 3.7010 - acc: 0.15 - ETA: 23s - loss: 3.7119 - acc: 0.15 - ETA: 23s - loss: 3.7108 - acc: 0.15 - ETA: 23s - loss: 3.7086 - acc: 0.15 - ETA: 23s - loss: 3.7138 - acc: 0.15 - ETA: 23s - loss: 3.7144 - acc: 0.15 - ETA: 23s - loss: 3.7164 - acc: 0.15 - ETA: 23s - loss: 3.7173 - acc: 0.15 - ETA: 23s - loss: 3.7106 - acc: 0.15 - ETA: 24s - loss: 3.7066 - acc: 0.15 - ETA: 24s - loss: 3.7068 - acc: 0.16 - ETA: 24s - loss: 3.7097 - acc: 0.15 - ETA: 23s - loss: 3.7084 - acc: 0.16 - ETA: 23s - loss: 3.7100 - acc: 0.16 - ETA: 23s - loss: 3.7123 - acc: 0.15 - ETA: 23s - loss: 3.7111 - acc: 0.15 - ETA: 23s - loss: 3.7144 - acc: 0.15 - ETA: 23s - loss: 3.7127 - acc: 0.15 - ETA: 23s - loss: 3.7155 - acc: 0.15 - ETA: 23s - loss: 3.7160 - acc: 0.15 - ETA: 23s - loss: 3.7184 - acc: 0.15 - ETA: 23s - loss: 3.7176 - acc: 0.15 - ETA: 23s - loss: 3.7193 - acc: 0.15 - ETA: 23s - loss: 3.7156 - acc: 0.15 - ETA: 23s - loss: 3.7173 - acc: 0.14 - ETA: 22s - loss: 3.7189 - acc: 0.14 - ETA: 22s - loss: 3.7179 - acc: 0.14 - ETA: 22s - loss: 3.7243 - acc: 0.14 - ETA: 22s - loss: 3.7248 - acc: 0.14 - ETA: 22s - loss: 3.7304 - acc: 0.14 - ETA: 22s - loss: 3.7325 - acc: 0.14 - ETA: 22s - loss: 3.7338 - acc: 0.14 - ETA: 22s - loss: 3.7326 - acc: 0.14 - ETA: 22s - loss: 3.7255 - acc: 0.14 - ETA: 22s - loss: 3.7236 - acc: 0.14 - ETA: 22s - loss: 3.7249 - acc: 0.14 - ETA: 22s - loss: 3.7296 - acc: 0.14 - ETA: 22s - loss: 3.7281 - acc: 0.14 - ETA: 22s - loss: 3.7289 - acc: 0.14 - ETA: 22s - loss: 3.7285 - acc: 0.14 - ETA: 22s - loss: 3.7329 - acc: 0.14 - ETA: 22s - loss: 3.7335 - acc: 0.14 - ETA: 22s - loss: 3.7343 - acc: 0.14 - ETA: 22s - loss: 3.7340 - acc: 0.14 - ETA: 21s - loss: 3.7340 - acc: 0.14 - ETA: 21s - loss: 3.7427 - acc: 0.14 - ETA: 21s - loss: 3.7437 - acc: 0.14 - ETA: 21s - loss: 3.7392 - acc: 0.14 - ETA: 21s - loss: 3.7403 - acc: 0.14 - ETA: 21s - loss: 3.7368 - acc: 0.14 - ETA: 21s - loss: 3.7377 - acc: 0.14 - ETA: 21s - loss: 3.7347 - acc: 0.14 - ETA: 21s - loss: 3.7378 - acc: 0.14 - ETA: 21s - loss: 3.7385 - acc: 0.14 - ETA: 21s - loss: 3.7422 - acc: 0.14 - ETA: 21s - loss: 3.7442 - acc: 0.14 - ETA: 21s - loss: 3.7451 - acc: 0.14 - ETA: 21s - loss: 3.7414 - acc: 0.14 - ETA: 21s - loss: 3.7389 - acc: 0.14 - ETA: 21s - loss: 3.7362 - acc: 0.14 - ETA: 21s - loss: 3.7352 - acc: 0.15 - ETA: 20s - loss: 3.7343 - acc: 0.15 - ETA: 20s - loss: 3.7356 - acc: 0.15 - ETA: 20s - loss: 3.7327 - acc: 0.15 - ETA: 20s - loss: 3.7306 - acc: 0.15 - ETA: 20s - loss: 3.7288 - acc: 0.15 - ETA: 20s - loss: 3.7268 - acc: 0.15 - ETA: 20s - loss: 3.7268 - acc: 0.15 - ETA: 20s - loss: 3.7256 - acc: 0.15 - ETA: 20s - loss: 3.7254 - acc: 0. ...

# %%
x = embedding_layer(main_input)
x = CuDNNLSTM(LSTM_HIDDEN_SIZE, return_sequences=True)(x)
Avg = keras.layers.core.Lambda(lambda x: K.mean(x, axis=1), output_shape=(LSTM_HIDDEN_SIZE,))
x = Avg(x)
x = Dense(LSTM_HIDDEN_SIZE)(x)
main_lstm_out = Activation('relu')(x)


lstm_hidden_and_entity = Concatenate(axis=0)([Transpose(main_lstm_out), the_entity])
# lstm_hidden_and_entity = the_entity
print("lstm_hidden_and_entity", K.int_shape(lstm_hidden_and_entity))
# input("continue?")

final_output = Dense(units=len(unique_labels), activation='softmax')(Transpose(lstm_hidden_and_entity))

optimizer = Adam(lr=LEARNING_RATE, clipvalue=0.25)

m2 = Model(inputs=main_input, outputs=final_output)

m2.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['acc'])

_, tmpfn = tempfile.mkstemp()
# Save the best model during validation and bail out of training early if we're not improving
callbacks = [ModelCheckpoint(tmpfn, monitor='val_acc', save_best_only=True, save_weights_only=True)]

m2.summary()

from tensorflow.keras.utils import plot_model
# plot_model(m, to_file='model.png')

_, tmpfn = tempfile.mkstemp()
# Save the best model during validation and bail out of training early if we're not improving
callbacks = [ModelCheckpoint(tmpfn,monitor='val_acc', save_best_only=True, save_weights_only=True)]
# Out:
# lstm_hidden_and_entity (247, None)
# Model: "model_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input (InputLayer)         [(None, 300)]        0
# __________________________________________________________________________________________________
# embedding_7 (Embedding)         (None, 300, 300)     6000000     main_input[0][0]
#                                                                  main_input[0][0]
# __________________________________________________________________________________________________
# cu_dnnlstm_11 (CuDNNLSTM)       (None, 300, 47)      65612       embedding_7[0][0]
# __________________________________________________________________________________________________
# lambda_46 (Lambda)              (None, 47)           0           cu_dnnlstm_11[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 47)           2256        lambda_46[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 47)           0           dense_11[0][0]
# __________________________________________________________________________________________________
# lambda_51 (Lambda)              (20, 2585, 100)      0           activation_11[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (20, 861, 1)         301         lambda_51[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_14 (MaxPooling1D) (20, 287, 1)         0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# cu_dnnlstm_12 (CuDNNLSTM)       (None, 300, 200)     401600      embedding_7[1][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (20, 95, 1)          4           max_pooling1d_14[0][0]
# __________________________________________________________________________________________________
# lambda_52 (Lambda)              (None, 200)          0           cu_dnnlstm_12[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_15 (MaxPooling1D) (20, 47, 1)          0           conv1d_15[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 200)          40200       lambda_52[0][0]
# __________________________________________________________________________________________________
# lambda_49 (Lambda)              (20, 47)             0           max_pooling1d_15[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 200)          0           dense_13[0][0]
# __________________________________________________________________________________________________
# entity_cluster_reps (Reshape)   (20, 47)             0           lambda_49[0][0]
# __________________________________________________________________________________________________
# lambda_50 (Lambda)              multiple             0           activation_11[0][0]
#                                                                  entity_cluster_reps[0][0]
#                                                                  activation_12[0][0]
#                                                                  concatenate[0][0]
# __________________________________________________________________________________________________
# lambda_47 (Lambda)              multiple             0           entity_cluster_reps[0][0]
#                                                                  lambda_50[0][0]
#                                                                  lambda_50[1][0]
#                                                                  entity_attention[0][0]
# __________________________________________________________________________________________________
# entity_attention (Softmax)      (20, None)           0           lambda_47[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (247, None)          0           lambda_50[3][0]
#                                                                  lambda_47[1][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 78)           19344       lambda_50[4][0]
# ==================================================================================================
# Total params: 6,529,317
# Trainable params: 529,317
# Non-trainable params: 6,000,000
# __________________________________________________________________________________________________

# %%
BATCH_SIZE = 2
NUM_EPOCHS = 10

history = m2.fit(x_train, y_train,
                batch_size=BATCH_SIZE,
                epochs=NUM_EPOCHS,
                validation_data=(x_val, y_val), 
                callbacks=callbacks)
# m.save('node2vec_lstm_model')
# Out:
# Epoch 1/10
# 2418/2418 [==============================] - ETA: 1:11:50 - loss: 7.2254 - acc: 0.0000e+ - ETA: 1:05 - loss: 7.1679 - acc: 0.0000e+00   - ETA: 1:04 - loss: 6.8003 - acc: 0.0000e+0 - ETA: 1:03 - loss: 6.7538 - acc: 0.0000e+0 - ETA: 1:05 - loss: 6.6375 - acc: 0.0000e+0 - ETA: 1:03 - loss: 6.3145 - acc: 0.0000e+0 - ETA: 1:01 - loss: 6.2957 - acc: 0.0000e+0 - ETA: 1:01 - loss: 6.2813 - acc: 0.0000e+0 - ETA: 1:00 - loss: 6.4059 - acc: 0.0000e+0 - ETA: 1:00 - loss: 6.4646 - acc: 0.0000e+0 - ETA: 1:00 - loss: 6.2589 - acc: 0.0000e+0 - ETA: 59s - loss: 6.1739 - acc: 0.0000e+0 - ETA: 59s - loss: 6.1250 - acc: 0.0000e+ - ETA: 59s - loss: 6.1809 - acc: 0.0000e+ - ETA: 59s - loss: 6.1095 - acc: 0.0000e+ - ETA: 58s - loss: 6.0120 - acc: 0.0000e+ - ETA: 58s - loss: 5.9598 - acc: 0.0000e+ - ETA: 58s - loss: 5.9370 - acc: 0.0000e+ - ETA: 58s - loss: 5.9218 - acc: 0.0000e+ - ETA: 58s - loss: 5.8304 - acc: 0.0093   - ETA: 58s - loss: 5.7933 - acc: 0.00 - ETA: 57s - loss: 5.7470 - acc: 0.00 - ETA: 57s - loss: 5.7178 - acc: 0.00 - ETA: 57s - loss: 5.7393 - acc: 0.00 - ETA: 57s - loss: 5.6678 - acc: 0.00 - ETA: 57s - loss: 5.6205 - acc: 0.00 - ETA: 57s - loss: 5.5995 - acc: 0.00 - ETA: 56s - loss: 5.5636 - acc: 0.00 - ETA: 56s - loss: 5.5354 - acc: 0.00 - ETA: 56s - loss: 5.5005 - acc: 0.00 - ETA: 56s - loss: 5.4856 - acc: 0.00 - ETA: 56s - loss: 5.4496 - acc: 0.00 - ETA: 56s - loss: 5.4205 - acc: 0.00 - ETA: 56s - loss: 5.3832 - acc: 0.00 - ETA: 56s - loss: 5.3556 - acc: 0.00 - ETA: 56s - loss: 5.3518 - acc: 0.00 - ETA: 56s - loss: 5.3082 - acc: 0.00 - ETA: 56s - loss: 5.3034 - acc: 0.00 - ETA: 56s - loss: 5.3012 - acc: 0.00 - ETA: 56s - loss: 5.2935 - acc: 0.00 - ETA: 56s - loss: 5.2832 - acc: 0.00 - ETA: 55s - loss: 5.2611 - acc: 0.00 - ETA: 55s - loss: 5.2230 - acc: 0.01 - ETA: 55s - loss: 5.1919 - acc: 0.01 - ETA: 55s - loss: 5.1971 - acc: 0.01 - ETA: 55s - loss: 5.1786 - acc: 0.01 - ETA: 55s - loss: 5.1601 - acc: 0.01 - ETA: 55s - loss: 5.1290 - acc: 0.02 - ETA: 55s - loss: 5.1219 - acc: 0.02 - ETA: 55s - loss: 5.1069 - acc: 0.02 - ETA: 55s - loss: 5.0957 - acc: 0.02 - ETA: 55s - loss: 5.1039 - acc: 0.02 - ETA: 55s - loss: 5.0799 - acc: 0.02 - ETA: 55s - loss: 5.0465 - acc: 0.02 - ETA: 55s - loss: 5.0363 - acc: 0.02 - ETA: 55s - loss: 5.0215 - acc: 0.02 - ETA: 55s - loss: 4.9915 - acc: 0.03 - ETA: 54s - loss: 4.9928 - acc: 0.03 - ETA: 54s - loss: 5.0016 - acc: 0.03 - ETA: 54s - loss: 4.9973 - acc: 0.03 - ETA: 54s - loss: 4.9955 - acc: 0.02 - ETA: 54s - loss: 5.0009 - acc: 0.02 - ETA: 54s - loss: 4.9957 - acc: 0.02 - ETA: 54s - loss: 4.9883 - acc: 0.02 - ETA: 54s - loss: 4.9793 - acc: 0.03 - ETA: 54s - loss: 4.9737 - acc: 0.03 - ETA: 54s - loss: 4.9597 - acc: 0.03 - ETA: 54s - loss: 4.9526 - acc: 0.03 - ETA: 54s - loss: 4.9361 - acc: 0.03 - ETA: 54s - loss: 4.9214 - acc: 0.03 - ETA: 54s - loss: 4.9105 - acc: 0.03 - ETA: 54s - loss: 4.9197 - acc: 0.03 - ETA: 54s - loss: 4.8938 - acc: 0.04 - ETA: 54s - loss: 4.8805 - acc: 0.04 - ETA: 54s - loss: 4.8734 - acc: 0.04 - ETA: 54s - loss: 4.8688 - acc: 0.04 - ETA: 53s - loss: 4.8598 - acc: 0.05 - ETA: 53s - loss: 4.8386 - acc: 0.05 - ETA: 53s - loss: 4.8313 - acc: 0.05 - ETA: 53s - loss: 4.8177 - acc: 0.05 - ETA: 53s - loss: 4.8094 - acc: 0.05 - ETA: 53s - loss: 4.8066 - acc: 0.05 - ETA: 53s - loss: 4.8003 - acc: 0.05 - ETA: 53s - loss: 4.8031 - acc: 0.05 - ETA: 53s - loss: 4.7974 - acc: 0.05 - ETA: 53s - loss: 4.7862 - acc: 0.05 - ETA: 53s - loss: 4.7797 - acc: 0.05 - ETA: 53s - loss: 4.7745 - acc: 0.05 - ETA: 53s - loss: 4.7672 - acc: 0.05 - ETA: 53s - loss: 4.7589 - acc: 0.05 - ETA: 53s - loss: 4.7472 - acc: 0.05 - ETA: 53s - loss: 4.7391 - acc: 0.06 - ETA: 53s - loss: 4.7219 - acc: 0.06 - ETA: 52s - loss: 4.7134 - acc: 0.06 - ETA: 52s - loss: 4.7048 - acc: 0.06 - ETA: 52s - loss: 4.6971 - acc: 0.06 - ETA: 52s - loss: 4.6807 - acc: 0.06 - ETA: 52s - loss: 4.6683 - acc: 0.06 - ETA: 52s - loss: 4.6606 - acc: 0.06 - ETA: 52s - loss: 4.6565 - acc: 0.06 - ETA: 52s - loss: 4.6480 - acc: 0.06 - ETA: 52s  ...
# Epoch 2/10
# 2418/2418 [==============================] - ETA: 58s - loss: 3.9580 - acc: 0.0000e+ - ETA: 58s - loss: 2.6087 - acc: 0.2500   - ETA: 59s - loss: 2.6121 - acc: 0.16 - ETA: 59s - loss: 2.1510 - acc: 0.33 - ETA: 59s - loss: 2.3546 - acc: 0.29 - ETA: 58s - loss: 2.4183 - acc: 0.30 - ETA: 58s - loss: 2.3367 - acc: 0.32 - ETA: 59s - loss: 2.2779 - acc: 0.32 - ETA: 58s - loss: 2.1013 - acc: 0.41 - ETA: 58s - loss: 2.2026 - acc: 0.38 - ETA: 58s - loss: 2.0792 - acc: 0.42 - ETA: 58s - loss: 1.9885 - acc: 0.45 - ETA: 58s - loss: 2.0245 - acc: 0.43 - ETA: 58s - loss: 1.9604 - acc: 0.44 - ETA: 58s - loss: 1.9480 - acc: 0.42 - ETA: 58s - loss: 1.9120 - acc: 0.43 - ETA: 58s - loss: 1.9053 - acc: 0.42 - ETA: 58s - loss: 1.8845 - acc: 0.42 - ETA: 58s - loss: 1.8599 - acc: 0.43 - ETA: 58s - loss: 1.8802 - acc: 0.42 - ETA: 57s - loss: 1.8608 - acc: 0.43 - ETA: 57s - loss: 1.8706 - acc: 0.43 - ETA: 57s - loss: 1.8677 - acc: 0.43 - ETA: 57s - loss: 1.8475 - acc: 0.43 - ETA: 57s - loss: 1.8632 - acc: 0.43 - ETA: 57s - loss: 1.8653 - acc: 0.42 - ETA: 57s - loss: 1.8359 - acc: 0.43 - ETA: 57s - loss: 1.8342 - acc: 0.43 - ETA: 57s - loss: 1.8626 - acc: 0.44 - ETA: 57s - loss: 1.8476 - acc: 0.44 - ETA: 57s - loss: 1.8371 - acc: 0.46 - ETA: 56s - loss: 1.8357 - acc: 0.47 - ETA: 56s - loss: 1.8219 - acc: 0.47 - ETA: 56s - loss: 1.8094 - acc: 0.48 - ETA: 56s - loss: 1.8179 - acc: 0.47 - ETA: 56s - loss: 1.8380 - acc: 0.47 - ETA: 56s - loss: 1.8382 - acc: 0.46 - ETA: 56s - loss: 1.8464 - acc: 0.46 - ETA: 56s - loss: 1.8469 - acc: 0.46 - ETA: 56s - loss: 1.8623 - acc: 0.46 - ETA: 56s - loss: 1.8464 - acc: 0.46 - ETA: 56s - loss: 1.8727 - acc: 0.46 - ETA: 56s - loss: 1.8814 - acc: 0.46 - ETA: 56s - loss: 1.8815 - acc: 0.45 - ETA: 56s - loss: 1.8733 - acc: 0.45 - ETA: 56s - loss: 1.8630 - acc: 0.46 - ETA: 55s - loss: 1.8592 - acc: 0.46 - ETA: 55s - loss: 1.8417 - acc: 0.47 - ETA: 55s - loss: 1.8234 - acc: 0.47 - ETA: 55s - loss: 1.8131 - acc: 0.47 - ETA: 55s - loss: 1.8345 - acc: 0.47 - ETA: 55s - loss: 1.8291 - acc: 0.47 - ETA: 55s - loss: 1.8416 - acc: 0.46 - ETA: 55s - loss: 1.8487 - acc: 0.46 - ETA: 55s - loss: 1.8320 - acc: 0.47 - ETA: 55s - loss: 1.8462 - acc: 0.46 - ETA: 55s - loss: 1.8402 - acc: 0.47 - ETA: 55s - loss: 1.8231 - acc: 0.47 - ETA: 55s - loss: 1.8410 - acc: 0.47 - ETA: 54s - loss: 1.8234 - acc: 0.47 - ETA: 54s - loss: 1.8326 - acc: 0.47 - ETA: 54s - loss: 1.8254 - acc: 0.47 - ETA: 54s - loss: 1.8299 - acc: 0.47 - ETA: 54s - loss: 1.8116 - acc: 0.48 - ETA: 54s - loss: 1.7974 - acc: 0.48 - ETA: 54s - loss: 1.8009 - acc: 0.48 - ETA: 54s - loss: 1.7953 - acc: 0.48 - ETA: 54s - loss: 1.7892 - acc: 0.49 - ETA: 54s - loss: 1.7776 - acc: 0.49 - ETA: 54s - loss: 1.7796 - acc: 0.48 - ETA: 54s - loss: 1.7776 - acc: 0.48 - ETA: 54s - loss: 1.7676 - acc: 0.49 - ETA: 54s - loss: 1.7807 - acc: 0.48 - ETA: 54s - loss: 1.7848 - acc: 0.48 - ETA: 54s - loss: 1.7824 - acc: 0.48 - ETA: 53s - loss: 1.7866 - acc: 0.48 - ETA: 53s - loss: 1.7965 - acc: 0.48 - ETA: 53s - loss: 1.8010 - acc: 0.48 - ETA: 53s - loss: 1.8086 - acc: 0.47 - ETA: 53s - loss: 1.8094 - acc: 0.47 - ETA: 53s - loss: 1.8139 - acc: 0.47 - ETA: 53s - loss: 1.8093 - acc: 0.47 - ETA: 53s - loss: 1.8108 - acc: 0.47 - ETA: 53s - loss: 1.8017 - acc: 0.47 - ETA: 53s - loss: 1.7858 - acc: 0.48 - ETA: 53s - loss: 1.7835 - acc: 0.48 - ETA: 53s - loss: 1.7735 - acc: 0.48 - ETA: 53s - loss: 1.7823 - acc: 0.48 - ETA: 53s - loss: 1.7816 - acc: 0.48 - ETA: 53s - loss: 1.7820 - acc: 0.48 - ETA: 53s - loss: 1.7758 - acc: 0.49 - ETA: 52s - loss: 1.7730 - acc: 0.48 - ETA: 52s - loss: 1.7609 - acc: 0.49 - ETA: 52s - loss: 1.7614 - acc: 0.49 - ETA: 52s - loss: 1.7740 - acc: 0.49 - ETA: 52s - loss: 1.7845 - acc: 0.49 - ETA: 52s - loss: 1.7956 - acc: 0.49 - ETA: 52s - loss: 1.7881 - acc: 0.49 - ETA: 52s - loss: 1.7907 - acc: 0.49 - ETA: 52s - loss: 1.7913 - acc: 0.49 - ETA: 52s - loss: 1.7845 - acc: 0.49 - ETA: 52s - loss: 1.7789 - acc: 0.49 - ETA: 52s - loss: 1.7723 - acc: 0.49 - ETA: 52s - loss: 1.7793 - acc: 0. ...
# Epoch 3/10
# 2418/2418 [==============================] - ETA: 54s - loss: 0.6855 - acc: 0.50 - ETA: 52s - loss: 1.0252 - acc: 0.50 - ETA: 53s - loss: 1.1576 - acc: 0.57 - ETA: 53s - loss: 1.3089 - acc: 0.55 - ETA: 54s - loss: 1.3489 - acc: 0.57 - ETA: 54s - loss: 1.4449 - acc: 0.56 - ETA: 54s - loss: 1.6398 - acc: 0.52 - ETA: 55s - loss: 1.5959 - acc: 0.52 - ETA: 55s - loss: 1.5373 - acc: 0.54 - ETA: 55s - loss: 1.5933 - acc: 0.51 - ETA: 55s - loss: 1.4668 - acc: 0.54 - ETA: 55s - loss: 1.5251 - acc: 0.55 - ETA: 55s - loss: 1.4514 - acc: 0.58 - ETA: 55s - loss: 1.4097 - acc: 0.58 - ETA: 55s - loss: 1.3699 - acc: 0.60 - ETA: 55s - loss: 1.3210 - acc: 0.60 - ETA: 55s - loss: 1.3406 - acc: 0.59 - ETA: 55s - loss: 1.3152 - acc: 0.58 - ETA: 55s - loss: 1.2747 - acc: 0.60 - ETA: 56s - loss: 1.2879 - acc: 0.60 - ETA: 56s - loss: 1.3085 - acc: 0.60 - ETA: 56s - loss: 1.2691 - acc: 0.62 - ETA: 55s - loss: 1.2698 - acc: 0.62 - ETA: 55s - loss: 1.2737 - acc: 0.62 - ETA: 55s - loss: 1.2766 - acc: 0.61 - ETA: 55s - loss: 1.2742 - acc: 0.62 - ETA: 55s - loss: 1.3008 - acc: 0.61 - ETA: 55s - loss: 1.2719 - acc: 0.61 - ETA: 55s - loss: 1.2586 - acc: 0.62 - ETA: 55s - loss: 1.2336 - acc: 0.62 - ETA: 55s - loss: 1.2523 - acc: 0.61 - ETA: 55s - loss: 1.2559 - acc: 0.62 - ETA: 55s - loss: 1.2544 - acc: 0.62 - ETA: 55s - loss: 1.2375 - acc: 0.63 - ETA: 55s - loss: 1.2455 - acc: 0.63 - ETA: 55s - loss: 1.2287 - acc: 0.64 - ETA: 55s - loss: 1.2224 - acc: 0.64 - ETA: 55s - loss: 1.2051 - acc: 0.64 - ETA: 54s - loss: 1.1935 - acc: 0.64 - ETA: 54s - loss: 1.1845 - acc: 0.64 - ETA: 54s - loss: 1.2160 - acc: 0.64 - ETA: 54s - loss: 1.2538 - acc: 0.64 - ETA: 54s - loss: 1.2522 - acc: 0.64 - ETA: 54s - loss: 1.2440 - acc: 0.64 - ETA: 54s - loss: 1.2245 - acc: 0.65 - ETA: 54s - loss: 1.2432 - acc: 0.64 - ETA: 54s - loss: 1.2615 - acc: 0.63 - ETA: 54s - loss: 1.2526 - acc: 0.63 - ETA: 54s - loss: 1.2396 - acc: 0.64 - ETA: 54s - loss: 1.2440 - acc: 0.63 - ETA: 54s - loss: 1.2417 - acc: 0.63 - ETA: 54s - loss: 1.2467 - acc: 0.64 - ETA: 54s - loss: 1.2317 - acc: 0.64 - ETA: 54s - loss: 1.2345 - acc: 0.64 - ETA: 54s - loss: 1.2307 - acc: 0.65 - ETA: 54s - loss: 1.2167 - acc: 0.65 - ETA: 53s - loss: 1.2259 - acc: 0.64 - ETA: 53s - loss: 1.2244 - acc: 0.64 - ETA: 53s - loss: 1.2433 - acc: 0.64 - ETA: 53s - loss: 1.2288 - acc: 0.65 - ETA: 53s - loss: 1.2167 - acc: 0.65 - ETA: 53s - loss: 1.2364 - acc: 0.64 - ETA: 53s - loss: 1.2183 - acc: 0.65 - ETA: 53s - loss: 1.2542 - acc: 0.64 - ETA: 53s - loss: 1.2515 - acc: 0.64 - ETA: 53s - loss: 1.2507 - acc: 0.63 - ETA: 53s - loss: 1.2794 - acc: 0.63 - ETA: 53s - loss: 1.2771 - acc: 0.63 - ETA: 52s - loss: 1.2646 - acc: 0.64 - ETA: 52s - loss: 1.2801 - acc: 0.63 - ETA: 52s - loss: 1.2887 - acc: 0.63 - ETA: 52s - loss: 1.2861 - acc: 0.63 - ETA: 52s - loss: 1.2964 - acc: 0.63 - ETA: 52s - loss: 1.2936 - acc: 0.63 - ETA: 52s - loss: 1.3061 - acc: 0.63 - ETA: 52s - loss: 1.3027 - acc: 0.63 - ETA: 52s - loss: 1.2921 - acc: 0.64 - ETA: 52s - loss: 1.2889 - acc: 0.64 - ETA: 52s - loss: 1.2899 - acc: 0.63 - ETA: 52s - loss: 1.2952 - acc: 0.63 - ETA: 52s - loss: 1.2991 - acc: 0.63 - ETA: 52s - loss: 1.3046 - acc: 0.63 - ETA: 52s - loss: 1.2999 - acc: 0.63 - ETA: 52s - loss: 1.2974 - acc: 0.63 - ETA: 52s - loss: 1.2924 - acc: 0.63 - ETA: 52s - loss: 1.2836 - acc: 0.64 - ETA: 52s - loss: 1.2800 - acc: 0.64 - ETA: 52s - loss: 1.2745 - acc: 0.64 - ETA: 52s - loss: 1.2643 - acc: 0.64 - ETA: 52s - loss: 1.2566 - acc: 0.64 - ETA: 51s - loss: 1.2599 - acc: 0.64 - ETA: 51s - loss: 1.2501 - acc: 0.64 - ETA: 51s - loss: 1.2611 - acc: 0.64 - ETA: 51s - loss: 1.2482 - acc: 0.65 - ETA: 51s - loss: 1.2429 - acc: 0.65 - ETA: 51s - loss: 1.2365 - acc: 0.65 - ETA: 51s - loss: 1.2422 - acc: 0.65 - ETA: 51s - loss: 1.2550 - acc: 0.65 - ETA: 51s - loss: 1.2470 - acc: 0.65 - ETA: 51s - loss: 1.2520 - acc: 0.65 - ETA: 51s - loss: 1.2498 - acc: 0.64 - ETA: 51s - loss: 1.2495 - acc: 0.64 - ETA: 51s - loss: 1.2549 - acc: 0.64 - ETA: 51s - loss: 1.2523 - acc: 0.64 - ETA ...
# Epoch 4/10
# 2418/2418 [==============================] - ETA: 1:00 - loss: 0.3276 - acc: 1.000 - ETA: 58s - loss: 0.3285 - acc: 1.000 - ETA: 55s - loss: 0.7853 - acc: 0.85 - ETA: 56s - loss: 0.7678 - acc: 0.80 - ETA: 56s - loss: 0.6970 - acc: 0.80 - ETA: 57s - loss: 0.5793 - acc: 0.84 - ETA: 57s - loss: 0.7047 - acc: 0.81 - ETA: 56s - loss: 0.7466 - acc: 0.79 - ETA: 56s - loss: 0.7880 - acc: 0.80 - ETA: 57s - loss: 0.7922 - acc: 0.79 - ETA: 58s - loss: 0.7983 - acc: 0.79 - ETA: 59s - loss: 0.7728 - acc: 0.80 - ETA: 59s - loss: 0.7299 - acc: 0.82 - ETA: 59s - loss: 0.7182 - acc: 0.83 - ETA: 59s - loss: 0.7558 - acc: 0.80 - ETA: 58s - loss: 0.8090 - acc: 0.78 - ETA: 58s - loss: 0.7966 - acc: 0.78 - ETA: 58s - loss: 0.7984 - acc: 0.79 - ETA: 57s - loss: 0.8181 - acc: 0.77 - ETA: 57s - loss: 0.7847 - acc: 0.78 - ETA: 57s - loss: 0.8181 - acc: 0.78 - ETA: 57s - loss: 0.8143 - acc: 0.78 - ETA: 57s - loss: 0.8014 - acc: 0.78 - ETA: 57s - loss: 0.7833 - acc: 0.78 - ETA: 57s - loss: 0.8180 - acc: 0.77 - ETA: 57s - loss: 0.8105 - acc: 0.77 - ETA: 57s - loss: 0.8352 - acc: 0.77 - ETA: 57s - loss: 0.8268 - acc: 0.78 - ETA: 57s - loss: 0.8168 - acc: 0.78 - ETA: 57s - loss: 0.8847 - acc: 0.76 - ETA: 57s - loss: 0.8989 - acc: 0.75 - ETA: 56s - loss: 0.9065 - acc: 0.75 - ETA: 56s - loss: 0.9127 - acc: 0.75 - ETA: 56s - loss: 0.9240 - acc: 0.74 - ETA: 56s - loss: 0.9170 - acc: 0.74 - ETA: 56s - loss: 0.8989 - acc: 0.75 - ETA: 56s - loss: 0.8783 - acc: 0.75 - ETA: 56s - loss: 0.8628 - acc: 0.76 - ETA: 55s - loss: 0.8710 - acc: 0.76 - ETA: 55s - loss: 0.8642 - acc: 0.77 - ETA: 55s - loss: 0.8819 - acc: 0.77 - ETA: 55s - loss: 0.8694 - acc: 0.77 - ETA: 55s - loss: 0.8709 - acc: 0.77 - ETA: 55s - loss: 0.8572 - acc: 0.77 - ETA: 55s - loss: 0.8393 - acc: 0.78 - ETA: 55s - loss: 0.8225 - acc: 0.78 - ETA: 55s - loss: 0.8173 - acc: 0.79 - ETA: 55s - loss: 0.8066 - acc: 0.79 - ETA: 55s - loss: 0.7973 - acc: 0.79 - ETA: 55s - loss: 0.7878 - acc: 0.80 - ETA: 55s - loss: 0.7848 - acc: 0.80 - ETA: 54s - loss: 0.7768 - acc: 0.80 - ETA: 54s - loss: 0.7790 - acc: 0.80 - ETA: 54s - loss: 0.7747 - acc: 0.81 - ETA: 54s - loss: 0.7695 - acc: 0.81 - ETA: 54s - loss: 0.7861 - acc: 0.81 - ETA: 54s - loss: 0.8140 - acc: 0.80 - ETA: 54s - loss: 0.8057 - acc: 0.80 - ETA: 54s - loss: 0.8108 - acc: 0.80 - ETA: 54s - loss: 0.8132 - acc: 0.80 - ETA: 53s - loss: 0.8273 - acc: 0.79 - ETA: 53s - loss: 0.8222 - acc: 0.79 - ETA: 53s - loss: 0.8182 - acc: 0.79 - ETA: 53s - loss: 0.8098 - acc: 0.79 - ETA: 53s - loss: 0.8047 - acc: 0.79 - ETA: 53s - loss: 0.7967 - acc: 0.80 - ETA: 53s - loss: 0.7976 - acc: 0.80 - ETA: 53s - loss: 0.8018 - acc: 0.79 - ETA: 53s - loss: 0.8004 - acc: 0.79 - ETA: 53s - loss: 0.7972 - acc: 0.80 - ETA: 53s - loss: 0.8105 - acc: 0.79 - ETA: 53s - loss: 0.8147 - acc: 0.79 - ETA: 53s - loss: 0.8083 - acc: 0.79 - ETA: 53s - loss: 0.8067 - acc: 0.79 - ETA: 53s - loss: 0.8113 - acc: 0.79 - ETA: 53s - loss: 0.8077 - acc: 0.79 - ETA: 53s - loss: 0.8141 - acc: 0.79 - ETA: 53s - loss: 0.8115 - acc: 0.79 - ETA: 53s - loss: 0.8144 - acc: 0.79 - ETA: 53s - loss: 0.8172 - acc: 0.79 - ETA: 53s - loss: 0.8171 - acc: 0.79 - ETA: 53s - loss: 0.8196 - acc: 0.79 - ETA: 52s - loss: 0.8223 - acc: 0.79 - ETA: 52s - loss: 0.8179 - acc: 0.79 - ETA: 52s - loss: 0.8431 - acc: 0.78 - ETA: 52s - loss: 0.8408 - acc: 0.78 - ETA: 52s - loss: 0.8388 - acc: 0.78 - ETA: 52s - loss: 0.8304 - acc: 0.79 - ETA: 52s - loss: 0.8232 - acc: 0.79 - ETA: 52s - loss: 0.8193 - acc: 0.79 - ETA: 52s - loss: 0.8336 - acc: 0.78 - ETA: 52s - loss: 0.8376 - acc: 0.78 - ETA: 52s - loss: 0.8385 - acc: 0.78 - ETA: 52s - loss: 0.8387 - acc: 0.78 - ETA: 51s - loss: 0.8348 - acc: 0.78 - ETA: 51s - loss: 0.8368 - acc: 0.79 - ETA: 51s - loss: 0.8298 - acc: 0.79 - ETA: 51s - loss: 0.8238 - acc: 0.79 - ETA: 51s - loss: 0.8198 - acc: 0.79 - ETA: 51s - loss: 0.8145 - acc: 0.79 - ETA: 51s - loss: 0.8099 - acc: 0.79 - ETA: 51s - loss: 0.8052 - acc: 0.79 - ETA: 51s - loss: 0.8060 - acc: 0.79 - ETA: 51s - loss: 0.8088 - acc: 0.79 -  ...
# Epoch 5/10
# 2418/2418 [==============================] - ETA: 54s - loss: 0.0018 - acc: 1.00 - ETA: 55s - loss: 0.3150 - acc: 0.87 - ETA: 55s - loss: 0.5567 - acc: 0.78 - ETA: 57s - loss: 0.4975 - acc: 0.83 - ETA: 1:00 - loss: 0.4646 - acc: 0.863 - ETA: 1:00 - loss: 0.4817 - acc: 0.884 - ETA: 1:00 - loss: 0.4063 - acc: 0.906 - ETA: 1:00 - loss: 0.4121 - acc: 0.894 - ETA: 59s - loss: 0.3899 - acc: 0.909 - ETA: 59s - loss: 0.4041 - acc: 0.90 - ETA: 58s - loss: 0.4514 - acc: 0.89 - ETA: 58s - loss: 0.4927 - acc: 0.85 - ETA: 58s - loss: 0.5086 - acc: 0.83 - ETA: 58s - loss: 0.5042 - acc: 0.83 - ETA: 58s - loss: 0.4840 - acc: 0.85 - ETA: 57s - loss: 0.4718 - acc: 0.84 - ETA: 57s - loss: 0.4615 - acc: 0.84 - ETA: 57s - loss: 0.4382 - acc: 0.85 - ETA: 57s - loss: 0.4413 - acc: 0.86 - ETA: 57s - loss: 0.4520 - acc: 0.85 - ETA: 57s - loss: 0.4529 - acc: 0.85 - ETA: 57s - loss: 0.4546 - acc: 0.85 - ETA: 56s - loss: 0.4849 - acc: 0.84 - ETA: 56s - loss: 0.4857 - acc: 0.84 - ETA: 56s - loss: 0.5141 - acc: 0.83 - ETA: 56s - loss: 0.4982 - acc: 0.84 - ETA: 56s - loss: 0.4968 - acc: 0.84 - ETA: 57s - loss: 0.5094 - acc: 0.84 - ETA: 57s - loss: 0.5547 - acc: 0.83 - ETA: 57s - loss: 0.5659 - acc: 0.83 - ETA: 56s - loss: 0.5502 - acc: 0.84 - ETA: 56s - loss: 0.5418 - acc: 0.84 - ETA: 56s - loss: 0.5340 - acc: 0.84 - ETA: 56s - loss: 0.5332 - acc: 0.84 - ETA: 56s - loss: 0.5337 - acc: 0.84 - ETA: 56s - loss: 0.5419 - acc: 0.83 - ETA: 55s - loss: 0.5699 - acc: 0.82 - ETA: 55s - loss: 0.5963 - acc: 0.81 - ETA: 55s - loss: 0.6085 - acc: 0.80 - ETA: 55s - loss: 0.6243 - acc: 0.80 - ETA: 55s - loss: 0.6400 - acc: 0.79 - ETA: 55s - loss: 0.6313 - acc: 0.79 - ETA: 55s - loss: 0.6345 - acc: 0.79 - ETA: 55s - loss: 0.6233 - acc: 0.80 - ETA: 55s - loss: 0.6106 - acc: 0.80 - ETA: 55s - loss: 0.6049 - acc: 0.80 - ETA: 55s - loss: 0.6042 - acc: 0.80 - ETA: 55s - loss: 0.5929 - acc: 0.81 - ETA: 55s - loss: 0.5997 - acc: 0.81 - ETA: 55s - loss: 0.5978 - acc: 0.81 - ETA: 55s - loss: 0.5853 - acc: 0.81 - ETA: 55s - loss: 0.5833 - acc: 0.81 - ETA: 55s - loss: 0.5938 - acc: 0.81 - ETA: 55s - loss: 0.5868 - acc: 0.81 - ETA: 54s - loss: 0.5996 - acc: 0.81 - ETA: 54s - loss: 0.6119 - acc: 0.80 - ETA: 55s - loss: 0.6043 - acc: 0.81 - ETA: 55s - loss: 0.5975 - acc: 0.81 - ETA: 55s - loss: 0.5885 - acc: 0.81 - ETA: 54s - loss: 0.5801 - acc: 0.82 - ETA: 54s - loss: 0.5829 - acc: 0.82 - ETA: 54s - loss: 0.6037 - acc: 0.82 - ETA: 54s - loss: 0.5993 - acc: 0.82 - ETA: 54s - loss: 0.5920 - acc: 0.82 - ETA: 54s - loss: 0.5940 - acc: 0.82 - ETA: 54s - loss: 0.5881 - acc: 0.82 - ETA: 54s - loss: 0.5840 - acc: 0.83 - ETA: 54s - loss: 0.5855 - acc: 0.82 - ETA: 54s - loss: 0.5886 - acc: 0.82 - ETA: 54s - loss: 0.6112 - acc: 0.82 - ETA: 54s - loss: 0.6145 - acc: 0.82 - ETA: 54s - loss: 0.6139 - acc: 0.82 - ETA: 53s - loss: 0.6063 - acc: 0.82 - ETA: 53s - loss: 0.6041 - acc: 0.83 - ETA: 53s - loss: 0.6226 - acc: 0.82 - ETA: 53s - loss: 0.6237 - acc: 0.82 - ETA: 53s - loss: 0.6306 - acc: 0.82 - ETA: 53s - loss: 0.6345 - acc: 0.81 - ETA: 53s - loss: 0.6339 - acc: 0.81 - ETA: 53s - loss: 0.6308 - acc: 0.81 - ETA: 53s - loss: 0.6372 - acc: 0.81 - ETA: 53s - loss: 0.6445 - acc: 0.81 - ETA: 53s - loss: 0.6366 - acc: 0.81 - ETA: 52s - loss: 0.6347 - acc: 0.81 - ETA: 52s - loss: 0.6468 - acc: 0.81 - ETA: 52s - loss: 0.6545 - acc: 0.80 - ETA: 52s - loss: 0.6639 - acc: 0.80 - ETA: 52s - loss: 0.6608 - acc: 0.80 - ETA: 52s - loss: 0.6618 - acc: 0.80 - ETA: 52s - loss: 0.6659 - acc: 0.80 - ETA: 52s - loss: 0.6687 - acc: 0.80 - ETA: 52s - loss: 0.6635 - acc: 0.80 - ETA: 52s - loss: 0.6711 - acc: 0.80 - ETA: 52s - loss: 0.6670 - acc: 0.80 - ETA: 52s - loss: 0.6634 - acc: 0.80 - ETA: 51s - loss: 0.6701 - acc: 0.80 - ETA: 51s - loss: 0.6749 - acc: 0.80 - ETA: 51s - loss: 0.6738 - acc: 0.80 - ETA: 51s - loss: 0.6793 - acc: 0.80 - ETA: 51s - loss: 0.6742 - acc: 0.80 - ETA: 51s - loss: 0.6742 - acc: 0.80 - ETA: 51s - loss: 0.6692 - acc: 0.80 - ETA: 51s - loss: 0.6663 - acc: 0.80 - ETA: 51s - loss: 0.6603 - acc: 0 ...
# Epoch 6/10
# 2418/2418 [==============================] - ETA: 54s - loss: 0.1721 - acc: 1.00 - ETA: 54s - loss: 0.3978 - acc: 0.87 - ETA: 55s - loss: 0.6402 - acc: 0.85 - ETA: 55s - loss: 0.6130 - acc: 0.85 - ETA: 56s - loss: 0.5016 - acc: 0.88 - ETA: 55s - loss: 0.4807 - acc: 0.87 - ETA: 57s - loss: 0.4309 - acc: 0.88 - ETA: 59s - loss: 0.4776 - acc: 0.87 - ETA: 1:00 - loss: 0.4809 - acc: 0.863 - ETA: 1:00 - loss: 0.4625 - acc: 0.860 - ETA: 59s - loss: 0.4163 - acc: 0.875 - ETA: 58s - loss: 0.5076 - acc: 0.83 - ETA: 59s - loss: 0.4935 - acc: 0.84 - ETA: 59s - loss: 0.4567 - acc: 0.86 - ETA: 58s - loss: 0.4326 - acc: 0.87 - ETA: 58s - loss: 0.4043 - acc: 0.88 - ETA: 57s - loss: 0.3824 - acc: 0.88 - ETA: 57s - loss: 0.3863 - acc: 0.88 - ETA: 57s - loss: 0.4069 - acc: 0.87 - ETA: 58s - loss: 0.4617 - acc: 0.84 - ETA: 58s - loss: 0.4963 - acc: 0.83 - ETA: 58s - loss: 0.4949 - acc: 0.83 - ETA: 58s - loss: 0.4832 - acc: 0.84 - ETA: 57s - loss: 0.4811 - acc: 0.83 - ETA: 57s - loss: 0.4613 - acc: 0.84 - ETA: 57s - loss: 0.4466 - acc: 0.84 - ETA: 57s - loss: 0.4462 - acc: 0.84 - ETA: 57s - loss: 0.4357 - acc: 0.85 - ETA: 57s - loss: 0.4249 - acc: 0.85 - ETA: 56s - loss: 0.4821 - acc: 0.84 - ETA: 56s - loss: 0.4676 - acc: 0.85 - ETA: 56s - loss: 0.4547 - acc: 0.85 - ETA: 56s - loss: 0.4637 - acc: 0.85 - ETA: 56s - loss: 0.4565 - acc: 0.85 - ETA: 56s - loss: 0.4471 - acc: 0.85 - ETA: 56s - loss: 0.4691 - acc: 0.84 - ETA: 56s - loss: 0.4710 - acc: 0.84 - ETA: 56s - loss: 0.4732 - acc: 0.83 - ETA: 56s - loss: 0.4785 - acc: 0.83 - ETA: 56s - loss: 0.4725 - acc: 0.84 - ETA: 56s - loss: 0.4673 - acc: 0.84 - ETA: 56s - loss: 0.4653 - acc: 0.83 - ETA: 56s - loss: 0.4802 - acc: 0.83 - ETA: 56s - loss: 0.4807 - acc: 0.82 - ETA: 55s - loss: 0.4867 - acc: 0.82 - ETA: 55s - loss: 0.4824 - acc: 0.82 - ETA: 55s - loss: 0.4823 - acc: 0.82 - ETA: 55s - loss: 0.4760 - acc: 0.82 - ETA: 55s - loss: 0.4687 - acc: 0.82 - ETA: 55s - loss: 0.4859 - acc: 0.82 - ETA: 55s - loss: 0.4760 - acc: 0.83 - ETA: 55s - loss: 0.4728 - acc: 0.82 - ETA: 55s - loss: 0.4630 - acc: 0.83 - ETA: 55s - loss: 0.4592 - acc: 0.83 - ETA: 55s - loss: 0.4587 - acc: 0.83 - ETA: 55s - loss: 0.4548 - acc: 0.83 - ETA: 55s - loss: 0.4623 - acc: 0.83 - ETA: 55s - loss: 0.4603 - acc: 0.83 - ETA: 55s - loss: 0.4677 - acc: 0.82 - ETA: 54s - loss: 0.4600 - acc: 0.83 - ETA: 54s - loss: 0.4722 - acc: 0.82 - ETA: 55s - loss: 0.4704 - acc: 0.83 - ETA: 55s - loss: 0.4649 - acc: 0.83 - ETA: 55s - loss: 0.4569 - acc: 0.83 - ETA: 54s - loss: 0.4582 - acc: 0.83 - ETA: 54s - loss: 0.4584 - acc: 0.83 - ETA: 54s - loss: 0.4748 - acc: 0.83 - ETA: 54s - loss: 0.4774 - acc: 0.83 - ETA: 54s - loss: 0.4821 - acc: 0.83 - ETA: 54s - loss: 0.4927 - acc: 0.83 - ETA: 54s - loss: 0.4852 - acc: 0.83 - ETA: 54s - loss: 0.5023 - acc: 0.83 - ETA: 54s - loss: 0.5136 - acc: 0.83 - ETA: 54s - loss: 0.5142 - acc: 0.83 - ETA: 54s - loss: 0.5097 - acc: 0.83 - ETA: 54s - loss: 0.5047 - acc: 0.83 - ETA: 54s - loss: 0.5005 - acc: 0.83 - ETA: 54s - loss: 0.4996 - acc: 0.83 - ETA: 54s - loss: 0.4971 - acc: 0.83 - ETA: 54s - loss: 0.4984 - acc: 0.83 - ETA: 54s - loss: 0.4925 - acc: 0.83 - ETA: 54s - loss: 0.4880 - acc: 0.84 - ETA: 54s - loss: 0.4954 - acc: 0.84 - ETA: 53s - loss: 0.4892 - acc: 0.84 - ETA: 53s - loss: 0.4913 - acc: 0.84 - ETA: 53s - loss: 0.5055 - acc: 0.83 - ETA: 53s - loss: 0.5070 - acc: 0.83 - ETA: 53s - loss: 0.5037 - acc: 0.83 - ETA: 53s - loss: 0.5042 - acc: 0.83 - ETA: 53s - loss: 0.5013 - acc: 0.83 - ETA: 53s - loss: 0.4953 - acc: 0.84 - ETA: 53s - loss: 0.4927 - acc: 0.84 - ETA: 53s - loss: 0.4906 - acc: 0.84 - ETA: 53s - loss: 0.5016 - acc: 0.83 - ETA: 53s - loss: 0.5018 - acc: 0.83 - ETA: 53s - loss: 0.5005 - acc: 0.83 - ETA: 53s - loss: 0.5009 - acc: 0.83 - ETA: 53s - loss: 0.4988 - acc: 0.83 - ETA: 52s - loss: 0.5026 - acc: 0.83 - ETA: 52s - loss: 0.5061 - acc: 0.83 - ETA: 52s - loss: 0.5178 - acc: 0.83 - ETA: 52s - loss: 0.5184 - acc: 0.83 - ETA: 52s - loss: 0.5160 - acc: 0.83 - ETA: 52s - loss: 0.5139 - acc: 0.83  ...
# Epoch 7/10
# 2418/2418 [==============================] - ETA: 59s - loss: 0.1206 - acc: 1.00 - ETA: 55s - loss: 0.1216 - acc: 1.00 - ETA: 57s - loss: 0.2644 - acc: 0.91 - ETA: 57s - loss: 0.3280 - acc: 0.88 - ETA: 57s - loss: 0.3174 - acc: 0.87 - ETA: 57s - loss: 0.2870 - acc: 0.90 - ETA: 57s - loss: 0.2449 - acc: 0.91 - ETA: 57s - loss: 0.2287 - acc: 0.92 - ETA: 56s - loss: 0.2437 - acc: 0.91 - ETA: 56s - loss: 0.2263 - acc: 0.92 - ETA: 57s - loss: 0.2211 - acc: 0.93 - ETA: 57s - loss: 0.2061 - acc: 0.93 - ETA: 57s - loss: 0.2280 - acc: 0.92 - ETA: 56s - loss: 0.2568 - acc: 0.92 - ETA: 56s - loss: 0.2914 - acc: 0.90 - ETA: 56s - loss: 0.3400 - acc: 0.89 - ETA: 56s - loss: 0.3398 - acc: 0.89 - ETA: 56s - loss: 0.3340 - acc: 0.89 - ETA: 56s - loss: 0.3323 - acc: 0.90 - ETA: 56s - loss: 0.3154 - acc: 0.90 - ETA: 56s - loss: 0.3048 - acc: 0.91 - ETA: 56s - loss: 0.3060 - acc: 0.90 - ETA: 56s - loss: 0.3399 - acc: 0.90 - ETA: 56s - loss: 0.3590 - acc: 0.90 - ETA: 56s - loss: 0.3754 - acc: 0.88 - ETA: 55s - loss: 0.3932 - acc: 0.88 - ETA: 55s - loss: 0.3808 - acc: 0.89 - ETA: 55s - loss: 0.3713 - acc: 0.89 - ETA: 55s - loss: 0.3578 - acc: 0.90 - ETA: 55s - loss: 0.3674 - acc: 0.89 - ETA: 55s - loss: 0.4019 - acc: 0.88 - ETA: 55s - loss: 0.4117 - acc: 0.88 - ETA: 55s - loss: 0.4006 - acc: 0.89 - ETA: 55s - loss: 0.4116 - acc: 0.88 - ETA: 55s - loss: 0.4014 - acc: 0.89 - ETA: 55s - loss: 0.3950 - acc: 0.89 - ETA: 55s - loss: 0.3974 - acc: 0.88 - ETA: 55s - loss: 0.4022 - acc: 0.88 - ETA: 55s - loss: 0.4087 - acc: 0.88 - ETA: 55s - loss: 0.4013 - acc: 0.89 - ETA: 55s - loss: 0.4082 - acc: 0.88 - ETA: 55s - loss: 0.4131 - acc: 0.88 - ETA: 55s - loss: 0.4051 - acc: 0.89 - ETA: 55s - loss: 0.4026 - acc: 0.89 - ETA: 55s - loss: 0.3933 - acc: 0.89 - ETA: 55s - loss: 0.4038 - acc: 0.89 - ETA: 55s - loss: 0.4174 - acc: 0.89 - ETA: 55s - loss: 0.4325 - acc: 0.88 - ETA: 54s - loss: 0.4235 - acc: 0.88 - ETA: 54s - loss: 0.4335 - acc: 0.88 - ETA: 54s - loss: 0.4457 - acc: 0.87 - ETA: 54s - loss: 0.4414 - acc: 0.87 - ETA: 54s - loss: 0.4327 - acc: 0.88 - ETA: 54s - loss: 0.4242 - acc: 0.88 - ETA: 54s - loss: 0.4181 - acc: 0.88 - ETA: 54s - loss: 0.4223 - acc: 0.88 - ETA: 54s - loss: 0.4252 - acc: 0.88 - ETA: 54s - loss: 0.4243 - acc: 0.88 - ETA: 54s - loss: 0.4262 - acc: 0.88 - ETA: 53s - loss: 0.4221 - acc: 0.88 - ETA: 53s - loss: 0.4150 - acc: 0.88 - ETA: 53s - loss: 0.4115 - acc: 0.88 - ETA: 53s - loss: 0.4104 - acc: 0.88 - ETA: 53s - loss: 0.4089 - acc: 0.88 - ETA: 53s - loss: 0.4043 - acc: 0.88 - ETA: 53s - loss: 0.4080 - acc: 0.88 - ETA: 53s - loss: 0.4079 - acc: 0.88 - ETA: 53s - loss: 0.4074 - acc: 0.88 - ETA: 53s - loss: 0.4034 - acc: 0.88 - ETA: 53s - loss: 0.4027 - acc: 0.88 - ETA: 53s - loss: 0.3976 - acc: 0.88 - ETA: 53s - loss: 0.3939 - acc: 0.88 - ETA: 53s - loss: 0.3900 - acc: 0.88 - ETA: 53s - loss: 0.4086 - acc: 0.88 - ETA: 53s - loss: 0.4027 - acc: 0.88 - ETA: 53s - loss: 0.3970 - acc: 0.88 - ETA: 53s - loss: 0.4044 - acc: 0.88 - ETA: 53s - loss: 0.4031 - acc: 0.88 - ETA: 52s - loss: 0.4042 - acc: 0.87 - ETA: 52s - loss: 0.4028 - acc: 0.87 - ETA: 52s - loss: 0.4080 - acc: 0.87 - ETA: 52s - loss: 0.4059 - acc: 0.87 - ETA: 52s - loss: 0.4033 - acc: 0.87 - ETA: 52s - loss: 0.4010 - acc: 0.87 - ETA: 52s - loss: 0.4034 - acc: 0.87 - ETA: 52s - loss: 0.4001 - acc: 0.87 - ETA: 52s - loss: 0.4010 - acc: 0.87 - ETA: 52s - loss: 0.3978 - acc: 0.87 - ETA: 52s - loss: 0.3988 - acc: 0.87 - ETA: 52s - loss: 0.4012 - acc: 0.87 - ETA: 52s - loss: 0.4024 - acc: 0.87 - ETA: 52s - loss: 0.3978 - acc: 0.87 - ETA: 52s - loss: 0.3965 - acc: 0.87 - ETA: 52s - loss: 0.3935 - acc: 0.87 - ETA: 51s - loss: 0.3908 - acc: 0.87 - ETA: 51s - loss: 0.3869 - acc: 0.87 - ETA: 51s - loss: 0.3834 - acc: 0.87 - ETA: 51s - loss: 0.3795 - acc: 0.88 - ETA: 51s - loss: 0.3762 - acc: 0.88 - ETA: 51s - loss: 0.3738 - acc: 0.88 - ETA: 51s - loss: 0.3784 - acc: 0.88 - ETA: 51s - loss: 0.3770 - acc: 0.88 - ETA: 51s - loss: 0.3828 - acc: 0.88 - ETA: 51s - loss: 0.3834 - acc: 0.87 - ETA ...
# Epoch 8/10
# 2418/2418 [==============================] - ETA: 58s - loss: 0.0084 - acc: 1.00 - ETA: 56s - loss: 0.4671 - acc: 0.87 - ETA: 55s - loss: 0.2718 - acc: 0.92 - ETA: 55s - loss: 0.5979 - acc: 0.90 - ETA: 55s - loss: 0.6430 - acc: 0.84 - ETA: 55s - loss: 0.5226 - acc: 0.87 - ETA: 55s - loss: 0.4878 - acc: 0.86 - ETA: 55s - loss: 0.7092 - acc: 0.84 - ETA: 55s - loss: 0.6428 - acc: 0.86 - ETA: 55s - loss: 0.5944 - acc: 0.85 - ETA: 55s - loss: 0.5635 - acc: 0.85 - ETA: 55s - loss: 0.5243 - acc: 0.86 - ETA: 55s - loss: 0.5085 - acc: 0.86 - ETA: 55s - loss: 0.4789 - acc: 0.87 - ETA: 55s - loss: 0.4628 - acc: 0.88 - ETA: 55s - loss: 0.4701 - acc: 0.87 - ETA: 55s - loss: 0.4417 - acc: 0.88 - ETA: 55s - loss: 0.4501 - acc: 0.88 - ETA: 55s - loss: 0.4335 - acc: 0.88 - ETA: 55s - loss: 0.4114 - acc: 0.89 - ETA: 55s - loss: 0.3952 - acc: 0.90 - ETA: 55s - loss: 0.4043 - acc: 0.89 - ETA: 56s - loss: 0.3934 - acc: 0.89 - ETA: 56s - loss: 0.3818 - acc: 0.90 - ETA: 56s - loss: 0.3765 - acc: 0.89 - ETA: 56s - loss: 0.3637 - acc: 0.90 - ETA: 55s - loss: 0.3871 - acc: 0.89 - ETA: 55s - loss: 0.3750 - acc: 0.89 - ETA: 55s - loss: 0.3657 - acc: 0.89 - ETA: 55s - loss: 0.3628 - acc: 0.89 - ETA: 55s - loss: 0.3568 - acc: 0.89 - ETA: 55s - loss: 0.3490 - acc: 0.89 - ETA: 55s - loss: 0.3419 - acc: 0.89 - ETA: 55s - loss: 0.3314 - acc: 0.90 - ETA: 55s - loss: 0.3289 - acc: 0.89 - ETA: 55s - loss: 0.3272 - acc: 0.89 - ETA: 54s - loss: 0.3180 - acc: 0.89 - ETA: 54s - loss: 0.3227 - acc: 0.89 - ETA: 54s - loss: 0.3339 - acc: 0.89 - ETA: 54s - loss: 0.3286 - acc: 0.89 - ETA: 54s - loss: 0.3331 - acc: 0.89 - ETA: 54s - loss: 0.3335 - acc: 0.89 - ETA: 54s - loss: 0.3255 - acc: 0.89 - ETA: 54s - loss: 0.3450 - acc: 0.89 - ETA: 54s - loss: 0.3430 - acc: 0.89 - ETA: 54s - loss: 0.3817 - acc: 0.88 - ETA: 54s - loss: 0.3931 - acc: 0.88 - ETA: 53s - loss: 0.3948 - acc: 0.88 - ETA: 53s - loss: 0.3868 - acc: 0.88 - ETA: 53s - loss: 0.3867 - acc: 0.88 - ETA: 53s - loss: 0.3806 - acc: 0.88 - ETA: 53s - loss: 0.3912 - acc: 0.87 - ETA: 53s - loss: 0.3893 - acc: 0.88 - ETA: 53s - loss: 0.3875 - acc: 0.87 - ETA: 53s - loss: 0.3854 - acc: 0.87 - ETA: 53s - loss: 0.3893 - acc: 0.87 - ETA: 53s - loss: 0.3825 - acc: 0.88 - ETA: 53s - loss: 0.3784 - acc: 0.87 - ETA: 53s - loss: 0.3739 - acc: 0.88 - ETA: 53s - loss: 0.3809 - acc: 0.88 - ETA: 53s - loss: 0.3989 - acc: 0.87 - ETA: 53s - loss: 0.3982 - acc: 0.87 - ETA: 53s - loss: 0.3940 - acc: 0.87 - ETA: 53s - loss: 0.3885 - acc: 0.87 - ETA: 53s - loss: 0.3830 - acc: 0.88 - ETA: 53s - loss: 0.3839 - acc: 0.87 - ETA: 52s - loss: 0.3779 - acc: 0.88 - ETA: 52s - loss: 0.3949 - acc: 0.87 - ETA: 52s - loss: 0.3912 - acc: 0.87 - ETA: 52s - loss: 0.3883 - acc: 0.87 - ETA: 52s - loss: 0.3857 - acc: 0.88 - ETA: 52s - loss: 0.3801 - acc: 0.88 - ETA: 52s - loss: 0.3809 - acc: 0.88 - ETA: 52s - loss: 0.3822 - acc: 0.88 - ETA: 52s - loss: 0.3817 - acc: 0.88 - ETA: 52s - loss: 0.3840 - acc: 0.88 - ETA: 52s - loss: 0.3834 - acc: 0.88 - ETA: 52s - loss: 0.3917 - acc: 0.87 - ETA: 52s - loss: 0.3892 - acc: 0.88 - ETA: 52s - loss: 0.3900 - acc: 0.87 - ETA: 52s - loss: 0.3866 - acc: 0.88 - ETA: 52s - loss: 0.3835 - acc: 0.88 - ETA: 52s - loss: 0.3896 - acc: 0.87 - ETA: 51s - loss: 0.3874 - acc: 0.88 - ETA: 51s - loss: 0.3865 - acc: 0.87 - ETA: 51s - loss: 0.3847 - acc: 0.88 - ETA: 51s - loss: 0.3849 - acc: 0.88 - ETA: 51s - loss: 0.3865 - acc: 0.88 - ETA: 51s - loss: 0.3852 - acc: 0.87 - ETA: 51s - loss: 0.3927 - acc: 0.87 - ETA: 51s - loss: 0.3940 - acc: 0.87 - ETA: 51s - loss: 0.3913 - acc: 0.87 - ETA: 51s - loss: 0.3908 - acc: 0.87 - ETA: 51s - loss: 0.3905 - acc: 0.87 - ETA: 51s - loss: 0.3903 - acc: 0.87 - ETA: 50s - loss: 0.3876 - acc: 0.87 - ETA: 50s - loss: 0.3845 - acc: 0.88 - ETA: 50s - loss: 0.3804 - acc: 0.88 - ETA: 50s - loss: 0.3783 - acc: 0.88 - ETA: 50s - loss: 0.3858 - acc: 0.88 - ETA: 50s - loss: 0.3865 - acc: 0.88 - ETA: 50s - loss: 0.3915 - acc: 0.88 - ETA: 50s - loss: 0.3933 - acc: 0.87 - ETA: 50s - loss: 0.3901 - acc: 0.88 - ETA ...
# Epoch 9/10
# 2418/2418 [==============================] - ETA: 53s - loss: 0.0804 - acc: 1.00 - ETA: 56s - loss: 0.2835 - acc: 0.87 - ETA: 56s - loss: 0.4529 - acc: 0.78 - ETA: 55s - loss: 0.3867 - acc: 0.80 - ETA: 56s - loss: 0.3812 - acc: 0.79 - ETA: 57s - loss: 0.3509 - acc: 0.82 - ETA: 57s - loss: 0.4440 - acc: 0.82 - ETA: 56s - loss: 0.5149 - acc: 0.80 - ETA: 56s - loss: 0.5448 - acc: 0.78 - ETA: 56s - loss: 0.4840 - acc: 0.80 - ETA: 55s - loss: 0.4691 - acc: 0.82 - ETA: 55s - loss: 0.4720 - acc: 0.82 - ETA: 55s - loss: 0.5582 - acc: 0.81 - ETA: 55s - loss: 0.5601 - acc: 0.81 - ETA: 55s - loss: 0.5401 - acc: 0.81 - ETA: 55s - loss: 0.5347 - acc: 0.81 - ETA: 55s - loss: 0.5573 - acc: 0.81 - ETA: 55s - loss: 0.5232 - acc: 0.82 - ETA: 54s - loss: 0.5319 - acc: 0.81 - ETA: 54s - loss: 0.5135 - acc: 0.82 - ETA: 55s - loss: 0.4886 - acc: 0.83 - ETA: 55s - loss: 0.5160 - acc: 0.82 - ETA: 55s - loss: 0.4997 - acc: 0.83 - ETA: 55s - loss: 0.4953 - acc: 0.83 - ETA: 55s - loss: 0.4839 - acc: 0.83 - ETA: 55s - loss: 0.4704 - acc: 0.83 - ETA: 55s - loss: 0.4593 - acc: 0.83 - ETA: 55s - loss: 0.4519 - acc: 0.84 - ETA: 55s - loss: 0.4417 - acc: 0.84 - ETA: 56s - loss: 0.4472 - acc: 0.84 - ETA: 56s - loss: 0.4395 - acc: 0.84 - ETA: 56s - loss: 0.4247 - acc: 0.85 - ETA: 56s - loss: 0.4267 - acc: 0.85 - ETA: 56s - loss: 0.4267 - acc: 0.85 - ETA: 56s - loss: 0.4478 - acc: 0.84 - ETA: 56s - loss: 0.4351 - acc: 0.85 - ETA: 56s - loss: 0.4302 - acc: 0.85 - ETA: 55s - loss: 0.4176 - acc: 0.85 - ETA: 55s - loss: 0.4057 - acc: 0.86 - ETA: 55s - loss: 0.4090 - acc: 0.85 - ETA: 55s - loss: 0.4254 - acc: 0.85 - ETA: 55s - loss: 0.4184 - acc: 0.85 - ETA: 55s - loss: 0.4151 - acc: 0.86 - ETA: 55s - loss: 0.4081 - acc: 0.86 - ETA: 55s - loss: 0.4014 - acc: 0.86 - ETA: 55s - loss: 0.3972 - acc: 0.86 - ETA: 55s - loss: 0.3885 - acc: 0.87 - ETA: 55s - loss: 0.3794 - acc: 0.87 - ETA: 55s - loss: 0.3776 - acc: 0.87 - ETA: 55s - loss: 0.3804 - acc: 0.87 - ETA: 55s - loss: 0.3726 - acc: 0.87 - ETA: 55s - loss: 0.3705 - acc: 0.87 - ETA: 55s - loss: 0.3679 - acc: 0.87 - ETA: 54s - loss: 0.3653 - acc: 0.87 - ETA: 54s - loss: 0.3640 - acc: 0.87 - ETA: 54s - loss: 0.3568 - acc: 0.87 - ETA: 54s - loss: 0.3541 - acc: 0.87 - ETA: 54s - loss: 0.3478 - acc: 0.88 - ETA: 54s - loss: 0.3480 - acc: 0.88 - ETA: 54s - loss: 0.3568 - acc: 0.87 - ETA: 54s - loss: 0.3535 - acc: 0.87 - ETA: 54s - loss: 0.3573 - acc: 0.87 - ETA: 54s - loss: 0.3513 - acc: 0.88 - ETA: 53s - loss: 0.3520 - acc: 0.88 - ETA: 53s - loss: 0.3463 - acc: 0.88 - ETA: 53s - loss: 0.3443 - acc: 0.88 - ETA: 54s - loss: 0.3502 - acc: 0.88 - ETA: 54s - loss: 0.3464 - acc: 0.88 - ETA: 54s - loss: 0.3475 - acc: 0.88 - ETA: 53s - loss: 0.3420 - acc: 0.88 - ETA: 53s - loss: 0.3411 - acc: 0.88 - ETA: 53s - loss: 0.3375 - acc: 0.88 - ETA: 53s - loss: 0.3409 - acc: 0.88 - ETA: 53s - loss: 0.3365 - acc: 0.88 - ETA: 53s - loss: 0.3324 - acc: 0.88 - ETA: 53s - loss: 0.3283 - acc: 0.88 - ETA: 53s - loss: 0.3240 - acc: 0.89 - ETA: 53s - loss: 0.3208 - acc: 0.89 - ETA: 52s - loss: 0.3169 - acc: 0.89 - ETA: 52s - loss: 0.3201 - acc: 0.89 - ETA: 52s - loss: 0.3159 - acc: 0.89 - ETA: 52s - loss: 0.3140 - acc: 0.89 - ETA: 52s - loss: 0.3106 - acc: 0.89 - ETA: 52s - loss: 0.3075 - acc: 0.89 - ETA: 52s - loss: 0.3188 - acc: 0.89 - ETA: 52s - loss: 0.3161 - acc: 0.89 - ETA: 52s - loss: 0.3186 - acc: 0.89 - ETA: 52s - loss: 0.3172 - acc: 0.89 - ETA: 52s - loss: 0.3137 - acc: 0.89 - ETA: 52s - loss: 0.3103 - acc: 0.89 - ETA: 51s - loss: 0.3070 - acc: 0.89 - ETA: 51s - loss: 0.3036 - acc: 0.89 - ETA: 51s - loss: 0.3214 - acc: 0.89 - ETA: 51s - loss: 0.3231 - acc: 0.89 - ETA: 51s - loss: 0.3208 - acc: 0.89 - ETA: 51s - loss: 0.3201 - acc: 0.89 - ETA: 51s - loss: 0.3249 - acc: 0.89 - ETA: 51s - loss: 0.3233 - acc: 0.89 - ETA: 51s - loss: 0.3217 - acc: 0.89 - ETA: 51s - loss: 0.3247 - acc: 0.89 - ETA: 51s - loss: 0.3213 - acc: 0.89 - ETA: 51s - loss: 0.3190 - acc: 0.89 - ETA: 51s - loss: 0.3218 - acc: 0.89 - ETA: 51s - loss: 0.3218 - acc: 0.89 - ETA ...
# Epoch 10/10
# 2418/2418 [==============================] - ETA: 57s - loss: 1.0729e-06 - acc: 1.00 - ETA: 57s - loss: 0.1157 - acc: 1.0000   - ETA: 56s - loss: 0.2128 - acc: 0.92 - ETA: 55s - loss: 0.4062 - acc: 0.90 - ETA: 56s - loss: 0.3581 - acc: 0.88 - ETA: 55s - loss: 0.4188 - acc: 0.87 - ETA: 55s - loss: 0.3690 - acc: 0.89 - ETA: 55s - loss: 0.3697 - acc: 0.88 - ETA: 55s - loss: 0.3305 - acc: 0.90 - ETA: 56s - loss: 0.3100 - acc: 0.90 - ETA: 58s - loss: 0.2892 - acc: 0.91 - ETA: 58s - loss: 0.2724 - acc: 0.91 - ETA: 58s - loss: 0.3442 - acc: 0.90 - ETA: 58s - loss: 0.3213 - acc: 0.91 - ETA: 58s - loss: 0.3016 - acc: 0.92 - ETA: 57s - loss: 0.3084 - acc: 0.91 - ETA: 57s - loss: 0.3678 - acc: 0.91 - ETA: 57s - loss: 0.3477 - acc: 0.91 - ETA: 57s - loss: 0.3275 - acc: 0.92 - ETA: 56s - loss: 0.3310 - acc: 0.91 - ETA: 56s - loss: 0.3169 - acc: 0.92 - ETA: 56s - loss: 0.3200 - acc: 0.92 - ETA: 56s - loss: 0.3124 - acc: 0.92 - ETA: 56s - loss: 0.2982 - acc: 0.93 - ETA: 56s - loss: 0.2854 - acc: 0.93 - ETA: 56s - loss: 0.2848 - acc: 0.93 - ETA: 56s - loss: 0.2941 - acc: 0.92 - ETA: 55s - loss: 0.3134 - acc: 0.92 - ETA: 55s - loss: 0.3343 - acc: 0.91 - ETA: 55s - loss: 0.3282 - acc: 0.91 - ETA: 55s - loss: 0.3180 - acc: 0.91 - ETA: 55s - loss: 0.3414 - acc: 0.91 - ETA: 55s - loss: 0.3423 - acc: 0.90 - ETA: 55s - loss: 0.3352 - acc: 0.91 - ETA: 55s - loss: 0.3294 - acc: 0.91 - ETA: 55s - loss: 0.3230 - acc: 0.91 - ETA: 55s - loss: 0.3167 - acc: 0.91 - ETA: 55s - loss: 0.3160 - acc: 0.91 - ETA: 55s - loss: 0.3151 - acc: 0.91 - ETA: 55s - loss: 0.3172 - acc: 0.91 - ETA: 55s - loss: 0.3096 - acc: 0.91 - ETA: 54s - loss: 0.3049 - acc: 0.91 - ETA: 54s - loss: 0.2972 - acc: 0.91 - ETA: 54s - loss: 0.2984 - acc: 0.91 - ETA: 54s - loss: 0.2916 - acc: 0.91 - ETA: 54s - loss: 0.3035 - acc: 0.91 - ETA: 54s - loss: 0.2986 - acc: 0.91 - ETA: 54s - loss: 0.3029 - acc: 0.91 - ETA: 54s - loss: 0.3290 - acc: 0.90 - ETA: 54s - loss: 0.3384 - acc: 0.90 - ETA: 54s - loss: 0.3412 - acc: 0.90 - ETA: 54s - loss: 0.3611 - acc: 0.89 - ETA: 53s - loss: 0.3787 - acc: 0.89 - ETA: 53s - loss: 0.3718 - acc: 0.89 - ETA: 54s - loss: 0.3675 - acc: 0.89 - ETA: 54s - loss: 0.3663 - acc: 0.89 - ETA: 54s - loss: 0.3611 - acc: 0.89 - ETA: 54s - loss: 0.3546 - acc: 0.90 - ETA: 54s - loss: 0.3589 - acc: 0.90 - ETA: 54s - loss: 0.3542 - acc: 0.90 - ETA: 54s - loss: 0.3569 - acc: 0.90 - ETA: 54s - loss: 0.3533 - acc: 0.90 - ETA: 54s - loss: 0.3674 - acc: 0.89 - ETA: 53s - loss: 0.3773 - acc: 0.89 - ETA: 53s - loss: 0.3941 - acc: 0.88 - ETA: 53s - loss: 0.3880 - acc: 0.88 - ETA: 53s - loss: 0.3859 - acc: 0.88 - ETA: 53s - loss: 0.3835 - acc: 0.88 - ETA: 53s - loss: 0.3802 - acc: 0.88 - ETA: 53s - loss: 0.3748 - acc: 0.88 - ETA: 53s - loss: 0.3711 - acc: 0.88 - ETA: 53s - loss: 0.3732 - acc: 0.88 - ETA: 53s - loss: 0.3733 - acc: 0.88 - ETA: 53s - loss: 0.3688 - acc: 0.88 - ETA: 53s - loss: 0.3670 - acc: 0.89 - ETA: 53s - loss: 0.3619 - acc: 0.89 - ETA: 52s - loss: 0.3570 - acc: 0.89 - ETA: 52s - loss: 0.3551 - acc: 0.89 - ETA: 52s - loss: 0.3529 - acc: 0.89 - ETA: 52s - loss: 0.3501 - acc: 0.89 - ETA: 52s - loss: 0.3471 - acc: 0.89 - ETA: 52s - loss: 0.3450 - acc: 0.90 - ETA: 52s - loss: 0.3412 - acc: 0.90 - ETA: 52s - loss: 0.3388 - acc: 0.90 - ETA: 52s - loss: 0.3353 - acc: 0.90 - ETA: 52s - loss: 0.3313 - acc: 0.90 - ETA: 52s - loss: 0.3276 - acc: 0.90 - ETA: 52s - loss: 0.3277 - acc: 0.90 - ETA: 52s - loss: 0.3256 - acc: 0.90 - ETA: 52s - loss: 0.3238 - acc: 0.90 - ETA: 52s - loss: 0.3201 - acc: 0.91 - ETA: 52s - loss: 0.3216 - acc: 0.90 - ETA: 52s - loss: 0.3194 - acc: 0.90 - ETA: 52s - loss: 0.3177 - acc: 0.90 - ETA: 51s - loss: 0.3169 - acc: 0.90 - ETA: 51s - loss: 0.3151 - acc: 0.91 - ETA: 51s - loss: 0.3280 - acc: 0.90 - ETA: 51s - loss: 0.3263 - acc: 0.90 - ETA: 51s - loss: 0.3255 - acc: 0.90 - ETA: 51s - loss: 0.3222 - acc: 0.90 - ETA: 51s - loss: 0.3192 - acc: 0.91 - ETA: 51s - loss: 0.3173 - acc: 0.91 - ETA: 51s - loss: 0.3152 - acc: 0.91 - ETA: 51s - loss: 0.3152 - acc: 0. ...

# %%
# Restore the best found model during validation
# m.load_weights(tmpfn)

loss, acc = m2.evaluate(x_test, y_test, batch_size=BATCH_SIZE)
print('Test loss / test accuracy = {:.4f} / {:.4f}'.format(loss, acc))

preds = m2.predict(x_test, batch_size=BATCH_SIZE, verbose=0,
                  steps=None)

def get_result_labels(results):
    return [unique_labels[np.where(row==max(row))[0][0]] for row in results]

result_labels = get_result_labels(preds)

print('Accuracy score: %.2f' % accuracy_score(result_labels, y_str_test))
print(classification_report(y_str_test, result_labels))
